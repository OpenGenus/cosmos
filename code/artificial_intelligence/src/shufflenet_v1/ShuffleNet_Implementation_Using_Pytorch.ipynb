# %%
#Mounting G-drive to load dataset

from google.colab import drive

drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/Datasets' #Choose this root path according to you, I have a Datasets folder for saving all my models
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # **Importing Libraries**

# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms #for data augmentation; here, image transformations
import torchvision.datasets as dsets #for data loaders for popular vision datasets
from torchvision import  models #for definitions for popular model architectures
from torchsummary import summary #to get model summary after declaring it
from torch import nn,optim
import torch.nn.functional as functions #for non linear functions
import torchvision

import numpy as np
import pandas as pd

#core python packages
import os
import sys
import time
import math
import datetime as dt
import tqdm
import argparse
import glob
import tarfile
import warnings
warnings.filterwarnings("ignore")

#for plotting images
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# # **Initializing Constants**

# %%
#initialize values
device = 'cuda' if torch.cuda.is_available() else 'cpu'
best_acc = 0 #best test accuracy
start_epoch = 0 #start from epoch 0 or last checkpoint epoch
batch_size = 128

#declaring constant label mapper for CIFAR 10 dataset
LABEL_MAP = {0:'airplane', 1:'car', 2:'bird', 3:'cat', 4:'deer', 5:'dog', 6:'frog', 7:'horse', 8:'ship', 9:'truck'}

# %% [markdown]
# # **Exploring Dataset**

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(5, 5), dpi=150, facecolor='w', edgecolor='k')

#Exploring image dataset
def show_imgs(X):
  plt.figure(1)
  plt.rcParams.update({'font.size': 5})
  k=0
  for i in range(0,5):
    for j in range(0,5):
      plt.subplot2grid((5,5),(i,j))
      plt.title(LABEL_MAP[X[k][1]])
      plt.imshow(X[k][0])
      plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
      plt.tick_params(axis='y', which='both', left=False, right=False, labelleft=False)
      k = k+1
  #show the plot
  plt.tight_layout()
  plt.show()

data_train = dsets.CIFAR10(root=root_path, download = True)
data_test = dsets.CIFAR10(root=root_path, download=True, train=False)
show_imgs(data_train)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # **Loading Dataset with Data Augmentation**

# %%
#defining transformation rules for training set
transform_train = transforms.Compose(transforms=[transforms.Pad(4), transforms.RandomHorizontalFlip(), transforms.RandomCrop(32), transforms.ToTensor(), transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])

#defining transformation rules for testing set
transform_test = transforms.Compose(transforms=[transforms.ToTensor(), transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])

train_set = dsets.CIFAR10(root=root_path, download = True, transform= transform_train)
train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=2)

test_set = dsets.CIFAR10(root=root_path, download=True, train=False, transform= transform_test)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=2)

#looking into the transformed images
figure(num=None, figsize=(10,8), dpi = 150, facecolor = 'w', edgecolor='k')
def imshow(img):
  img = img/2 + 0.5 #unnormalize
  np_img = img.numpy()
  plt.imshow(np.transpose(np_img, (1,2,0)))
  plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
  plt.tick_params(axis='y', which='both', left=False, right=False, labelleft=False)
  plt.show()

#get random training example images
data_iter = iter(train_loader)
images, labels = data_iter.next()

#understanding image tensor
images[0].shape

#show images
imshow(torchvision.utils.make_grid(images))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # **Creating ShuffleNet Network**

# %%
class ShuffleBlock(nn.Module):
  def __init__(self, groups):
    super(ShuffleBlock, self).__init__()
    self.groups = groups
  def forward(self, x):
    '''Channel shuffle: [N,C,H,W] -> [N, g, C/g, H, W] -> [N, C/g, g, H, W] -> [N,C,H,W]'''
    N,C,H,W = x.size()
    g = self.groups
    return x.view(N, g, C//g, H, W).permute(0, 2, 1, 3, 4).reshape(N, C, H, W)

# %%
class Bottleneck(nn.Module): 
  def __init__(self, in_planes, out_planes, stride, groups):
    super(Bottleneck, self).__init__()
    self.stride = stride
    mid_planes = int(out_planes/4)
    g = 1 if in_planes == 24 else groups
    self.conv1 = nn.Conv2d(in_planes, mid_planes, kernel_size=1, groups=g, bias=False)
    self.bn1 = nn.BatchNorm2d(mid_planes)
    self.shuffle1 = ShuffleBlock(groups= g)
    self.conv2 = nn.Conv2d(mid_planes, mid_planes, kernel_size=3, stride=stride, padding=1, groups=mid_planes, bias=False)
    self.bn2 = nn.BatchNorm2d(mid_planes)
    self.conv3 = nn.Conv2d(mid_planes, out_planes, kernel_size=1, groups=groups, bias=False)
    self.bn3 = nn.BatchNorm2d(out_planes)
    self.shortcut = nn.Sequential()
    if stride==2:
      self.shortcut = nn.Sequential(nn.AvgPool2d(3,stride=2, padding =1))
  def forward(self,x):
    out = functions.relu(self.bn1(self.conv1(x)))
    out = self.shuffle1(out)
    out = functions.relu(self.bn2(self.conv2(out)))
    out = self.bn3(self.conv3(out))
    res = self.shortcut(x)
    out = functions.relu(torch.cat([out,res], 1)) if self.stride==2 else functions.relu(out+res)
    return out

# %%
class ShuffleNet(nn.Module):
  def __init__(self, cfg):
    super(ShuffleNet, self).__init__()
    out_planes = cfg['out_planes']
    num_blocks = cfg['num_blocks']
    groups = cfg['groups']
    self.conv1 = nn.Conv2d(3, 24, kernel_size=1, bias = False)
    self.bn1 = nn.BatchNorm2d(24)
    self.in_planes = 24
    self.layer1 = self._make_layer(out_planes[0], num_blocks[0], groups)
    self.layer2 = self._make_layer(out_planes[1], num_blocks[1], groups)
    self.layer3 = self._make_layer(out_planes[2], num_blocks[2], groups)
    self.linear = nn.Linear(out_planes[2], 10) #10 as there are 10 classes

  def _make_layer(self, out_planes, num_blocks, groups):
    layers = []
    for i in range(num_blocks):
      stride = 2 if i == 0 else 1
      cat_planes = self.in_planes if i==0 else 0
      layers.append(Bottleneck(self.in_planes, out_planes-cat_planes, stride=stride, groups=groups))
      self.in_planes = out_planes
    return nn.Sequential(*layers)
  
  def forward(self,x):
    out = functions.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = functions.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

# %%
def ShuffleNetG2():
  cfg = {'out_planes': [200, 400, 800],
         'num_blocks': [4, 8, 4],
         'groups': 2
         }
  return ShuffleNet(cfg)

def ShuffleNetG3():
  cfg = {'out_planes': [240, 480, 960],
         'num_blocks': [4, 8, 4],
         'groups': 3
         }
  return ShuffleNet(cfg)

# #testing the shufflenet with rnadom vector
# net = ShuffleNetG2()
# x = torch.randn(1, 3, 32, 32)
# y = net(x)
# print(y)

#Shufflenet with groups = 2
net2 = ShuffleNetG2()
print("ShuffleNet with 2 Groups: " + str(net2))

#Shufflenet with groups = 3
net3 = ShuffleNetG3()
print("ShuffleNet with 3 Groups: " + str(net3))
#we will be using g=3 for training

#Setting the model with CUDA
if torch.cuda.is_available():
  net3.cuda()
# Out:
# ShuffleNet with 2 Groups: ShuffleNet(
#   (conv1): Conv2d(3, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(24, 44, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(44, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(44, 44, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=44, bias=False)
#       (bn2): BatchNorm2d(44, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(44, 176, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn3): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=2, padding=1)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(200, 50, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn1): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(50, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=50, bias=False)
#       (bn2): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(50, 200, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn3): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(200, 50, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn1): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(50, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=50, bias=False)
#       (bn2): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(50, 200, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn3): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(200, 50, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn1): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(50, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=50, bias=False)
#       (bn2): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(50, 200, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn3): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(200, 50, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn1): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(50, 50, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=50, bias=False)
#       (bn2): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(50, 200, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn3): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=2, padding=1)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(400, 100, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn1): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(100, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=100, bias=False)
#       (bn2): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(100, 400, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn3): BatchNorm2d(400, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(400, 100, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn1): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(100, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=100, bias=False)
#       (bn2): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(100, 400, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn3): BatchNorm2d(400, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(400, 100, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn1): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(100, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=100, bias=False)
#       (bn2): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(100, 400, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn3): BatchNorm2d(400, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(400, 100, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn1): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(100, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=100, bias=False)
#       (bn2): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(100, 400, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn3): BatchNorm2d(400, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(400, 100, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn1): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(100, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=100, bias=False)
#       (bn2): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(100, 400, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn3): BatchNorm2d(400, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(400, 100, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn1): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(100, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=100, bias=False)
#       (bn2): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(100, 400, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn3): BatchNorm2d(400, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(400, 100, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn1): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(100, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=100, bias=False)
#       (bn2): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(100, 400, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn3): BatchNorm2d(400, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(400, 100, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn1): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(100, 100, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=100, bias=False)
#       (bn2): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(100, 400, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn3): BatchNorm2d(400, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=2, padding=1)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(800, 200, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn1): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=200, bias=False)
#       (bn2): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(200, 800, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn3): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(800, 200, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn1): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=200, bias=False)
#       (bn2): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(200, 800, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn3): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(800, 200, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn1): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=200, bias=False)
#       (bn2): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(200, 800, kernel_size=(1, 1), stride=(1, 1), groups=2, bias=False)
#       (bn3): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=800, out_features=10, bias=True)
# )
# ShuffleNet with 3 Groups: ShuffleNet(
#   (conv1): Conv2d(3, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(24, 54, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(54, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(54, 54, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=54, bias=False)
#       (bn2): BatchNorm2d(54, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(54, 216, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn3): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=2, padding=1)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(240, 60, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn1): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(60, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=60, bias=False)
#       (bn2): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(60, 240, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn3): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(240, 60, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn1): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(60, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=60, bias=False)
#       (bn2): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(60, 240, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn3): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(240, 60, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn1): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(60, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=60, bias=False)
#       (bn2): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(60, 240, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn3): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(240, 60, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn1): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(60, 60, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=60, bias=False)
#       (bn2): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(60, 240, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn3): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=2, padding=1)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(120, 120, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=120, bias=False)
#       (bn2): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn3): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(120, 120, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=120, bias=False)
#       (bn2): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn3): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(120, 120, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=120, bias=False)
#       (bn2): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn3): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(120, 120, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=120, bias=False)
#       (bn2): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn3): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(120, 120, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=120, bias=False)
#       (bn2): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn3): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(120, 120, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=120, bias=False)
#       (bn2): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn3): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(120, 120, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=120, bias=False)
#       (bn2): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn3): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(120, 120, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=120, bias=False)
#       (bn2): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn3): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=2, padding=1)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#       (bn2): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn3): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#       (bn2): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn3): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shuffle1): ShuffleBlock()
#       (conv2): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#       (bn2): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1), groups=3, bias=False)
#       (bn3): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=960, out_features=10, bias=True)
# )

# %% [markdown]
# # **Setting up loss function and optimizer**

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net3.parameters(), lr = 0.01,momentum=0.9, weight_decay=5e-4)

# %% [markdown]
# # **Training model**

# %%
def train_model():
  net3.train()
  train_loss = 0
  n_correct = 0
  n_total = 0
  for batch_size, (inputs, targets) in enumerate(train_loader):
    inputs, targets = inputs.to(device), targets.to(device)
    optimizer.zero_grad()
    outputs = net3(inputs)
    loss = criterion(outputs, targets)
    loss.backward()
    optimizer.step()
    train_loss += loss.item()
    _, predicted = outputs.max(1)
    n_correct +=predicted.eq(targets).sum().item()
    n_total += targets.shape[0]
  return train_loss/(batch_size+1), n_correct/n_total

# %% [markdown]
# # **Loss Accuracy Calculation**

# %%
def get_loss_acc(is_test_dataset = True):
  net3.eval()
  dataloader = test_loader if is_test_dataset else train-loader
  n_correct = 0
  n_total = 0
  test_loss = 0
  with torch.no_grad():
    for batch_size, (inputs, targets) in enumerate(dataloader):
      inputs, targets = inputs.to(device), targets.to(device)
      outputs = net3(inputs)
      test_loss += criterion(outputs, targets).item()
      _, predicted = outputs.max(1)
      n_correct +=predicted.eq(targets).sum().item()
      n_total += targets.shape[0]

  return test_loss/(batch_size+1), n_correct/n_total

# %% [markdown]
# # **Model testing**

# %%
def save_best_model(epoch):
  global best_acc
  net3.eval()
  test_loss = 0
  correct = 0
  total = 0
  with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(train_loader):
      inputs, targets = inputs.to(device), targets.to(device)
      outputs = net3(inputs)
      loss = criterion(outputs, targets)
      test_loss += loss.item()
      _, predicted = outputs.max(1)
      total += targets.size(0)
      correct +=predicted.eq(targets).sum().item()
      print(batch_idx, len(train_loader), 'Loss: %.3f | Acc: %0.3f%% (Correct classifications %d/Total classifications %d)' % (test_loss/(batch_idx+1), 100.*correct/total, correct, total))

      #save checkpoint
      acc =100.*correct/total
      if acc>best_acc:
        print('Saving...')
        state = {'net': net3.state_dict(),
                 'acc': acc,
                 'epoch': epoch
                 }
        if not os.path.isdir('checkpoint'):
          os.mkdir('checkpoint')
        torch.save(state, './checkpoint/ckpt.pth')
        torch.save(net3, './checkpoint/net3.pth')
        best_acc = acc

# %%
EPOCH = 60
training_time = dt.datetime.now()
start = dt.datetime.now()
start_epoch = 0
train_accuracy_list = []
test_accuracy_list = []
for epoch_i in range(start_epoch, start_epoch + EPOCH):
  global accuracy_list
  current_learning_rate = [i['lr'] for i in optimizer.param_groups][0]
  print('Batch Size', batch_size, '(%0.2fs)\n\nEpoch: %d/%d | Current Learning Rate: %.4f ' % ((dt.datetime.now() - start).seconds, epoch_i +1, EPOCH+start_epoch , current_learning_rate))
  start = dt.datetime.now()
  test_loss, test_acc = get_loss_acc()
  train_loss, train_acc = train_model()
  train_accuracy_list.append(train_acc*100)
  test_accuracy_list.append(test_acc*100)
  save_best_model(epoch_i)
  print('Train Loss: %.3f | Acc: %.3f%% \nTest Loss: %0.3f | Acc: %0.3f%% \n\n' % (train_loss, train_acc*100, test_loss, test_acc*100))

print('\n\nTotal Training time: %0.2f minutes ' %((dt.datetime.now() - training_time).seconds/60))
# Out:
# Streaming output truncated to the last 5000 lines.
# 174 391 Loss: 0.228 | Acc: 92.308% (Correct classifications 20677/Total classifications 22400)
# 175 391 Loss: 0.227 | Acc: 92.316% (Correct classifications 20797/Total classifications 22528)
# 176 391 Loss: 0.227 | Acc: 92.324% (Correct classifications 20917/Total classifications 22656)
# 177 391 Loss: 0.227 | Acc: 92.328% (Correct classifications 21036/Total classifications 22784)
# 178 391 Loss: 0.227 | Acc: 92.323% (Correct classifications 21153/Total classifications 22912)
# 179 391 Loss: 0.228 | Acc: 92.309% (Correct classifications 21268/Total classifications 23040)
# 180 391 Loss: 0.228 | Acc: 92.313% (Correct classifications 21387/Total classifications 23168)
# 181 391 Loss: 0.228 | Acc: 92.303% (Correct classifications 21503/Total classifications 23296)
# 182 391 Loss: 0.229 | Acc: 92.290% (Correct classifications 21618/Total classifications 23424)
# 183 391 Loss: 0.228 | Acc: 92.302% (Correct classifications 21739/Total classifications 23552)
# 184 391 Loss: 0.229 | Acc: 92.276% (Correct classifications 21851/Total classifications 23680)
# 185 391 Loss: 0.229 | Acc: 92.255% (Correct classifications 21964/Total classifications 23808)
# 186 391 Loss: 0.230 | Acc: 92.238% (Correct classifications 22078/Total classifications 23936)
# 187 391 Loss: 0.230 | Acc: 92.237% (Correct classifications 22196/Total classifications 24064)
# 188 391 Loss: 0.230 | Acc: 92.229% (Correct classifications 22312/Total classifications 24192)
# 189 391 Loss: 0.229 | Acc: 92.237% (Correct classifications 22432/Total classifications 24320)
# 190 391 Loss: 0.229 | Acc: 92.237% (Correct classifications 22550/Total classifications 24448)
# 191 391 Loss: 0.229 | Acc: 92.253% (Correct classifications 22672/Total classifications 24576)
# 192 391 Loss: 0.230 | Acc: 92.240% (Correct classifications 22787/Total classifications 24704)
# 193 391 Loss: 0.230 | Acc: 92.236% (Correct classifications 22904/Total classifications 24832)
# 194 391 Loss: 0.229 | Acc: 92.260% (Correct classifications 23028/Total classifications 24960)
# 195 391 Loss: 0.229 | Acc: 92.267% (Correct classifications 23148/Total classifications 25088)
# 196 391 Loss: 0.229 | Acc: 92.263% (Correct classifications 23265/Total classifications 25216)
# 197 391 Loss: 0.230 | Acc: 92.255% (Correct classifications 23381/Total classifications 25344)
# 198 391 Loss: 0.230 | Acc: 92.239% (Correct classifications 23495/Total classifications 25472)
# 199 391 Loss: 0.230 | Acc: 92.246% (Correct classifications 23615/Total classifications 25600)
# 200 391 Loss: 0.230 | Acc: 92.254% (Correct classifications 23735/Total classifications 25728)
# 201 391 Loss: 0.230 | Acc: 92.261% (Correct classifications 23855/Total classifications 25856)
# 202 391 Loss: 0.230 | Acc: 92.261% (Correct classifications 23973/Total classifications 25984)
# 203 391 Loss: 0.229 | Acc: 92.272% (Correct classifications 24094/Total classifications 26112)
# 204 391 Loss: 0.230 | Acc: 92.248% (Correct classifications 24206/Total classifications 26240)
# 205 391 Loss: 0.230 | Acc: 92.256% (Correct classifications 24326/Total classifications 26368)
# 206 391 Loss: 0.230 | Acc: 92.240% (Correct classifications 24440/Total classifications 26496)
# 207 391 Loss: 0.230 | Acc: 92.244% (Correct classifications 24559/Total classifications 26624)
# 208 391 Loss: 0.230 | Acc: 92.244% (Correct classifications 24677/Total classifications 26752)
# 209 391 Loss: 0.231 | Acc: 92.221% (Correct classifications 24789/Total classifications 26880)
# 210 391 Loss: 0.231 | Acc: 92.217% (Correct classifications 24906/Total classifications 27008)
# 211 391 Loss: 0.231 | Acc: 92.221% (Correct classifications 25025/Total classifications 27136)
# 212 391 Loss: 0.231 | Acc: 92.221% (Correct classifications 25143/Total classifications 27264)
# 213 391 Loss: 0.231 | Acc: 92.202% (Correct classifications 25256/Total classifications 27392)
# 214 391 Loss: 0.231 | Acc: 92.195% (Correct classifications 25372/Total classifications 27520)
# 215 391 Loss: 0.231 | Acc: 92.188% (Correct classifications 25488/Total classifications 27648)
# 216 391 Loss: 0.231 | Acc: 92.198% (Correct classifications 25609/Total classifications 27776)
# 217 391 Loss: 0.230 | Acc: 92.198% (Correct classifications 25727/Total classifications 27904)
# 218 391 Loss: 0.230 | Acc: 92.198% (Correct classifications 25845/Total classifications 28032)
# 219 391 Loss: 0.231 | Acc: 92.198% (Correct classifications 25963/Total classifications 28160)
# 220 391 Loss: 0.231 | Acc: 92.184% (Correct classifications 26077/Total classifications 28288)
# 221 391 Loss: 0.231 | Acc: 92.188% (Correct classifications 26196/Total classifications 28416)
# 222 391 Loss: 0.231 | Acc: 92.184% (Correct classifications 26313/Total classifications 28544)
# 223 391 Loss: 0.231 | Acc: 92.181% (Correct classifications 26430/Total classifications 28672)
# 224 391 Loss: 0.231 | Acc: 92.194% (Correct classifications 26552/Total classifications 28800)
# 225 391 Loss: 0.231 | Acc: 92.198% (Correct classifications 26671/Total classifications 28928)
# 226 391 Loss: 0.231 | Acc: 92.194% (Correct classifications 26788/Total classifications 29056)
# 227 391 Loss: 0.230 | Acc: 92.201% (Correct classifications 26908/Total classifications 29184)
# 228 391 Loss: 0.231 | Acc: 92.205% (Correct classifications 27027/Total classifications 29312)
# 229 391 Loss: 0.230 | Acc: 92.215% (Correct classifications 27148/Total classifications 29440)
# 230 391 Loss: 0.230 | Acc: 92.218% (Correct classifications 27267/Total classifications 29568)
# 231 391 Loss: 0.230 | Acc: 92.218% (Correct classifications 27385/Total classifications 29696)
# 232 391 Loss: 0.230 | Acc: 92.234% (Correct classifications 27508/Total classifications 29824)
# 233 391 Loss: 0.230 | Acc: 92.244% (Correct classifications 27629/Total classifications 29952)
# 234 391 Loss: 0.230 | Acc: 92.237% (Correct classifications 27745/Total classifications 30080)
# 235 391 Loss: 0.230 | Acc: 92.224% (Correct classifications 27859/Total classifications 30208)
# 236 391 Loss: 0.230 | Acc: 92.220% (Correct classifications 27976/Total classifications 30336)
# 237 391 Loss: 0.230 | Acc: 92.224% (Correct classifications 28095/Total classifications 30464)
# 238 391 Loss: 0.231 | Acc: 92.220% (Correct classifications 28212/Total classifications 30592)
# 239 391 Loss: 0.231 | Acc: 92.207% (Correct classifications 28326/Total classifications 30720)
# 240 391 Loss: 0.231 | Acc: 92.204% (Correct classifications 28443/Total classifications 30848)
# 241 391 Loss: 0.231 | Acc: 92.197% (Correct classifications 28559/Total classifications 30976)
# 242 391 Loss: 0.231 | Acc: 92.204% (Correct classifications 28679/Total classifications 31104)
# 243 391 Loss: 0.231 | Acc: 92.197% (Correct classifications 28795/Total classifications 31232)
# 244 391 Loss: 0.231 | Acc: 92.181% (Correct classifications 28908/Total classifications 31360)
# 245 391 Loss: 0.231 | Acc: 92.178% (Correct classifications 29025/Total classifications 31488)
# 246 391 Loss: 0.232 | Acc: 92.172% (Correct classifications 29141/Total classifications 31616)
# 247 391 Loss: 0.232 | Acc: 92.184% (Correct classifications 29263/Total classifications 31744)
# 248 391 Loss: 0.231 | Acc: 92.191% (Correct classifications 29383/Total classifications 31872)
# 249 391 Loss: 0.231 | Acc: 92.197% (Correct classifications 29503/Total classifications 32000)
# 250 391 Loss: 0.231 | Acc: 92.188% (Correct classifications 29618/Total classifications 32128)
# 251 391 Loss: 0.231 | Acc: 92.181% (Correct classifications 29734/Total classifications 32256)
# 252 391 Loss: 0.231 | Acc: 92.191% (Correct classifications 29855/Total classifications 32384)
# 253 391 Loss: 0.231 | Acc: 92.194% (Correct classifications 29974/Total classifications 32512)
# 254 391 Loss: 0.231 | Acc: 92.203% (Correct classifications 30095/Total classifications 32640)
# 255 391 Loss: 0.231 | Acc: 92.200% (Correct classifications 30212/Total classifications 32768)
# 256 391 Loss: 0.231 | Acc: 92.194% (Correct classifications 30328/Total classifications 32896)
# 257 391 Loss: 0.231 | Acc: 92.188% (Correct classifications 30444/Total classifications 33024)
# 258 391 Loss: 0.231 | Acc: 92.181% (Correct classifications 30560/Total classifications 33152)
# 259 391 Loss: 0.231 | Acc: 92.178% (Correct classifications 30677/Total classifications 33280)
# 260 391 Loss: 0.231 | Acc: 92.188% (Correct classifications 30798/Total classifications 33408)
# 261 391 Loss: 0.231 | Acc: 92.193% (Correct classifications 30918/Total classifications 33536)
# 262 391 Loss: 0.231 | Acc: 92.196% (Correct classifications 31037/Total classifications 33664)
# 263 391 Loss: 0.231 | Acc: 92.205% (Correct classifications 31158/Total classifications 33792)
# 264 391 Loss: 0.231 | Acc: 92.196% (Correct classifications 31273/Total classifications 33920)
# 265 391 Loss: 0.231 | Acc: 92.190% (Correct classifications 31389/Total classifications 34048)
# 266 391 Loss: 0.231 | Acc: 92.190% (Correct classifications 31507/Total classifications 34176)
# 267 391 Loss: 0.231 | Acc: 92.182% (Correct classifications 31622/Total classifications 34304)
# 268 391 Loss: 0.231 | Acc: 92.199% (Correct classifications 31746/Total classifications 34432)
# 269 391 Loss: 0.231 | Acc: 92.193% (Correct classifications 31862/Total classifications 34560)
# 270 391 Loss: 0.231 | Acc: 92.205% (Correct classifications 31984/Total classifications 34688)
# 271 391 Loss: 0.231 | Acc: 92.205% (Correct classifications 32102/Total classifications 34816)
# 272 391 Loss: 0.231 | Acc: 92.205% (Correct classifications 32220/Total classifications 34944)
# 273 391 Loss: 0.230 | Acc: 92.213% (Correct classifications 32341/Total classifications 35072)
# 274 391 Loss: 0.231 | Acc: 92.205% (Correct classifications 32456/Total classifications 35200)
# 275 391 Loss: 0.231 | Acc: 92.202% (Correct classifications 32573/Total classifications 35328)
# 276 391 Loss: 0.230 | Acc: 92.204% (Correct classifications 32692/Total classifications 35456)
# 277 391 Loss: 0.230 | Acc: 92.199% (Correct classifications 32808/Total classifications 35584)
# 278 391 Loss: 0.231 | Acc: 92.190% (Correct classifications 32923/Total classifications 35712)
# 279 391 Loss: 0.231 | Acc: 92.190% (Correct classifications 33041/Total classifications 35840)
# 280 391 Loss: 0.231 | Acc: 92.188% (Correct classifications 33158/Total classifications 35968)
# 281 391 Loss: 0.231 | Acc: 92.185% (Correct classifications 33275/Total classifications 36096)
# 282 391 Loss: 0.231 | Acc: 92.190% (Correct classifications 33395/Total classifications 36224)
# 283 391 Loss: 0.230 | Acc: 92.199% (Correct classifications 33516/Total classifications 36352)
# 284 391 Loss: 0.230 | Acc: 92.204% (Correct classifications 33636/Total classifications 36480)
# 285 391 Loss: 0.231 | Acc: 92.193% (Correct classifications 33750/Total classifications 36608)
# 286 391 Loss: 0.231 | Acc: 92.190% (Correct classifications 33867/Total classifications 36736)
# 287 391 Loss: 0.231 | Acc: 92.179% (Correct classifications 33981/Total classifications 36864)
# 288 391 Loss: 0.231 | Acc: 92.158% (Correct classifications 34091/Total classifications 36992)
# 289 391 Loss: 0.231 | Acc: 92.166% (Correct classifications 34212/Total classifications 37120)
# 290 391 Loss: 0.231 | Acc: 92.161% (Correct classifications 34328/Total classifications 37248)
# 291 391 Loss: 0.231 | Acc: 92.161% (Correct classifications 34446/Total classifications 37376)
# 292 391 Loss: 0.231 | Acc: 92.156% (Correct classifications 34562/Total classifications 37504)
# 293 391 Loss: 0.231 | Acc: 92.153% (Correct classifications 34679/Total classifications 37632)
# 294 391 Loss: 0.231 | Acc: 92.156% (Correct classifications 34798/Total classifications 37760)
# 295 391 Loss: 0.231 | Acc: 92.151% (Correct classifications 34914/Total classifications 37888)
# 296 391 Loss: 0.231 | Acc: 92.153% (Correct classifications 35033/Total classifications 38016)
# 297 391 Loss: 0.231 | Acc: 92.159% (Correct classifications 35153/Total classifications 38144)
# 298 391 Loss: 0.231 | Acc: 92.156% (Correct classifications 35270/Total classifications 38272)
# 299 391 Loss: 0.231 | Acc: 92.161% (Correct classifications 35390/Total classifications 38400)
# 300 391 Loss: 0.231 | Acc: 92.172% (Correct classifications 35512/Total classifications 38528)
# 301 391 Loss: 0.231 | Acc: 92.172% (Correct classifications 35630/Total classifications 38656)
# 302 391 Loss: 0.231 | Acc: 92.167% (Correct classifications 35746/Total classifications 38784)
# 303 391 Loss: 0.231 | Acc: 92.167% (Correct classifications 35864/Total classifications 38912)
# 304 391 Loss: 0.231 | Acc: 92.175% (Correct classifications 35985/Total classifications 39040)
# 305 391 Loss: 0.231 | Acc: 92.172% (Correct classifications 36102/Total classifications 39168)
# 306 391 Loss: 0.231 | Acc: 92.177% (Correct classifications 36222/Total classifications 39296)
# 307 391 Loss: 0.231 | Acc: 92.175% (Correct classifications 36339/Total classifications 39424)
# 308 391 Loss: 0.232 | Acc: 92.157% (Correct classifications 36450/Total classifications 39552)
# 309 391 Loss: 0.232 | Acc: 92.147% (Correct classifications 36564/Total classifications 39680)
# 310 391 Loss: 0.232 | Acc: 92.162% (Correct classifications 36688/Total classifications 39808)
# 311 391 Loss: 0.232 | Acc: 92.165% (Correct classifications 36807/Total classifications 39936)
# 312 391 Loss: 0.231 | Acc: 92.173% (Correct classifications 36928/Total classifications 40064)
# 313 391 Loss: 0.232 | Acc: 92.145% (Correct classifications 37035/Total classifications 40192)
# 314 391 Loss: 0.232 | Acc: 92.140% (Correct classifications 37151/Total classifications 40320)
# 315 391 Loss: 0.232 | Acc: 92.143% (Correct classifications 37270/Total classifications 40448)
# 316 391 Loss: 0.232 | Acc: 92.146% (Correct classifications 37389/Total classifications 40576)
# 317 391 Loss: 0.232 | Acc: 92.146% (Correct classifications 37507/Total classifications 40704)
# 318 391 Loss: 0.231 | Acc: 92.156% (Correct classifications 37629/Total classifications 40832)
# 319 391 Loss: 0.231 | Acc: 92.153% (Correct classifications 37746/Total classifications 40960)
# 320 391 Loss: 0.231 | Acc: 92.156% (Correct classifications 37865/Total classifications 41088)
# 321 391 Loss: 0.231 | Acc: 92.161% (Correct classifications 37985/Total classifications 41216)
# 322 391 Loss: 0.231 | Acc: 92.166% (Correct classifications 38105/Total classifications 41344)
# 323 391 Loss: 0.232 | Acc: 92.166% (Correct classifications 38223/Total classifications 41472)
# 324 391 Loss: 0.232 | Acc: 92.166% (Correct classifications 38341/Total classifications 41600)
# 325 391 Loss: 0.232 | Acc: 92.164% (Correct classifications 38458/Total classifications 41728)
# 326 391 Loss: 0.232 | Acc: 92.156% (Correct classifications 38573/Total classifications 41856)
# 327 391 Loss: 0.232 | Acc: 92.161% (Correct classifications 38693/Total classifications 41984)
# 328 391 Loss: 0.232 | Acc: 92.157% (Correct classifications 38809/Total classifications 42112)
# 329 391 Loss: 0.232 | Acc: 92.166% (Correct classifications 38931/Total classifications 42240)
# 330 391 Loss: 0.232 | Acc: 92.162% (Correct classifications 39047/Total classifications 42368)
# 331 391 Loss: 0.232 | Acc: 92.157% (Correct classifications 39163/Total classifications 42496)
# 332 391 Loss: 0.232 | Acc: 92.152% (Correct classifications 39279/Total classifications 42624)
# 333 391 Loss: 0.232 | Acc: 92.157% (Correct classifications 39399/Total classifications 42752)
# 334 391 Loss: 0.233 | Acc: 92.143% (Correct classifications 39511/Total classifications 42880)
# 335 391 Loss: 0.233 | Acc: 92.150% (Correct classifications 39632/Total classifications 43008)
# 336 391 Loss: 0.233 | Acc: 92.125% (Correct classifications 39739/Total classifications 43136)
# 337 391 Loss: 0.233 | Acc: 92.132% (Correct classifications 39860/Total classifications 43264)
# 338 391 Loss: 0.232 | Acc: 92.146% (Correct classifications 39984/Total classifications 43392)
# 339 391 Loss: 0.232 | Acc: 92.144% (Correct classifications 40101/Total classifications 43520)
# 340 391 Loss: 0.233 | Acc: 92.139% (Correct classifications 40217/Total classifications 43648)
# 341 391 Loss: 0.233 | Acc: 92.135% (Correct classifications 40333/Total classifications 43776)
# 342 391 Loss: 0.232 | Acc: 92.133% (Correct classifications 40450/Total classifications 43904)
# 343 391 Loss: 0.233 | Acc: 92.122% (Correct classifications 40563/Total classifications 44032)
# 344 391 Loss: 0.233 | Acc: 92.122% (Correct classifications 40681/Total classifications 44160)
# 345 391 Loss: 0.232 | Acc: 92.122% (Correct classifications 40799/Total classifications 44288)
# 346 391 Loss: 0.233 | Acc: 92.118% (Correct classifications 40915/Total classifications 44416)
# 347 391 Loss: 0.232 | Acc: 92.113% (Correct classifications 41031/Total classifications 44544)
# 348 391 Loss: 0.233 | Acc: 92.114% (Correct classifications 41149/Total classifications 44672)
# 349 391 Loss: 0.233 | Acc: 92.105% (Correct classifications 41263/Total classifications 44800)
# 350 391 Loss: 0.233 | Acc: 92.101% (Correct classifications 41379/Total classifications 44928)
# 351 391 Loss: 0.233 | Acc: 92.101% (Correct classifications 41497/Total classifications 45056)
# 352 391 Loss: 0.233 | Acc: 92.101% (Correct classifications 41615/Total classifications 45184)
# 353 391 Loss: 0.233 | Acc: 92.106% (Correct classifications 41735/Total classifications 45312)
# 354 391 Loss: 0.233 | Acc: 92.113% (Correct classifications 41856/Total classifications 45440)
# 355 391 Loss: 0.233 | Acc: 92.117% (Correct classifications 41976/Total classifications 45568)
# 356 391 Loss: 0.233 | Acc: 92.109% (Correct classifications 42090/Total classifications 45696)
# 357 391 Loss: 0.233 | Acc: 92.102% (Correct classifications 42205/Total classifications 45824)
# 358 391 Loss: 0.233 | Acc: 92.096% (Correct classifications 42320/Total classifications 45952)
# 359 391 Loss: 0.233 | Acc: 92.107% (Correct classifications 42443/Total classifications 46080)
# 360 391 Loss: 0.233 | Acc: 92.105% (Correct classifications 42560/Total classifications 46208)
# 361 391 Loss: 0.233 | Acc: 92.112% (Correct classifications 42681/Total classifications 46336)
# 362 391 Loss: 0.233 | Acc: 92.116% (Correct classifications 42801/Total classifications 46464)
# 363 391 Loss: 0.232 | Acc: 92.125% (Correct classifications 42923/Total classifications 46592)
# 364 391 Loss: 0.232 | Acc: 92.123% (Correct classifications 43040/Total classifications 46720)
# 365 391 Loss: 0.233 | Acc: 92.119% (Correct classifications 43156/Total classifications 46848)
# 366 391 Loss: 0.233 | Acc: 92.122% (Correct classifications 43275/Total classifications 46976)
# 367 391 Loss: 0.233 | Acc: 92.117% (Correct classifications 43391/Total classifications 47104)
# 368 391 Loss: 0.233 | Acc: 92.118% (Correct classifications 43509/Total classifications 47232)
# 369 391 Loss: 0.233 | Acc: 92.118% (Correct classifications 43627/Total classifications 47360)
# 370 391 Loss: 0.233 | Acc: 92.118% (Correct classifications 43745/Total classifications 47488)
# 371 391 Loss: 0.232 | Acc: 92.129% (Correct classifications 43868/Total classifications 47616)
# 372 391 Loss: 0.232 | Acc: 92.133% (Correct classifications 43988/Total classifications 47744)
# 373 391 Loss: 0.232 | Acc: 92.129% (Correct classifications 44104/Total classifications 47872)
# 374 391 Loss: 0.232 | Acc: 92.129% (Correct classifications 44222/Total classifications 48000)
# 375 391 Loss: 0.232 | Acc: 92.131% (Correct classifications 44341/Total classifications 48128)
# 376 391 Loss: 0.232 | Acc: 92.127% (Correct classifications 44457/Total classifications 48256)
# 377 391 Loss: 0.233 | Acc: 92.128% (Correct classifications 44575/Total classifications 48384)
# 378 391 Loss: 0.233 | Acc: 92.119% (Correct classifications 44689/Total classifications 48512)
# 379 391 Loss: 0.232 | Acc: 92.118% (Correct classifications 44806/Total classifications 48640)
# 380 391 Loss: 0.232 | Acc: 92.124% (Correct classifications 44927/Total classifications 48768)
# 381 391 Loss: 0.232 | Acc: 92.124% (Correct classifications 45045/Total classifications 48896)
# 382 391 Loss: 0.232 | Acc: 92.132% (Correct classifications 45167/Total classifications 49024)
# 383 391 Loss: 0.232 | Acc: 92.137% (Correct classifications 45287/Total classifications 49152)
# 384 391 Loss: 0.232 | Acc: 92.129% (Correct classifications 45401/Total classifications 49280)
# 385 391 Loss: 0.232 | Acc: 92.133% (Correct classifications 45521/Total classifications 49408)
# 386 391 Loss: 0.232 | Acc: 92.133% (Correct classifications 45639/Total classifications 49536)
# 387 391 Loss: 0.232 | Acc: 92.135% (Correct classifications 45758/Total classifications 49664)
# 388 391 Loss: 0.231 | Acc: 92.139% (Correct classifications 45878/Total classifications 49792)
# 389 391 Loss: 0.231 | Acc: 92.139% (Correct classifications 45996/Total classifications 49920)
# 390 391 Loss: 0.231 | Acc: 92.138% (Correct classifications 46069/Total classifications 50000)
# Train Loss: 0.269 | Acc: 90.512%
# Test Loss: 0.479 | Acc: 84.620%
#
#
# Batch Size 128 (142.00s)
#
# Epoch: 49/60 | Current Learning Rate: 0.0100
# 0 391 Loss: 0.244 | Acc: 89.062% (Correct classifications 114/Total classifications 128)
# 1 391 Loss: 0.210 | Acc: 91.797% (Correct classifications 235/Total classifications 256)
# 2 391 Loss: 0.230 | Acc: 90.885% (Correct classifications 349/Total classifications 384)
# 3 391 Loss: 0.243 | Acc: 90.039% (Correct classifications 461/Total classifications 512)
# 4 391 Loss: 0.252 | Acc: 90.000% (Correct classifications 576/Total classifications 640)
# 5 391 Loss: 0.241 | Acc: 90.495% (Correct classifications 695/Total classifications 768)
# 6 391 Loss: 0.253 | Acc: 90.402% (Correct classifications 810/Total classifications 896)
# 7 391 Loss: 0.273 | Acc: 89.648% (Correct classifications 918/Total classifications 1024)
# 8 391 Loss: 0.281 | Acc: 89.497% (Correct classifications 1031/Total classifications 1152)
# 9 391 Loss: 0.290 | Acc: 89.141% (Correct classifications 1141/Total classifications 1280)
# 10 391 Loss: 0.287 | Acc: 88.991% (Correct classifications 1253/Total classifications 1408)
# 11 391 Loss: 0.294 | Acc: 88.867% (Correct classifications 1365/Total classifications 1536)
# 12 391 Loss: 0.297 | Acc: 88.762% (Correct classifications 1477/Total classifications 1664)
# 13 391 Loss: 0.300 | Acc: 88.560% (Correct classifications 1587/Total classifications 1792)
# 14 391 Loss: 0.305 | Acc: 88.698% (Correct classifications 1703/Total classifications 1920)
# 15 391 Loss: 0.300 | Acc: 88.867% (Correct classifications 1820/Total classifications 2048)
# 16 391 Loss: 0.292 | Acc: 89.154% (Correct classifications 1940/Total classifications 2176)
# 17 391 Loss: 0.296 | Acc: 88.976% (Correct classifications 2050/Total classifications 2304)
# 18 391 Loss: 0.296 | Acc: 89.021% (Correct classifications 2165/Total classifications 2432)
# 19 391 Loss: 0.305 | Acc: 88.789% (Correct classifications 2273/Total classifications 2560)
# 20 391 Loss: 0.309 | Acc: 88.728% (Correct classifications 2385/Total classifications 2688)
# 21 391 Loss: 0.304 | Acc: 88.991% (Correct classifications 2506/Total classifications 2816)
# 22 391 Loss: 0.304 | Acc: 88.961% (Correct classifications 2619/Total classifications 2944)
# 23 391 Loss: 0.304 | Acc: 88.965% (Correct classifications 2733/Total classifications 3072)
# 24 391 Loss: 0.299 | Acc: 89.094% (Correct classifications 2851/Total classifications 3200)
# 25 391 Loss: 0.299 | Acc: 89.032% (Correct classifications 2963/Total classifications 3328)
# 26 391 Loss: 0.300 | Acc: 89.091% (Correct classifications 3079/Total classifications 3456)
# 27 391 Loss: 0.298 | Acc: 89.174% (Correct classifications 3196/Total classifications 3584)
# 28 391 Loss: 0.295 | Acc: 89.305% (Correct classifications 3315/Total classifications 3712)
# 29 391 Loss: 0.293 | Acc: 89.323% (Correct classifications 3430/Total classifications 3840)
# 30 391 Loss: 0.297 | Acc: 89.189% (Correct classifications 3539/Total classifications 3968)
# 31 391 Loss: 0.295 | Acc: 89.233% (Correct classifications 3655/Total classifications 4096)
# 32 391 Loss: 0.295 | Acc: 89.323% (Correct classifications 3773/Total classifications 4224)
# 33 391 Loss: 0.290 | Acc: 89.568% (Correct classifications 3898/Total classifications 4352)
# 34 391 Loss: 0.291 | Acc: 89.576% (Correct classifications 4013/Total classifications 4480)
# 35 391 Loss: 0.288 | Acc: 89.692% (Correct classifications 4133/Total classifications 4608)
# 36 391 Loss: 0.286 | Acc: 89.780% (Correct classifications 4252/Total classifications 4736)
# 37 391 Loss: 0.285 | Acc: 89.823% (Correct classifications 4369/Total classifications 4864)
# 38 391 Loss: 0.284 | Acc: 89.844% (Correct classifications 4485/Total classifications 4992)
# 39 391 Loss: 0.284 | Acc: 89.785% (Correct classifications 4597/Total classifications 5120)
# 40 391 Loss: 0.284 | Acc: 89.806% (Correct classifications 4713/Total classifications 5248)
# 41 391 Loss: 0.282 | Acc: 89.900% (Correct classifications 4833/Total classifications 5376)
# 42 391 Loss: 0.281 | Acc: 89.935% (Correct classifications 4950/Total classifications 5504)
# 43 391 Loss: 0.280 | Acc: 89.950% (Correct classifications 5066/Total classifications 5632)
# 44 391 Loss: 0.282 | Acc: 89.896% (Correct classifications 5178/Total classifications 5760)
# 45 391 Loss: 0.284 | Acc: 89.895% (Correct classifications 5293/Total classifications 5888)
# 46 391 Loss: 0.284 | Acc: 89.794% (Correct classifications 5402/Total classifications 6016)
# 47 391 Loss: 0.283 | Acc: 89.844% (Correct classifications 5520/Total classifications 6144)
# 48 391 Loss: 0.284 | Acc: 89.748% (Correct classifications 5629/Total classifications 6272)
# 49 391 Loss: 0.281 | Acc: 89.875% (Correct classifications 5752/Total classifications 6400)
# 50 391 Loss: 0.280 | Acc: 89.890% (Correct classifications 5868/Total classifications 6528)
# 51 391 Loss: 0.279 | Acc: 89.964% (Correct classifications 5988/Total classifications 6656)
# 52 391 Loss: 0.280 | Acc: 89.917% (Correct classifications 6100/Total classifications 6784)
# 53 391 Loss: 0.279 | Acc: 89.916% (Correct classifications 6215/Total classifications 6912)
# 54 391 Loss: 0.281 | Acc: 89.872% (Correct classifications 6327/Total classifications 7040)
# 55 391 Loss: 0.280 | Acc: 89.872% (Correct classifications 6442/Total classifications 7168)
# 56 391 Loss: 0.280 | Acc: 89.899% (Correct classifications 6559/Total classifications 7296)
# 57 391 Loss: 0.280 | Acc: 89.871% (Correct classifications 6672/Total classifications 7424)
# 58 391 Loss: 0.280 | Acc: 89.870% (Correct classifications 6787/Total classifications 7552)
# 59 391 Loss: 0.280 | Acc: 89.831% (Correct classifications 6899/Total classifications 7680)
# 60 391 Loss: 0.280 | Acc: 89.818% (Correct classifications 7013/Total classifications 7808)
# 61 391 Loss: 0.279 | Acc: 89.869% (Correct classifications 7132/Total classifications 7936)
# 62 391 Loss: 0.279 | Acc: 89.856% (Correct classifications 7246/Total classifications 8064)
# 63 391 Loss: 0.279 | Acc: 89.807% (Correct classifications 7357/Total classifications 8192)
# 64 391 Loss: 0.279 | Acc: 89.760% (Correct classifications 7468/Total classifications 8320)
# 65 391 Loss: 0.279 | Acc: 89.773% (Correct classifications 7584/Total classifications 8448)
# 66 391 Loss: 0.278 | Acc: 89.785% (Correct classifications 7700/Total classifications 8576)
# 67 391 Loss: 0.278 | Acc: 89.775% (Correct classifications 7814/Total classifications 8704)
# 68 391 Loss: 0.278 | Acc: 89.787% (Correct classifications 7930/Total classifications 8832)
# 69 391 Loss: 0.278 | Acc: 89.766% (Correct classifications 8043/Total classifications 8960)
# 70 391 Loss: 0.277 | Acc: 89.767% (Correct classifications 8158/Total classifications 9088)
# 71 391 Loss: 0.277 | Acc: 89.768% (Correct classifications 8273/Total classifications 9216)
# 72 391 Loss: 0.277 | Acc: 89.780% (Correct classifications 8389/Total classifications 9344)
# 73 391 Loss: 0.277 | Acc: 89.823% (Correct classifications 8508/Total classifications 9472)
# 74 391 Loss: 0.278 | Acc: 89.802% (Correct classifications 8621/Total classifications 9600)
# 75 391 Loss: 0.279 | Acc: 89.751% (Correct classifications 8731/Total classifications 9728)
# 76 391 Loss: 0.278 | Acc: 89.783% (Correct classifications 8849/Total classifications 9856)
# 77 391 Loss: 0.276 | Acc: 89.854% (Correct classifications 8971/Total classifications 9984)
# 78 391 Loss: 0.274 | Acc: 89.933% (Correct classifications 9094/Total classifications 10112)
# 79 391 Loss: 0.274 | Acc: 89.951% (Correct classifications 9211/Total classifications 10240)
# 80 391 Loss: 0.273 | Acc: 89.988% (Correct classifications 9330/Total classifications 10368)
# 81 391 Loss: 0.273 | Acc: 89.977% (Correct classifications 9444/Total classifications 10496)
# 82 391 Loss: 0.273 | Acc: 89.966% (Correct classifications 9558/Total classifications 10624)
# 83 391 Loss: 0.273 | Acc: 89.927% (Correct classifications 9669/Total classifications 10752)
# 84 391 Loss: 0.273 | Acc: 89.954% (Correct classifications 9787/Total classifications 10880)
# 85 391 Loss: 0.274 | Acc: 89.962% (Correct classifications 9903/Total classifications 11008)
# 86 391 Loss: 0.274 | Acc: 89.952% (Correct classifications 10017/Total classifications 11136)
# 87 391 Loss: 0.275 | Acc: 89.924% (Correct classifications 10129/Total classifications 11264)
# 88 391 Loss: 0.275 | Acc: 89.949% (Correct classifications 10247/Total classifications 11392)
# 89 391 Loss: 0.276 | Acc: 89.931% (Correct classifications 10360/Total classifications 11520)
# 90 391 Loss: 0.276 | Acc: 89.912% (Correct classifications 10473/Total classifications 11648)
# 91 391 Loss: 0.275 | Acc: 89.963% (Correct classifications 10594/Total classifications 11776)
# 92 391 Loss: 0.274 | Acc: 89.978% (Correct classifications 10711/Total classifications 11904)
# 93 391 Loss: 0.275 | Acc: 89.968% (Correct classifications 10825/Total classifications 12032)
# 94 391 Loss: 0.275 | Acc: 89.975% (Correct classifications 10941/Total classifications 12160)
# 95 391 Loss: 0.275 | Acc: 89.966% (Correct classifications 11055/Total classifications 12288)
# 96 391 Loss: 0.275 | Acc: 89.981% (Correct classifications 11172/Total classifications 12416)
# 97 391 Loss: 0.275 | Acc: 89.955% (Correct classifications 11284/Total classifications 12544)
# 98 391 Loss: 0.277 | Acc: 89.875% (Correct classifications 11389/Total classifications 12672)
# 99 391 Loss: 0.278 | Acc: 89.844% (Correct classifications 11500/Total classifications 12800)
# 100 391 Loss: 0.278 | Acc: 89.851% (Correct classifications 11616/Total classifications 12928)
# 101 391 Loss: 0.278 | Acc: 89.897% (Correct classifications 11737/Total classifications 13056)
# 102 391 Loss: 0.278 | Acc: 89.889% (Correct classifications 11851/Total classifications 13184)
# 103 391 Loss: 0.277 | Acc: 89.911% (Correct classifications 11969/Total classifications 13312)
# 104 391 Loss: 0.279 | Acc: 89.888% (Correct classifications 12081/Total classifications 13440)
# 105 391 Loss: 0.279 | Acc: 89.888% (Correct classifications 12196/Total classifications 13568)
# 106 391 Loss: 0.279 | Acc: 89.902% (Correct classifications 12313/Total classifications 13696)
# 107 391 Loss: 0.280 | Acc: 89.880% (Correct classifications 12425/Total classifications 13824)
# 108 391 Loss: 0.279 | Acc: 89.915% (Correct classifications 12545/Total classifications 13952)
# 109 391 Loss: 0.279 | Acc: 89.922% (Correct classifications 12661/Total classifications 14080)
# 110 391 Loss: 0.278 | Acc: 89.956% (Correct classifications 12781/Total classifications 14208)
# 111 391 Loss: 0.277 | Acc: 89.962% (Correct classifications 12897/Total classifications 14336)
# 112 391 Loss: 0.278 | Acc: 89.947% (Correct classifications 13010/Total classifications 14464)
# 113 391 Loss: 0.277 | Acc: 89.988% (Correct classifications 13131/Total classifications 14592)
# 114 391 Loss: 0.277 | Acc: 89.993% (Correct classifications 13247/Total classifications 14720)
# 115 391 Loss: 0.276 | Acc: 90.012% (Correct classifications 13365/Total classifications 14848)
# 116 391 Loss: 0.276 | Acc: 89.997% (Correct classifications 13478/Total classifications 14976)
# 117 391 Loss: 0.276 | Acc: 90.016% (Correct classifications 13596/Total classifications 15104)
# 118 391 Loss: 0.275 | Acc: 90.047% (Correct classifications 13716/Total classifications 15232)
# 119 391 Loss: 0.276 | Acc: 90.046% (Correct classifications 13831/Total classifications 15360)
# 120 391 Loss: 0.276 | Acc: 90.057% (Correct classifications 13948/Total classifications 15488)
# 121 391 Loss: 0.276 | Acc: 90.049% (Correct classifications 14062/Total classifications 15616)
# 122 391 Loss: 0.275 | Acc: 90.079% (Correct classifications 14182/Total classifications 15744)
# 123 391 Loss: 0.275 | Acc: 90.083% (Correct classifications 14298/Total classifications 15872)
# 124 391 Loss: 0.275 | Acc: 90.062% (Correct classifications 14410/Total classifications 16000)
# 125 391 Loss: 0.276 | Acc: 90.048% (Correct classifications 14523/Total classifications 16128)
# 126 391 Loss: 0.275 | Acc: 90.078% (Correct classifications 14643/Total classifications 16256)
# 127 391 Loss: 0.275 | Acc: 90.070% (Correct classifications 14757/Total classifications 16384)
# 128 391 Loss: 0.276 | Acc: 90.062% (Correct classifications 14871/Total classifications 16512)
# 129 391 Loss: 0.276 | Acc: 90.054% (Correct classifications 14985/Total classifications 16640)
# 130 391 Loss: 0.276 | Acc: 90.047% (Correct classifications 15099/Total classifications 16768)
# 131 391 Loss: 0.276 | Acc: 90.009% (Correct classifications 15208/Total classifications 16896)
# 132 391 Loss: 0.276 | Acc: 89.991% (Correct classifications 15320/Total classifications 17024)
# 133 391 Loss: 0.276 | Acc: 89.990% (Correct classifications 15435/Total classifications 17152)
# 134 391 Loss: 0.275 | Acc: 90.012% (Correct classifications 15554/Total classifications 17280)
# 135 391 Loss: 0.276 | Acc: 90.005% (Correct classifications 15668/Total classifications 17408)
# 136 391 Loss: 0.276 | Acc: 89.975% (Correct classifications 15778/Total classifications 17536)
# 137 391 Loss: 0.276 | Acc: 89.951% (Correct classifications 15889/Total classifications 17664)
# 138 391 Loss: 0.277 | Acc: 89.951% (Correct classifications 16004/Total classifications 17792)
# 139 391 Loss: 0.277 | Acc: 89.967% (Correct classifications 16122/Total classifications 17920)
# 140 391 Loss: 0.277 | Acc: 89.943% (Correct classifications 16233/Total classifications 18048)
# 141 391 Loss: 0.277 | Acc: 89.954% (Correct classifications 16350/Total classifications 18176)
# 142 391 Loss: 0.276 | Acc: 89.969% (Correct classifications 16468/Total classifications 18304)
# 143 391 Loss: 0.276 | Acc: 89.979% (Correct classifications 16585/Total classifications 18432)
# 144 391 Loss: 0.276 | Acc: 89.973% (Correct classifications 16699/Total classifications 18560)
# 145 391 Loss: 0.277 | Acc: 89.924% (Correct classifications 16805/Total classifications 18688)
# 146 391 Loss: 0.277 | Acc: 89.934% (Correct classifications 16922/Total classifications 18816)
# 147 391 Loss: 0.276 | Acc: 89.976% (Correct classifications 17045/Total classifications 18944)
# 148 391 Loss: 0.276 | Acc: 89.970% (Correct classifications 17159/Total classifications 19072)
# 149 391 Loss: 0.275 | Acc: 89.974% (Correct classifications 17275/Total classifications 19200)
# 150 391 Loss: 0.275 | Acc: 89.973% (Correct classifications 17390/Total classifications 19328)
# 151 391 Loss: 0.275 | Acc: 89.988% (Correct classifications 17508/Total classifications 19456)
# 152 391 Loss: 0.275 | Acc: 89.992% (Correct classifications 17624/Total classifications 19584)
# 153 391 Loss: 0.275 | Acc: 90.001% (Correct classifications 17741/Total classifications 19712)
# 154 391 Loss: 0.274 | Acc: 90.020% (Correct classifications 17860/Total classifications 19840)
# 155 391 Loss: 0.275 | Acc: 90.009% (Correct classifications 17973/Total classifications 19968)
# 156 391 Loss: 0.275 | Acc: 89.993% (Correct classifications 18085/Total classifications 20096)
# 157 391 Loss: 0.275 | Acc: 90.007% (Correct classifications 18203/Total classifications 20224)
# 158 391 Loss: 0.275 | Acc: 90.016% (Correct classifications 18320/Total classifications 20352)
# 159 391 Loss: 0.275 | Acc: 90.020% (Correct classifications 18436/Total classifications 20480)
# 160 391 Loss: 0.275 | Acc: 90.023% (Correct classifications 18552/Total classifications 20608)
# 161 391 Loss: 0.275 | Acc: 90.022% (Correct classifications 18667/Total classifications 20736)
# 162 391 Loss: 0.275 | Acc: 90.012% (Correct classifications 18780/Total classifications 20864)
# 163 391 Loss: 0.275 | Acc: 90.001% (Correct classifications 18893/Total classifications 20992)
# 164 391 Loss: 0.275 | Acc: 90.019% (Correct classifications 19012/Total classifications 21120)
# 165 391 Loss: 0.276 | Acc: 89.999% (Correct classifications 19123/Total classifications 21248)
# 166 391 Loss: 0.276 | Acc: 89.984% (Correct classifications 19235/Total classifications 21376)
# 167 391 Loss: 0.276 | Acc: 89.983% (Correct classifications 19350/Total classifications 21504)
# 168 391 Loss: 0.276 | Acc: 89.945% (Correct classifications 19457/Total classifications 21632)
# 169 391 Loss: 0.277 | Acc: 89.945% (Correct classifications 19572/Total classifications 21760)
# 170 391 Loss: 0.276 | Acc: 89.963% (Correct classifications 19691/Total classifications 21888)
# 171 391 Loss: 0.276 | Acc: 89.962% (Correct classifications 19806/Total classifications 22016)
# 172 391 Loss: 0.276 | Acc: 89.957% (Correct classifications 19920/Total classifications 22144)
# 173 391 Loss: 0.276 | Acc: 89.943% (Correct classifications 20032/Total classifications 22272)
# 174 391 Loss: 0.276 | Acc: 89.951% (Correct classifications 20149/Total classifications 22400)
# 175 391 Loss: 0.276 | Acc: 89.964% (Correct classifications 20267/Total classifications 22528)
# 176 391 Loss: 0.276 | Acc: 89.989% (Correct classifications 20388/Total classifications 22656)
# 177 391 Loss: 0.275 | Acc: 90.006% (Correct classifications 20507/Total classifications 22784)
# 178 391 Loss: 0.276 | Acc: 89.983% (Correct classifications 20617/Total classifications 22912)
# 179 391 Loss: 0.276 | Acc: 89.970% (Correct classifications 20729/Total classifications 23040)
# 180 391 Loss: 0.277 | Acc: 89.947% (Correct classifications 20839/Total classifications 23168)
# 181 391 Loss: 0.277 | Acc: 89.947% (Correct classifications 20954/Total classifications 23296)
# 182 391 Loss: 0.277 | Acc: 89.950% (Correct classifications 21070/Total classifications 23424)
# 183 391 Loss: 0.276 | Acc: 89.967% (Correct classifications 21189/Total classifications 23552)
# 184 391 Loss: 0.277 | Acc: 89.949% (Correct classifications 21300/Total classifications 23680)
# 185 391 Loss: 0.277 | Acc: 89.953% (Correct classifications 21416/Total classifications 23808)
# 186 391 Loss: 0.277 | Acc: 89.952% (Correct classifications 21531/Total classifications 23936)
# 187 391 Loss: 0.277 | Acc: 89.981% (Correct classifications 21653/Total classifications 24064)
# 188 391 Loss: 0.277 | Acc: 89.980% (Correct classifications 21768/Total classifications 24192)
# 189 391 Loss: 0.276 | Acc: 90.004% (Correct classifications 21889/Total classifications 24320)
# 190 391 Loss: 0.276 | Acc: 90.032% (Correct classifications 22011/Total classifications 24448)
# 191 391 Loss: 0.275 | Acc: 90.039% (Correct classifications 22128/Total classifications 24576)
# 192 391 Loss: 0.275 | Acc: 90.030% (Correct classifications 22241/Total classifications 24704)
# 193 391 Loss: 0.275 | Acc: 90.029% (Correct classifications 22356/Total classifications 24832)
# 194 391 Loss: 0.275 | Acc: 90.020% (Correct classifications 22469/Total classifications 24960)
# 195 391 Loss: 0.275 | Acc: 90.039% (Correct classifications 22589/Total classifications 25088)
# 196 391 Loss: 0.275 | Acc: 90.054% (Correct classifications 22708/Total classifications 25216)
# 197 391 Loss: 0.275 | Acc: 90.045% (Correct classifications 22821/Total classifications 25344)
# 198 391 Loss: 0.275 | Acc: 90.024% (Correct classifications 22931/Total classifications 25472)
# 199 391 Loss: 0.275 | Acc: 90.043% (Correct classifications 23051/Total classifications 25600)
# 200 391 Loss: 0.275 | Acc: 90.046% (Correct classifications 23167/Total classifications 25728)
# 201 391 Loss: 0.275 | Acc: 90.049% (Correct classifications 23283/Total classifications 25856)
# 202 391 Loss: 0.275 | Acc: 90.025% (Correct classifications 23392/Total classifications 25984)
# 203 391 Loss: 0.275 | Acc: 90.035% (Correct classifications 23510/Total classifications 26112)
# 204 391 Loss: 0.275 | Acc: 90.050% (Correct classifications 23629/Total classifications 26240)
# 205 391 Loss: 0.275 | Acc: 90.056% (Correct classifications 23746/Total classifications 26368)
# 206 391 Loss: 0.275 | Acc: 90.032% (Correct classifications 23855/Total classifications 26496)
# 207 391 Loss: 0.275 | Acc: 90.032% (Correct classifications 23970/Total classifications 26624)
# 208 391 Loss: 0.275 | Acc: 90.027% (Correct classifications 24084/Total classifications 26752)
# 209 391 Loss: 0.275 | Acc: 90.048% (Correct classifications 24205/Total classifications 26880)
# 210 391 Loss: 0.275 | Acc: 90.047% (Correct classifications 24320/Total classifications 27008)
# 211 391 Loss: 0.275 | Acc: 90.046% (Correct classifications 24435/Total classifications 27136)
# 212 391 Loss: 0.275 | Acc: 90.020% (Correct classifications 24543/Total classifications 27264)
# 213 391 Loss: 0.275 | Acc: 90.026% (Correct classifications 24660/Total classifications 27392)
# 214 391 Loss: 0.275 | Acc: 90.000% (Correct classifications 24768/Total classifications 27520)
# 215 391 Loss: 0.275 | Acc: 90.010% (Correct classifications 24886/Total classifications 27648)
# 216 391 Loss: 0.275 | Acc: 90.020% (Correct classifications 25004/Total classifications 27776)
# 217 391 Loss: 0.275 | Acc: 90.016% (Correct classifications 25118/Total classifications 27904)
# 218 391 Loss: 0.275 | Acc: 90.008% (Correct classifications 25231/Total classifications 28032)
# 219 391 Loss: 0.275 | Acc: 89.975% (Correct classifications 25337/Total classifications 28160)
# 220 391 Loss: 0.276 | Acc: 89.953% (Correct classifications 25446/Total classifications 28288)
# 221 391 Loss: 0.276 | Acc: 89.960% (Correct classifications 25563/Total classifications 28416)
# 222 391 Loss: 0.276 | Acc: 89.963% (Correct classifications 25679/Total classifications 28544)
# 223 391 Loss: 0.276 | Acc: 89.969% (Correct classifications 25796/Total classifications 28672)
# 224 391 Loss: 0.276 | Acc: 89.965% (Correct classifications 25910/Total classifications 28800)
# 225 391 Loss: 0.276 | Acc: 89.968% (Correct classifications 26026/Total classifications 28928)
# 226 391 Loss: 0.276 | Acc: 89.968% (Correct classifications 26141/Total classifications 29056)
# 227 391 Loss: 0.276 | Acc: 89.984% (Correct classifications 26261/Total classifications 29184)
# 228 391 Loss: 0.276 | Acc: 89.990% (Correct classifications 26378/Total classifications 29312)
# 229 391 Loss: 0.276 | Acc: 89.990% (Correct classifications 26493/Total classifications 29440)
# 230 391 Loss: 0.276 | Acc: 90.003% (Correct classifications 26612/Total classifications 29568)
# 231 391 Loss: 0.276 | Acc: 90.009% (Correct classifications 26729/Total classifications 29696)
# 232 391 Loss: 0.276 | Acc: 90.018% (Correct classifications 26847/Total classifications 29824)
# 233 391 Loss: 0.275 | Acc: 90.031% (Correct classifications 26966/Total classifications 29952)
# 234 391 Loss: 0.275 | Acc: 90.037% (Correct classifications 27083/Total classifications 30080)
# 235 391 Loss: 0.275 | Acc: 90.046% (Correct classifications 27201/Total classifications 30208)
# 236 391 Loss: 0.275 | Acc: 90.058% (Correct classifications 27320/Total classifications 30336)
# 237 391 Loss: 0.275 | Acc: 90.051% (Correct classifications 27433/Total classifications 30464)
# 238 391 Loss: 0.276 | Acc: 90.056% (Correct classifications 27550/Total classifications 30592)
# 239 391 Loss: 0.276 | Acc: 90.049% (Correct classifications 27663/Total classifications 30720)
# 240 391 Loss: 0.275 | Acc: 90.061% (Correct classifications 27782/Total classifications 30848)
# 241 391 Loss: 0.276 | Acc: 90.050% (Correct classifications 27894/Total classifications 30976)
# 242 391 Loss: 0.276 | Acc: 90.040% (Correct classifications 28006/Total classifications 31104)
# 243 391 Loss: 0.276 | Acc: 90.052% (Correct classifications 28125/Total classifications 31232)
# 244 391 Loss: 0.276 | Acc: 90.051% (Correct classifications 28240/Total classifications 31360)
# 245 391 Loss: 0.276 | Acc: 90.057% (Correct classifications 28357/Total classifications 31488)
# 246 391 Loss: 0.276 | Acc: 90.049% (Correct classifications 28470/Total classifications 31616)
# 247 391 Loss: 0.276 | Acc: 90.045% (Correct classifications 28584/Total classifications 31744)
# 248 391 Loss: 0.276 | Acc: 90.051% (Correct classifications 28701/Total classifications 31872)
# 249 391 Loss: 0.276 | Acc: 90.050% (Correct classifications 28816/Total classifications 32000)
# 250 391 Loss: 0.276 | Acc: 90.046% (Correct classifications 28930/Total classifications 32128)
# 251 391 Loss: 0.276 | Acc: 90.039% (Correct classifications 29043/Total classifications 32256)
# 252 391 Loss: 0.276 | Acc: 90.060% (Correct classifications 29165/Total classifications 32384)
# 253 391 Loss: 0.275 | Acc: 90.081% (Correct classifications 29287/Total classifications 32512)
# 254 391 Loss: 0.275 | Acc: 90.067% (Correct classifications 29398/Total classifications 32640)
# 255 391 Loss: 0.275 | Acc: 90.082% (Correct classifications 29518/Total classifications 32768)
# 256 391 Loss: 0.275 | Acc: 90.078% (Correct classifications 29632/Total classifications 32896)
# 257 391 Loss: 0.275 | Acc: 90.068% (Correct classifications 29744/Total classifications 33024)
# 258 391 Loss: 0.275 | Acc: 90.085% (Correct classifications 29865/Total classifications 33152)
# 259 391 Loss: 0.275 | Acc: 90.087% (Correct classifications 29981/Total classifications 33280)
# 260 391 Loss: 0.275 | Acc: 90.101% (Correct classifications 30101/Total classifications 33408)
# 261 391 Loss: 0.275 | Acc: 90.109% (Correct classifications 30219/Total classifications 33536)
# 262 391 Loss: 0.275 | Acc: 90.105% (Correct classifications 30333/Total classifications 33664)
# 263 391 Loss: 0.275 | Acc: 90.113% (Correct classifications 30451/Total classifications 33792)
# 264 391 Loss: 0.275 | Acc: 90.103% (Correct classifications 30563/Total classifications 33920)
# 265 391 Loss: 0.275 | Acc: 90.108% (Correct classifications 30680/Total classifications 34048)
# 266 391 Loss: 0.275 | Acc: 90.104% (Correct classifications 30794/Total classifications 34176)
# 267 391 Loss: 0.275 | Acc: 90.109% (Correct classifications 30911/Total classifications 34304)
# 268 391 Loss: 0.275 | Acc: 90.105% (Correct classifications 31025/Total classifications 34432)
# 269 391 Loss: 0.274 | Acc: 90.119% (Correct classifications 31145/Total classifications 34560)
# 270 391 Loss: 0.274 | Acc: 90.112% (Correct classifications 31258/Total classifications 34688)
# 271 391 Loss: 0.274 | Acc: 90.105% (Correct classifications 31371/Total classifications 34816)
# 272 391 Loss: 0.274 | Acc: 90.107% (Correct classifications 31487/Total classifications 34944)
# 273 391 Loss: 0.275 | Acc: 90.095% (Correct classifications 31598/Total classifications 35072)
# 274 391 Loss: 0.275 | Acc: 90.088% (Correct classifications 31711/Total classifications 35200)
# 275 391 Loss: 0.275 | Acc: 90.065% (Correct classifications 31818/Total classifications 35328)
# 276 391 Loss: 0.275 | Acc: 90.067% (Correct classifications 31934/Total classifications 35456)
# 277 391 Loss: 0.275 | Acc: 90.071% (Correct classifications 32051/Total classifications 35584)
# 278 391 Loss: 0.275 | Acc: 90.065% (Correct classifications 32164/Total classifications 35712)
# 279 391 Loss: 0.275 | Acc: 90.078% (Correct classifications 32284/Total classifications 35840)
# 280 391 Loss: 0.276 | Acc: 90.072% (Correct classifications 32397/Total classifications 35968)
# 281 391 Loss: 0.276 | Acc: 90.076% (Correct classifications 32514/Total classifications 36096)
# 282 391 Loss: 0.276 | Acc: 90.078% (Correct classifications 32630/Total classifications 36224)
# 283 391 Loss: 0.275 | Acc: 90.086% (Correct classifications 32748/Total classifications 36352)
# 284 391 Loss: 0.275 | Acc: 90.099% (Correct classifications 32868/Total classifications 36480)
# 285 391 Loss: 0.275 | Acc: 90.095% (Correct classifications 32982/Total classifications 36608)
# 286 391 Loss: 0.275 | Acc: 90.105% (Correct classifications 33101/Total classifications 36736)
# 287 391 Loss: 0.275 | Acc: 90.099% (Correct classifications 33214/Total classifications 36864)
# 288 391 Loss: 0.275 | Acc: 90.114% (Correct classifications 33335/Total classifications 36992)
# ...
# 224 391 Loss: 0.233 | Acc: 91.903% (Correct classifications 26468/Total classifications 28800)
# 225 391 Loss: 0.233 | Acc: 91.904% (Correct classifications 26586/Total classifications 28928)
# 226 391 Loss: 0.233 | Acc: 91.909% (Correct classifications 26705/Total classifications 29056)
# 227 391 Loss: 0.233 | Acc: 91.907% (Correct classifications 26822/Total classifications 29184)
# 228 391 Loss: 0.233 | Acc: 91.908% (Correct classifications 26940/Total classifications 29312)
# 229 391 Loss: 0.234 | Acc: 91.882% (Correct classifications 27050/Total classifications 29440)
# 230 391 Loss: 0.233 | Acc: 91.893% (Correct classifications 27171/Total classifications 29568)
# 231 391 Loss: 0.234 | Acc: 91.881% (Correct classifications 27285/Total classifications 29696)
# 232 391 Loss: 0.234 | Acc: 91.856% (Correct classifications 27395/Total classifications 29824)
# 233 391 Loss: 0.234 | Acc: 91.840% (Correct classifications 27508/Total classifications 29952)
# 234 391 Loss: 0.235 | Acc: 91.832% (Correct classifications 27623/Total classifications 30080)
# 235 391 Loss: 0.235 | Acc: 91.820% (Correct classifications 27737/Total classifications 30208)
# 236 391 Loss: 0.235 | Acc: 91.815% (Correct classifications 27853/Total classifications 30336)
# 237 391 Loss: 0.235 | Acc: 91.813% (Correct classifications 27970/Total classifications 30464)
# 238 391 Loss: 0.235 | Acc: 91.815% (Correct classifications 28088/Total classifications 30592)
# 239 391 Loss: 0.235 | Acc: 91.826% (Correct classifications 28209/Total classifications 30720)
# 240 391 Loss: 0.235 | Acc: 91.834% (Correct classifications 28329/Total classifications 30848)
# 241 391 Loss: 0.235 | Acc: 91.836% (Correct classifications 28447/Total classifications 30976)
# 242 391 Loss: 0.235 | Acc: 91.831% (Correct classifications 28563/Total classifications 31104)
# 243 391 Loss: 0.235 | Acc: 91.832% (Correct classifications 28681/Total classifications 31232)
# 244 391 Loss: 0.235 | Acc: 91.824% (Correct classifications 28796/Total classifications 31360)
# 245 391 Loss: 0.235 | Acc: 91.838% (Correct classifications 28918/Total classifications 31488)
# 246 391 Loss: 0.235 | Acc: 91.849% (Correct classifications 29039/Total classifications 31616)
# 247 391 Loss: 0.234 | Acc: 91.857% (Correct classifications 29159/Total classifications 31744)
# 248 391 Loss: 0.234 | Acc: 91.864% (Correct classifications 29279/Total classifications 31872)
# 249 391 Loss: 0.234 | Acc: 91.862% (Correct classifications 29396/Total classifications 32000)
# 250 391 Loss: 0.234 | Acc: 91.861% (Correct classifications 29513/Total classifications 32128)
# 251 391 Loss: 0.235 | Acc: 91.850% (Correct classifications 29627/Total classifications 32256)
# 252 391 Loss: 0.235 | Acc: 91.842% (Correct classifications 29742/Total classifications 32384)
# 253 391 Loss: 0.235 | Acc: 91.815% (Correct classifications 29851/Total classifications 32512)
# 254 391 Loss: 0.235 | Acc: 91.808% (Correct classifications 29966/Total classifications 32640)
# 255 391 Loss: 0.236 | Acc: 91.788% (Correct classifications 30077/Total classifications 32768)
# 256 391 Loss: 0.236 | Acc: 91.786% (Correct classifications 30194/Total classifications 32896)
# 257 391 Loss: 0.236 | Acc: 91.794% (Correct classifications 30314/Total classifications 33024)
# 258 391 Loss: 0.236 | Acc: 91.798% (Correct classifications 30433/Total classifications 33152)
# 259 391 Loss: 0.236 | Acc: 91.812% (Correct classifications 30555/Total classifications 33280)
# 260 391 Loss: 0.236 | Acc: 91.807% (Correct classifications 30671/Total classifications 33408)
# 261 391 Loss: 0.236 | Acc: 91.809% (Correct classifications 30789/Total classifications 33536)
# 262 391 Loss: 0.236 | Acc: 91.798% (Correct classifications 30903/Total classifications 33664)
# 263 391 Loss: 0.237 | Acc: 91.782% (Correct classifications 31015/Total classifications 33792)
# 264 391 Loss: 0.237 | Acc: 91.787% (Correct classifications 31134/Total classifications 33920)
# 265 391 Loss: 0.237 | Acc: 91.773% (Correct classifications 31247/Total classifications 34048)
# 266 391 Loss: 0.237 | Acc: 91.769% (Correct classifications 31363/Total classifications 34176)
# 267 391 Loss: 0.237 | Acc: 91.768% (Correct classifications 31480/Total classifications 34304)
# 268 391 Loss: 0.237 | Acc: 91.772% (Correct classifications 31599/Total classifications 34432)
# 269 391 Loss: 0.237 | Acc: 91.774% (Correct classifications 31717/Total classifications 34560)
# 270 391 Loss: 0.237 | Acc: 91.784% (Correct classifications 31838/Total classifications 34688)
# 271 391 Loss: 0.237 | Acc: 91.777% (Correct classifications 31953/Total classifications 34816)
# 272 391 Loss: 0.237 | Acc: 91.761% (Correct classifications 32065/Total classifications 34944)
# 273 391 Loss: 0.237 | Acc: 91.754% (Correct classifications 32180/Total classifications 35072)
# 274 391 Loss: 0.237 | Acc: 91.759% (Correct classifications 32299/Total classifications 35200)
# 275 391 Loss: 0.237 | Acc: 91.757% (Correct classifications 32416/Total classifications 35328)
# 276 391 Loss: 0.237 | Acc: 91.745% (Correct classifications 32529/Total classifications 35456)
# 277 391 Loss: 0.237 | Acc: 91.741% (Correct classifications 32645/Total classifications 35584)
# 278 391 Loss: 0.237 | Acc: 91.734% (Correct classifications 32760/Total classifications 35712)
# 279 391 Loss: 0.238 | Acc: 91.727% (Correct classifications 32875/Total classifications 35840)
# 280 391 Loss: 0.237 | Acc: 91.737% (Correct classifications 32996/Total classifications 35968)
# 281 391 Loss: 0.238 | Acc: 91.739% (Correct classifications 33114/Total classifications 36096)
# 282 391 Loss: 0.238 | Acc: 91.740% (Correct classifications 33232/Total classifications 36224)
# 283 391 Loss: 0.238 | Acc: 91.750% (Correct classifications 33353/Total classifications 36352)
# 284 391 Loss: 0.238 | Acc: 91.752% (Correct classifications 33471/Total classifications 36480)
# 285 391 Loss: 0.238 | Acc: 91.753% (Correct classifications 33589/Total classifications 36608)
# 286 391 Loss: 0.238 | Acc: 91.757% (Correct classifications 33708/Total classifications 36736)
# 287 391 Loss: 0.237 | Acc: 91.767% (Correct classifications 33829/Total classifications 36864)
# 288 391 Loss: 0.237 | Acc: 91.766% (Correct classifications 33946/Total classifications 36992)
# 289 391 Loss: 0.238 | Acc: 91.748% (Correct classifications 34057/Total classifications 37120)
# 290 391 Loss: 0.237 | Acc: 91.763% (Correct classifications 34180/Total classifications 37248)
# 291 391 Loss: 0.237 | Acc: 91.757% (Correct classifications 34295/Total classifications 37376)
# 292 391 Loss: 0.237 | Acc: 91.766% (Correct classifications 34416/Total classifications 37504)
# 293 391 Loss: 0.237 | Acc: 91.770% (Correct classifications 34535/Total classifications 37632)
# 294 391 Loss: 0.237 | Acc: 91.769% (Correct classifications 34652/Total classifications 37760)
# 295 391 Loss: 0.237 | Acc: 91.770% (Correct classifications 34770/Total classifications 37888)
# 296 391 Loss: 0.237 | Acc: 91.775% (Correct classifications 34889/Total classifications 38016)
# 297 391 Loss: 0.238 | Acc: 91.758% (Correct classifications 35000/Total classifications 38144)
# 298 391 Loss: 0.238 | Acc: 91.751% (Correct classifications 35115/Total classifications 38272)
# 299 391 Loss: 0.238 | Acc: 91.750% (Correct classifications 35232/Total classifications 38400)
# 300 391 Loss: 0.238 | Acc: 91.741% (Correct classifications 35346/Total classifications 38528)
# 301 391 Loss: 0.239 | Acc: 91.722% (Correct classifications 35456/Total classifications 38656)
# 302 391 Loss: 0.238 | Acc: 91.718% (Correct classifications 35572/Total classifications 38784)
# 303 391 Loss: 0.239 | Acc: 91.699% (Correct classifications 35682/Total classifications 38912)
# 304 391 Loss: 0.239 | Acc: 91.698% (Correct classifications 35799/Total classifications 39040)
# 305 391 Loss: 0.239 | Acc: 91.692% (Correct classifications 35914/Total classifications 39168)
# 306 391 Loss: 0.239 | Acc: 91.696% (Correct classifications 36033/Total classifications 39296)
# 307 391 Loss: 0.238 | Acc: 91.706% (Correct classifications 36154/Total classifications 39424)
# 308 391 Loss: 0.239 | Acc: 91.697% (Correct classifications 36268/Total classifications 39552)
# 309 391 Loss: 0.239 | Acc: 91.678% (Correct classifications 36378/Total classifications 39680)
# 310 391 Loss: 0.240 | Acc: 91.678% (Correct classifications 36495/Total classifications 39808)
# 311 391 Loss: 0.239 | Acc: 91.679% (Correct classifications 36613/Total classifications 39936)
# 312 391 Loss: 0.239 | Acc: 91.681% (Correct classifications 36731/Total classifications 40064)
# 313 391 Loss: 0.239 | Acc: 91.685% (Correct classifications 36850/Total classifications 40192)
# 314 391 Loss: 0.239 | Acc: 91.691% (Correct classifications 36970/Total classifications 40320)
# 315 391 Loss: 0.239 | Acc: 91.688% (Correct classifications 37086/Total classifications 40448)
# 316 391 Loss: 0.239 | Acc: 91.685% (Correct classifications 37202/Total classifications 40576)
# 317 391 Loss: 0.239 | Acc: 91.689% (Correct classifications 37321/Total classifications 40704)
# 318 391 Loss: 0.239 | Acc: 91.678% (Correct classifications 37434/Total classifications 40832)
# 319 391 Loss: 0.240 | Acc: 91.667% (Correct classifications 37547/Total classifications 40960)
# 320 391 Loss: 0.240 | Acc: 91.669% (Correct classifications 37665/Total classifications 41088)
# 321 391 Loss: 0.240 | Acc: 91.659% (Correct classifications 37778/Total classifications 41216)
# 322 391 Loss: 0.240 | Acc: 91.660% (Correct classifications 37896/Total classifications 41344)
# 323 391 Loss: 0.240 | Acc: 91.650% (Correct classifications 38009/Total classifications 41472)
# 324 391 Loss: 0.240 | Acc: 91.656% (Correct classifications 38129/Total classifications 41600)
# 325 391 Loss: 0.240 | Acc: 91.660% (Correct classifications 38248/Total classifications 41728)
# 326 391 Loss: 0.240 | Acc: 91.645% (Correct classifications 38359/Total classifications 41856)
# 327 391 Loss: 0.240 | Acc: 91.647% (Correct classifications 38477/Total classifications 41984)
# 328 391 Loss: 0.240 | Acc: 91.641% (Correct classifications 38592/Total classifications 42112)
# 329 391 Loss: 0.240 | Acc: 91.652% (Correct classifications 38714/Total classifications 42240)
# 330 391 Loss: 0.240 | Acc: 91.654% (Correct classifications 38832/Total classifications 42368)
# 331 391 Loss: 0.240 | Acc: 91.667% (Correct classifications 38955/Total classifications 42496)
# 332 391 Loss: 0.241 | Acc: 91.643% (Correct classifications 39062/Total classifications 42624)
# 333 391 Loss: 0.241 | Acc: 91.638% (Correct classifications 39177/Total classifications 42752)
# 334 391 Loss: 0.241 | Acc: 91.632% (Correct classifications 39292/Total classifications 42880)
# 335 391 Loss: 0.241 | Acc: 91.639% (Correct classifications 39412/Total classifications 43008)
# 336 391 Loss: 0.241 | Acc: 91.640% (Correct classifications 39530/Total classifications 43136)
# 337 391 Loss: 0.241 | Acc: 91.635% (Correct classifications 39645/Total classifications 43264)
# 338 391 Loss: 0.241 | Acc: 91.625% (Correct classifications 39758/Total classifications 43392)
# 339 391 Loss: 0.241 | Acc: 91.618% (Correct classifications 39872/Total classifications 43520)
# 340 391 Loss: 0.241 | Acc: 91.608% (Correct classifications 39985/Total classifications 43648)
# 341 391 Loss: 0.241 | Acc: 91.605% (Correct classifications 40101/Total classifications 43776)
# 342 391 Loss: 0.241 | Acc: 91.600% (Correct classifications 40216/Total classifications 43904)
# 343 391 Loss: 0.241 | Acc: 91.597% (Correct classifications 40332/Total classifications 44032)
# 344 391 Loss: 0.241 | Acc: 91.592% (Correct classifications 40447/Total classifications 44160)
# 345 391 Loss: 0.242 | Acc: 91.578% (Correct classifications 40558/Total classifications 44288)
# 346 391 Loss: 0.242 | Acc: 91.575% (Correct classifications 40674/Total classifications 44416)
# 347 391 Loss: 0.242 | Acc: 91.577% (Correct classifications 40792/Total classifications 44544)
# 348 391 Loss: 0.242 | Acc: 91.576% (Correct classifications 40909/Total classifications 44672)
# 349 391 Loss: 0.242 | Acc: 91.569% (Correct classifications 41023/Total classifications 44800)
# 350 391 Loss: 0.242 | Acc: 91.569% (Correct classifications 41140/Total classifications 44928)
# 351 391 Loss: 0.242 | Acc: 91.566% (Correct classifications 41256/Total classifications 45056)
# 352 391 Loss: 0.242 | Acc: 91.561% (Correct classifications 41371/Total classifications 45184)
# 353 391 Loss: 0.242 | Acc: 91.565% (Correct classifications 41490/Total classifications 45312)
# 354 391 Loss: 0.241 | Acc: 91.571% (Correct classifications 41610/Total classifications 45440)
# 355 391 Loss: 0.241 | Acc: 91.575% (Correct classifications 41729/Total classifications 45568)
# 356 391 Loss: 0.241 | Acc: 91.588% (Correct classifications 41852/Total classifications 45696)
# 357 391 Loss: 0.241 | Acc: 91.583% (Correct classifications 41967/Total classifications 45824)
# 358 391 Loss: 0.241 | Acc: 91.585% (Correct classifications 42085/Total classifications 45952)
# 359 391 Loss: 0.241 | Acc: 91.580% (Correct classifications 42200/Total classifications 46080)
# 360 391 Loss: 0.241 | Acc: 91.584% (Correct classifications 42319/Total classifications 46208)
# 361 391 Loss: 0.241 | Acc: 91.590% (Correct classifications 42439/Total classifications 46336)
# 362 391 Loss: 0.241 | Acc: 91.585% (Correct classifications 42554/Total classifications 46464)
# 363 391 Loss: 0.241 | Acc: 91.587% (Correct classifications 42672/Total classifications 46592)
# 364 391 Loss: 0.241 | Acc: 91.584% (Correct classifications 42788/Total classifications 46720)
# 365 391 Loss: 0.241 | Acc: 91.590% (Correct classifications 42908/Total classifications 46848)
# 366 391 Loss: 0.241 | Acc: 91.596% (Correct classifications 43028/Total classifications 46976)
# 367 391 Loss: 0.241 | Acc: 91.597% (Correct classifications 43146/Total classifications 47104)
# 368 391 Loss: 0.242 | Acc: 91.580% (Correct classifications 43255/Total classifications 47232)
# 369 391 Loss: 0.242 | Acc: 91.575% (Correct classifications 43370/Total classifications 47360)
# 370 391 Loss: 0.242 | Acc: 91.583% (Correct classifications 43491/Total classifications 47488)
# 371 391 Loss: 0.242 | Acc: 91.583% (Correct classifications 43608/Total classifications 47616)
# 372 391 Loss: 0.241 | Acc: 91.586% (Correct classifications 43727/Total classifications 47744)
# 373 391 Loss: 0.241 | Acc: 91.584% (Correct classifications 43843/Total classifications 47872)
# 374 391 Loss: 0.241 | Acc: 91.594% (Correct classifications 43965/Total classifications 48000)
# 375 391 Loss: 0.241 | Acc: 91.587% (Correct classifications 44079/Total classifications 48128)
# 376 391 Loss: 0.241 | Acc: 91.591% (Correct classifications 44198/Total classifications 48256)
# 377 391 Loss: 0.241 | Acc: 91.590% (Correct classifications 44315/Total classifications 48384)
# 378 391 Loss: 0.241 | Acc: 91.584% (Correct classifications 44429/Total classifications 48512)
# 379 391 Loss: 0.241 | Acc: 91.579% (Correct classifications 44544/Total classifications 48640)
# 380 391 Loss: 0.241 | Acc: 91.578% (Correct classifications 44661/Total classifications 48768)
# 381 391 Loss: 0.241 | Acc: 91.576% (Correct classifications 44777/Total classifications 48896)
# 382 391 Loss: 0.241 | Acc: 91.567% (Correct classifications 44890/Total classifications 49024)
# 383 391 Loss: 0.242 | Acc: 91.555% (Correct classifications 45001/Total classifications 49152)
# 384 391 Loss: 0.242 | Acc: 91.552% (Correct classifications 45117/Total classifications 49280)
# 385 391 Loss: 0.242 | Acc: 91.536% (Correct classifications 45226/Total classifications 49408)
# 386 391 Loss: 0.242 | Acc: 91.537% (Correct classifications 45344/Total classifications 49536)
# 387 391 Loss: 0.242 | Acc: 91.541% (Correct classifications 45463/Total classifications 49664)
# 388 391 Loss: 0.242 | Acc: 91.543% (Correct classifications 45581/Total classifications 49792)
# 389 391 Loss: 0.242 | Acc: 91.540% (Correct classifications 45697/Total classifications 49920)
# 390 391 Loss: 0.242 | Acc: 91.548% (Correct classifications 45774/Total classifications 50000)
# Train Loss: 0.223 | Acc: 92.130%
# Test Loss: 0.471 | Acc: 84.650%
#
#
#
#
# Total Training time: 142.73 minutes

# %% [markdown]
# # **Evaluation of Model**

# %%
class UnNormalize(object):
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        """
        Args:
            tensor (Tensor): Tensor image of size (C, H, W) to be normalized.
        Returns:
            Tensor: Normalized image.
        """
        for t, m, s in zip(tensor, self.mean, self.std):
            t.mul_(s).add_(m)
            # The normalize code -> t.sub_(m).div_(s)
        return tensor

#seeing predictions of some images
def show_test_prediction_imgs(images, predicted_labels, real_labels):
  plt.figure(1, dpi = 150)
  plt.rcParams.update({'font.size': 5})
  k=0
  for i in range(0,3):
    for j in range(0,3):
      plt.subplot2grid((3,3),(i,j))
      plt.title('{0} -> {1} '.format(LABEL_MAP[real_labels[k].item()],LABEL_MAP[predicted_labels[k].item()]))
      unorm = UnNormalize(mean=(0.4914, 0.4822, 0.4465),std = (0.2023, 0.1994, 0.2010))
      image = unorm(images[k].cpu())
      plt.imshow(np.transpose(image.numpy(), (1,2,0)))
      plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
      plt.tick_params(axis='y', which='both', left=False, right=False, labelleft=False)
      k = k+1
  #show the plot
  plt.tight_layout()
  plt.show()

# %%
#Model Accuracy
total_correct = 0
total_images = 0
confusion_matrix = np.zeros([10,10], int)

with torch.no_grad():
  for i,data in enumerate(test_loader):
    images, labels = data
    images, labels = images.to(device), labels.to(device)
    outputs = net3(images)
    _, predicted = torch.max(outputs.data, 1)
    if(i in [0,1]):
      show_test_prediction_imgs(images, predicted, labels)
    total_images += labels.size(0)
    total_correct += (predicted == labels).sum().item()
    for i, l in enumerate(labels):
      confusion_matrix[l.item(), predicted[i].item()] +=1

model_accuracy = total_correct/total_images *100
print('Model Accuracy on {0} test images : {1:.2f} %'.format(total_images, model_accuracy))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Model Accuracy on 10000 test images : 85.37 %

# %% [markdown]
# # **Result of Model**

# %%
print('{0:10s} - {1}'.format('Category', 'Accuracy'))
for i, r in enumerate(confusion_matrix):
  print('{0:10s} - {1:0.1f}'.format(LABEL_MAP[i], r[i]/np.sum(r)*100))
# Out:
# Category   - Accuracy
# airplane   - 80.7
# car        - 93.4
# bird       - 83.6
# cat        - 72.4
# deer       - 89.6
# dog        - 78.7
# frog       - 95.0
# horse      - 83.4
# ship       - 86.3
# truck      - 90.6

# %% [markdown]
# # **Plotting Confusion Matrix**

# %%
fig, axis = plt.subplots(1,1,figsize = (10,10))
axis.matshow(confusion_matrix, aspect='auto', vmin = 0, vmax = 1000, cmap= plt.get_cmap('Wistia'))
for (i, j), z in np.ndenumerate(confusion_matrix):
  axis.text(j, i, '{:0.2f}'.format( z/np.sum(confusion_matrix, 0)[i]*100), ha='center', va='center')
plt.ylabel('Actual Category')
plt.yticks(range(10), LABEL_MAP.values())
plt.xlabel('Predicted Category')
plt.xticks(range(10), LABEL_MAP.values())
plt.rcParams.update({'font.size': 14})
plt.show()
