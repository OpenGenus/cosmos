# %%
# !wget https://people.eecs.berkeley.edu/~taesung_park/CycleGAN/datasets/monet2photo.zip
# Out:
# --2019-08-22 12:55:44--  https://people.eecs.berkeley.edu/~taesung_park/CycleGAN/datasets/monet2photo.zip
# Resolving people.eecs.berkeley.edu (people.eecs.berkeley.edu)... 128.32.189.73
# Connecting to people.eecs.berkeley.edu (people.eecs.berkeley.edu)|128.32.189.73|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 305231073 (291M) [application/zip]
# Saving to: ‘monet2photo.zip’
#
# monet2photo.zip     100%[===================>] 291.09M  21.2MB/s    in 15s
#
# 2019-08-22 12:55:59 (19.6 MB/s) - ‘monet2photo.zip’ saved [305231073/305231073]

# %%
# !mkdir data
# !cd data

# !unzip monet2photo.zip
# Out:
# Archive:  monet2photo.zip
#    creating: monet2photo/
#    creating: monet2photo/trainA/
#   inflating: monet2photo/trainA/01159.jpg
#   inflating: monet2photo/trainA/01048.jpg
#   inflating: monet2photo/trainA/01144.jpg
#   inflating: monet2photo/trainA/00799.jpg
#   inflating: monet2photo/trainA/00897.jpg
#   inflating: monet2photo/trainA/00998.jpg
#   inflating: monet2photo/trainA/00883.jpg
#   inflating: monet2photo/trainA/00985.jpg
#   inflating: monet2photo/trainA/00311.jpg
#   inflating: monet2photo/trainA/01243.jpg
#   inflating: monet2photo/trainA/01259.jpg
#   inflating: monet2photo/trainA/00454.jpg
#   inflating: monet2photo/trainA/00461.jpg
#   inflating: monet2photo/trainA/01283.jpg
#   inflating: monet2photo/trainA/00901.jpg
#   inflating: monet2photo/trainA/00502.jpg
#   inflating: monet2photo/trainA/00176.jpg
#   inflating: monet2photo/trainA/01157.jpg
#   inflating: monet2photo/trainA/00935.jpg
#   inflating: monet2photo/trainA/00929.jpg
#   inflating: monet2photo/trainA/00837.jpg
#   inflating: monet2photo/trainA/00444.jpg
#   inflating: monet2photo/trainA/00808.jpg
#   inflating: monet2photo/trainA/01009.jpg
#   inflating: monet2photo/trainA/01324.jpg
#   inflating: monet2photo/trainA/01278.jpg
#   inflating: monet2photo/trainA/01229.jpg
#   inflating: monet2photo/trainA/00625.jpg
#   inflating: monet2photo/trainA/00652.jpg
#   inflating: monet2photo/trainA/00056.jpg
#   inflating: monet2photo/trainA/00899.jpg
#   inflating: monet2photo/trainA/01115.jpg
#   inflating: monet2photo/trainA/00725.jpg
#   inflating: monet2photo/trainA/00063.jpg
#   inflating: monet2photo/trainA/01153.jpg
#   inflating: monet2photo/trainA/00731.jpg
#   inflating: monet2photo/trainA/00537.jpg
#   inflating: monet2photo/trainA/01183.jpg
#   inflating: monet2photo/trainA/00358.jpg
#   inflating: monet2photo/trainA/00486.jpg
#   inflating: monet2photo/trainA/00982.jpg
#   inflating: monet2photo/trainA/00019.jpg
#   inflating: monet2photo/trainA/00139.jpg
#   inflating: monet2photo/trainA/00873.jpg
#   inflating: monet2photo/trainA/00741.jpg
#   inflating: monet2photo/trainA/00034.jpg
#   inflating: monet2photo/trainA/00651.jpg
#   inflating: monet2photo/trainA/00169.jpg
#   inflating: monet2photo/trainA/01281.jpg
#   inflating: monet2photo/trainA/00178.jpg
#   inflating: monet2photo/trainA/00742.jpg
#   inflating: monet2photo/trainA/00923.jpg
#   inflating: monet2photo/trainA/00592.jpg
#   inflating: monet2photo/trainA/01152.jpg
#   inflating: monet2photo/trainA/00996.jpg
#   inflating: monet2photo/trainA/00534.jpg
#   inflating: monet2photo/trainA/00157.jpg
#   inflating: monet2photo/trainA/00977.jpg
#   inflating: monet2photo/trainA/00807.jpg
#   inflating: monet2photo/trainA/00971.jpg
#   inflating: monet2photo/trainA/00484.jpg
#   inflating: monet2photo/trainA/00015.jpg
#   inflating: monet2photo/trainA/00345.jpg
#   inflating: monet2photo/trainA/00524.jpg
#   inflating: monet2photo/trainA/01028.jpg
#   inflating: monet2photo/trainA/00294.jpg
#   inflating: monet2photo/trainA/01077.jpg
#   inflating: monet2photo/trainA/01241.jpg
#   inflating: monet2photo/trainA/01292.jpg
#   inflating: monet2photo/trainA/00634.jpg
#   inflating: monet2photo/trainA/00518.jpg
#   inflating: monet2photo/trainA/00536.jpg
#   inflating: monet2photo/trainA/00242.jpg
#   inflating: monet2photo/trainA/00307.jpg
#   inflating: monet2photo/trainA/00147.jpg
#   inflating: monet2photo/trainA/01141.jpg
#   inflating: monet2photo/trainA/00631.jpg
#   inflating: monet2photo/trainA/01191.jpg
#   inflating: monet2photo/trainA/00809.jpg
#   inflating: monet2photo/trainA/00966.jpg
#   inflating: monet2photo/trainA/01235.jpg
#   inflating: monet2photo/trainA/00644.jpg
#   inflating: monet2photo/trainA/01321.jpg
#   inflating: monet2photo/trainA/00078.jpg
#   inflating: monet2photo/trainA/01105.jpg
#   inflating: monet2photo/trainA/00805.jpg
#   inflating: monet2photo/trainA/00446.jpg
#   inflating: monet2photo/trainA/01227.jpg
#   inflating: monet2photo/trainA/00459.jpg
#   inflating: monet2photo/trainA/01177.jpg
#   inflating: monet2photo/trainA/00207.jpg
#   inflating: monet2photo/trainA/00871.jpg
#   inflating: monet2photo/trainA/00158.jpg
#   inflating: monet2photo/trainA/00609.jpg
#   inflating: monet2photo/trainA/00841.jpg
#   inflating: monet2photo/trainA/00125.jpg
#   inflating: monet2photo/trainA/00349.jpg
#   inflating: monet2photo/trainA/00027.jpg
#   inflating: monet2photo/trainA/00962.jpg
#   inflating: monet2photo/trainA/00382.jpg
#   inflating: monet2photo/trainA/00969.jpg
#   inflating: monet2photo/trainA/00109.jpg
#   inflating: monet2photo/trainA/00164.jpg
#   inflating: monet2photo/trainA/00767.jpg
#   inflating: monet2photo/trainA/00726.jpg
#   inflating: monet2photo/trainA/01275.jpg
#   inflating: monet2photo/trainA/00219.jpg
#   inflating: monet2photo/trainA/00972.jpg
#   inflating: monet2photo/trainA/01081.jpg
#   inflating: monet2photo/trainA/00997.jpg
#   inflating: monet2photo/trainA/00389.jpg
#   inflating: monet2photo/trainA/01188.jpg
#   inflating: monet2photo/trainA/01204.jpg
#   inflating: monet2photo/trainA/00012.jpg
#   inflating: monet2photo/trainA/01247.jpg
#   inflating: monet2photo/trainA/00548.jpg
#   inflating: monet2photo/trainA/00687.jpg
#   inflating: monet2photo/trainA/00539.jpg
#   inflating: monet2photo/trainA/01044.jpg
#   inflating: monet2photo/trainA/00193.jpg
#   inflating: monet2photo/trainA/00291.jpg
#   inflating: monet2photo/trainA/00388.jpg
#   inflating: monet2photo/trainA/01131.jpg
#   inflating: monet2photo/trainA/00432.jpg
#   inflating: monet2photo/trainA/00452.jpg
#   inflating: monet2photo/trainA/00275.jpg
#   inflating: monet2photo/trainA/00199.jpg
#   inflating: monet2photo/trainA/00329.jpg
#   inflating: monet2photo/trainA/01322.jpg
#   inflating: monet2photo/trainA/01175.jpg
#   inflating: monet2photo/trainA/00121.jpg
#   inflating: monet2photo/trainA/01337.jpg
#   inflating: monet2photo/trainA/00928.jpg
#   inflating: monet2photo/trainA/00712.jpg
#   inflating: monet2photo/trainA/00343.jpg
#   inflating: monet2photo/trainA/01239.jpg
#   inflating: monet2photo/trainA/00491.jpg
#   inflating: monet2photo/trainA/01006.jpg
#   inflating: monet2photo/trainA/01244.jpg
#   inflating: monet2photo/trainA/01092.jpg
#   inflating: monet2photo/trainA/00608.jpg
#   inflating: monet2photo/trainA/00148.jpg
#   inflating: monet2photo/trainA/01016.jpg
#   inflating: monet2photo/trainA/00978.jpg
#   inflating: monet2photo/trainA/00045.jpg
#   inflating: monet2photo/trainA/00117.jpg
#   inflating: monet2photo/trainA/00943.jpg
#   inflating: monet2photo/trainA/00677.jpg
#   inflating: monet2photo/trainA/01181.jpg
#   inflating: monet2photo/trainA/00161.jpg
#   inflating: monet2photo/trainA/00816.jpg
#   inflating: monet2photo/trainA/01198.jpg
#   inflating: monet2photo/trainA/00865.jpg
#   inflating: monet2photo/trainA/01148.jpg
#   inflating: monet2photo/trainA/00864.jpg
#   inflating: monet2photo/trainA/01303.jpg
#   inflating: monet2photo/trainA/01031.jpg
#   inflating: monet2photo/trainA/00597.jpg
#   inflating: monet2photo/trainA/01121.jpg
#   inflating: monet2photo/trainA/00404.jpg
#   inflating: monet2photo/trainA/00523.jpg
#   inflating: monet2photo/trainA/00594.jpg
#   inflating: monet2photo/trainA/01051.jpg
#   inflating: monet2photo/trainA/00469.jpg
#   inflating: monet2photo/trainA/00638.jpg
#   inflating: monet2photo/trainA/00813.jpg
#   inflating: monet2photo/trainA/00451.jpg
#   inflating: monet2photo/trainA/01145.jpg
#   inflating: monet2photo/trainA/00471.jpg
#   inflating: monet2photo/trainA/00033.jpg
#   inflating: monet2photo/trainA/01059.jpg
#   inflating: monet2photo/trainA/01282.jpg
#   inflating: monet2photo/trainA/01066.jpg
#   inflating: monet2photo/trainA/00204.jpg
#   inflating: monet2photo/trainA/00633.jpg
#   inflating: monet2photo/trainA/00845.jpg
#   inflating: monet2photo/trainA/00613.jpg
#   inflating: monet2photo/trainA/01067.jpg
#   inflating: monet2photo/trainA/00191.jpg
#   inflating: monet2photo/trainA/00185.jpg
#   inflating: monet2photo/trainA/01062.jpg
#   inflating: monet2photo/trainA/00611.jpg
#   inflating: monet2photo/trainA/00328.jpg
#   inflating: monet2photo/trainA/01072.jpg
#   inflating: monet2photo/trainA/00122.jpg
#   inflating: monet2photo/trainA/01209.jpg
#   inflating: monet2photo/trainA/01248.jpg
#   inflating: monet2photo/trainA/00083.jpg
#   inflating: monet2photo/trainA/01257.jpg
#   inflating: monet2photo/trainA/00729.jpg
#   inflating: monet2photo/trainA/00829.jpg
#   inflating: monet2photo/trainA/01251.jpg
#   inflating: monet2photo/trainA/00824.jpg
#   inflating: monet2photo/trainA/00778.jpg
#   inflating: monet2photo/trainA/00806.jpg
#   inflating: monet2photo/trainA/01107.jpg
#   inflating: monet2photo/trainA/00614.jpg
#   inflating: monet2photo/trainA/00635.jpg
#   inflating: monet2photo/trainA/00951.jpg
#   inflating: monet2photo/trainA/00227.jpg
#   inflating: monet2photo/trainA/01314.jpg
#   inflating: monet2photo/trainA/01098.jpg
#   inflating: monet2photo/trainA/00124.jpg
#   inflating: monet2photo/trainA/00136.jpg
#   inflating: monet2photo/trainA/00844.jpg
#   inflating: monet2photo/trainA/01195.jpg
#   inflating: monet2photo/trainA/00046.jpg
#   inflating: monet2photo/trainA/00248.jpg
#   inflating: monet2photo/trainA/01217.jpg
#   inflating: monet2photo/trainA/01002.jpg
#   inflating: monet2photo/trainA/01136.jpg
#   inflating: monet2photo/trainA/00678.jpg
#   inflating: monet2photo/trainA/00919.jpg
#   inflating: monet2photo/trainA/00115.jpg
#   inflating: monet2photo/trainA/00709.jpg
#   inflating: monet2photo/trainA/00558.jpg
#   inflating: monet2photo/trainA/00991.jpg
#   inflating: monet2photo/trainA/01111.jpg
#   inflating: monet2photo/trainA/00468.jpg
#   inflating: monet2photo/trainA/01133.jpg
#   inflating: monet2photo/trainA/00309.jpg
#   inflating: monet2photo/trainA/00504.jpg
#   inflating: monet2photo/trainA/00636.jpg
#   inflating: monet2photo/trainA/01308.jpg
#   inflating: monet2photo/trainA/00113.jpg
#   inflating: monet2photo/trainA/00542.jpg
#   inflating: monet2photo/trainA/00547.jpg
#   inflating: monet2photo/trainA/00995.jpg
#   inflating: monet2photo/trainA/00441.jpg
#   inflating: monet2photo/trainA/00936.jpg
#   inflating: monet2photo/trainA/00433.jpg
#   inflating: monet2photo/trainA/00156.jpg
#   inflating: monet2photo/trainA/00123.jpg
#   inflating: monet2photo/trainA/00224.jpg
#   inflating: monet2photo/trainA/00954.jpg
#   inflating: monet2photo/trainA/00079.jpg
#   inflating: monet2photo/trainA/00944.jpg
#   inflating: monet2photo/trainA/00649.jpg
#   inflating: monet2photo/trainA/00173.jpg
#   inflating: monet2photo/trainA/01261.jpg
#   inflating: monet2photo/trainA/00241.jpg
#   inflating: monet2photo/trainA/01274.jpg
#   inflating: monet2photo/trainA/00653.jpg
#   inflating: monet2photo/trainA/01147.jpg
#   inflating: monet2photo/trainA/00832.jpg
#   inflating: monet2photo/trainA/00437.jpg
#   inflating: monet2photo/trainA/00094.jpg
#   inflating: monet2photo/trainA/01103.jpg
#   inflating: monet2photo/trainA/00752.jpg
#   inflating: monet2photo/trainA/00762.jpg
#   inflating: monet2photo/trainA/00822.jpg
#   inflating: monet2photo/trainA/00693.jpg
#   inflating: monet2photo/trainA/01306.jpg
#   inflating: monet2photo/trainA/00187.jpg
#   inflating: monet2photo/trainA/00672.jpg
#   inflating: monet2photo/trainA/00261.jpg
#   inflating: monet2photo/trainA/00334.jpg
#   inflating: monet2photo/trainA/00624.jpg
#   inflating: monet2photo/trainA/01119.jpg
#   inflating: monet2photo/trainA/00202.jpg
#   inflating: monet2photo/trainA/00906.jpg
#   inflating: monet2photo/trainA/00436.jpg
#   inflating: monet2photo/trainA/00959.jpg
#   inflating: monet2photo/trainA/00812.jpg
#   inflating: monet2photo/trainA/00872.jpg
#   inflating: monet2photo/trainA/00301.jpg
#   inflating: monet2photo/trainA/00154.jpg
#   inflating: monet2photo/trainA/01035.jpg
#   inflating: monet2photo/trainA/00891.jpg
#   inflating: monet2photo/trainA/00213.jpg
#   inflating: monet2photo/trainA/00166.jpg
#   inflating: monet2photo/trainA/01174.jpg
#   inflating: monet2photo/trainA/00443.jpg
#   inflating: monet2photo/trainA/01302.jpg
#   inflating: monet2photo/trainA/00818.jpg
#   inflating: monet2photo/trainA/01211.jpg
#   inflating: monet2photo/trainA/00975.jpg
#   inflating: monet2photo/trainA/00589.jpg
#   inflating: monet2photo/trainA/00521.jpg
#   inflating: monet2photo/trainA/01328.jpg
#   inflating: monet2photo/trainA/00481.jpg
#   inflating: monet2photo/trainA/00274.jpg
#   inflating: monet2photo/trainA/00478.jpg
#   inflating: monet2photo/trainA/00789.jpg
#   inflating: monet2photo/trainA/00964.jpg
#   inflating: monet2photo/trainA/00801.jpg
#   inflating: monet2photo/trainA/00488.jpg
#   inflating: monet2photo/trainA/00249.jpg
#   inflating: monet2photo/trainA/01023.jpg
#   inflating: monet2photo/trainA/00366.jpg
#   inflating: monet2photo/trainA/00758.jpg
#   inflating: monet2photo/trainA/00421.jpg
#   inflating: monet2photo/trainA/00834.jpg
#   inflating: monet2photo/trainA/00466.jpg
#   inflating: monet2photo/trainA/00289.jpg
#   inflating: monet2photo/trainA/00192.jpg
#   inflating: monet2photo/trainA/00411.jpg
#   inflating: monet2photo/trainA/00779.jpg
#   inflating: monet2photo/trainA/00483.jpg
#   inflating: monet2photo/trainA/00172.jpg
#   inflating: monet2photo/trainA/00416.jpg
#   inflating: monet2photo/trainA/01025.jpg
#   inflating: monet2photo/trainA/00596.jpg
#   inflating: monet2photo/trainA/00415.jpg
#   inflating: monet2photo/trainA/00657.jpg
#   inflating: monet2photo/trainA/00546.jpg
#   inflating: monet2photo/trainA/00414.jpg
#   inflating: monet2photo/trainA/01109.jpg
#   inflating: monet2photo/trainA/00032.jpg
#   inflating: monet2photo/trainA/00526.jpg
#   inflating: monet2photo/trainA/00331.jpg
#   inflating: monet2photo/trainA/01027.jpg
#   inflating: monet2photo/trainA/00006.jpg
#   inflating: monet2photo/trainA/00467.jpg
#   inflating: monet2photo/trainA/01128.jpg
#   inflating: monet2photo/trainA/00251.jpg
#   inflating: monet2photo/trainA/01265.jpg
#   inflating: monet2photo/trainA/00292.jpg
#   inflating: monet2photo/trainA/01286.jpg
#   inflating: monet2photo/trainA/00127.jpg
#   inflating: monet2photo/trainA/00007.jpg
#   inflating: monet2photo/trainA/01179.jpg
#   inflating: monet2photo/trainA/00108.jpg
#   inflating: monet2photo/trainA/00144.jpg
#   inflating: monet2photo/trainA/00196.jpg
#   inflating: monet2photo/trainA/00278.jpg
#   inflating: monet2photo/trainA/01138.jpg
#   inflating: monet2photo/trainA/00735.jpg
#   inflating: monet2photo/trainA/00379.jpg
#   inflating: monet2photo/trainA/01184.jpg
#   inflating: monet2photo/trainA/01208.jpg
#   inflating: monet2photo/trainA/00777.jpg
#   inflating: monet2photo/trainA/00258.jpg
#   inflating: monet2photo/trainA/00826.jpg
#   inflating: monet2photo/trainA/00184.jpg
#   inflating: monet2photo/trainA/00744.jpg
#   inflating: monet2photo/trainA/00475.jpg
#   inflating: monet2photo/trainA/01046.jpg
#   inflating: monet2photo/trainA/00114.jpg
#   inflating: monet2photo/trainA/01091.jpg
#   inflating: monet2photo/trainA/00722.jpg
#   inflating: monet2photo/trainA/00747.jpg
#   inflating: monet2photo/trainA/01139.jpg
#   inflating: monet2photo/trainA/01014.jpg
#   inflating: monet2photo/trainA/01212.jpg
#   inflating: monet2photo/trainA/00398.jpg
#   inflating: monet2photo/trainA/00797.jpg
#   inflating: monet2photo/trainA/00761.jpg
#   inflating: monet2photo/trainA/00689.jpg
#   inflating: monet2photo/trainA/00276.jpg
#   inflating: monet2photo/trainA/00391.jpg
#   inflating: monet2photo/trainA/00004.jpg
#   inflating: monet2photo/trainA/00119.jpg
#   inflating: monet2photo/trainA/01272.jpg
#   inflating: monet2photo/trainA/00499.jpg
#   inflating: monet2photo/trainA/00302.jpg
#   inflating: monet2photo/trainA/01266.jpg
#   inflating: monet2photo/trainA/00986.jpg
#   inflating: monet2photo/trainA/00755.jpg
#   inflating: monet2photo/trainA/00961.jpg
#   inflating: monet2photo/trainA/00685.jpg
#   inflating: monet2photo/trainA/00092.jpg
#   inflating: monet2photo/trainA/01146.jpg
#   inflating: monet2photo/trainA/00739.jpg
#   inflating: monet2photo/trainA/00798.jpg
#   inflating: monet2photo/trainA/00128.jpg
#   inflating: monet2photo/trainA/01231.jpg
#   inflating: monet2photo/trainA/00615.jpg
#   inflating: monet2photo/trainA/01234.jpg
#   inflating: monet2photo/trainA/00907.jpg
#   inflating: monet2photo/trainA/00403.jpg
#   inflating: monet2photo/trainA/00281.jpg
#   inflating: monet2photo/trainA/00238.jpg
#   inflating: monet2photo/trainA/01064.jpg
#   inflating: monet2photo/trainA/00882.jpg
#   inflating: monet2photo/trainA/00987.jpg
#   inflating: monet2photo/trainA/01178.jpg
#   inflating: monet2photo/trainA/00201.jpg
#   inflating: monet2photo/trainA/00269.jpg
#   inflating: monet2photo/trainA/00288.jpg
#   inflating: monet2photo/trainA/00811.jpg
#   inflating: monet2photo/trainA/00037.jpg
#   inflating: monet2photo/trainA/01132.jpg
#   inflating: monet2photo/trainA/01108.jpg
#   inflating: monet2photo/trainA/01038.jpg
#   inflating: monet2photo/trainA/01083.jpg
#   inflating: monet2photo/trainA/00646.jpg
#   inflating: monet2photo/trainA/00828.jpg
#   inflating: monet2photo/trainA/00003.jpg
#   inflating: monet2photo/trainA/01167.jpg
#   inflating: monet2photo/trainA/00008.jpg
#   inflating: monet2photo/trainA/01316.jpg
#   inflating: monet2photo/trainA/01114.jpg
#   inflating: monet2photo/trainA/01297.jpg
#   inflating: monet2photo/trainA/00538.jpg
#   inflating: monet2photo/trainA/00344.jpg
#   inflating: monet2photo/trainA/01134.jpg
#   inflating: monet2photo/trainA/01318.jpg
#   inflating: monet2photo/trainA/00795.jpg
#   inflating: monet2photo/trainA/01124.jpg
#   inflating: monet2photo/trainA/01263.jpg
#   inflating: monet2photo/trainA/00426.jpg
#   inflating: monet2photo/trainA/00319.jpg
#   inflating: monet2photo/trainA/00455.jpg
#   inflating: monet2photo/trainA/01197.jpg
#   inflating: monet2photo/trainA/01169.jpg
#   inflating: monet2photo/trainA/00839.jpg
#   inflating: monet2photo/trainA/01069.jpg
#   inflating: monet2photo/trainA/00077.jpg
#   inflating: monet2photo/trainA/00869.jpg
#   inflating: monet2photo/trainA/00143.jpg
#   inflating: monet2photo/trainA/00286.jpg
#   inflating: monet2photo/trainA/00222.jpg
#   inflating: monet2photo/trainA/00676.jpg
#   inflating: monet2photo/trainA/00318.jpg
#   inflating: monet2photo/trainA/00142.jpg
#   inflating: monet2photo/trainA/00071.jpg
#   inflating: monet2photo/trainA/00385.jpg
#   inflating: monet2photo/trainA/00394.jpg
#   inflating: monet2photo/trainA/00893.jpg
#   inflating: monet2photo/trainA/01279.jpg
#   inflating: monet2photo/trainA/00239.jpg
#   inflating: monet2photo/trainA/01218.jpg
#   inflating: monet2photo/trainA/00205.jpg
#   inflating: monet2photo/trainA/00623.jpg
#   inflating: monet2photo/trainA/00983.jpg
#   inflating: monet2photo/trainA/00817.jpg
#   inflating: monet2photo/trainA/00557.jpg
#   inflating: monet2photo/trainA/00259.jpg
#   inflating: monet2photo/trainA/00924.jpg
#   inflating: monet2photo/trainA/00718.jpg
#   inflating: monet2photo/trainA/00022.jpg
#   inflating: monet2photo/trainA/01176.jpg
#   inflating: monet2photo/trainA/00028.jpg
#   inflating: monet2photo/trainA/01142.jpg
#   inflating: monet2photo/trainA/00772.jpg
#   inflating: monet2photo/trainA/00721.jpg
#   inflating: monet2photo/trainA/00472.jpg
#   inflating: monet2photo/trainA/00781.jpg
#   inflating: monet2photo/trainA/00435.jpg
#   inflating: monet2photo/trainA/00402.jpg
#   inflating: monet2photo/trainA/00211.jpg
#   inflating: monet2photo/trainA/00445.jpg
#   inflating: monet2photo/trainA/00892.jpg
#   inflating: monet2photo/trainA/00967.jpg
#   inflating: monet2photo/trainA/01246.jpg
#   inflating: monet2photo/trainA/01329.jpg
#   inflating: monet2photo/trainA/01315.jpg
#   inflating: monet2photo/trainA/00774.jpg
#   inflating: monet2photo/trainA/00551.jpg
#   inflating: monet2photo/trainA/00272.jpg
#   inflating: monet2photo/trainA/01222.jpg
#   inflating: monet2photo/trainA/00866.jpg
#   inflating: monet2photo/trainA/01117.jpg
#   inflating: monet2photo/trainA/00453.jpg
#   inflating: monet2photo/trainA/00695.jpg
#   inflating: monet2photo/trainA/00221.jpg
#   inflating: monet2photo/trainA/00931.jpg
#   inflating: monet2photo/trainA/01335.jpg
#   inflating: monet2photo/trainA/01055.jpg
#   inflating: monet2photo/trainA/00684.jpg
#   inflating: monet2photo/trainA/01018.jpg
#   inflating: monet2photo/trainA/01033.jpg
#   inflating: monet2photo/trainA/00149.jpg
#   inflating: monet2photo/trainA/00601.jpg
#   inflating: monet2photo/trainA/00675.jpg
#   inflating: monet2photo/trainA/00167.jpg
#   inflating: monet2photo/trainA/00377.jpg
#   inflating: monet2photo/trainA/00062.jpg
#   inflating: monet2photo/trainA/00922.jpg
#   inflating: monet2photo/trainA/00357.jpg
#   inflating: monet2photo/trainA/00422.jpg
#   inflating: monet2photo/trainA/00946.jpg
#   inflating: monet2photo/trainA/01037.jpg
#   inflating: monet2photo/trainA/00716.jpg
#   inflating: monet2photo/trainA/00287.jpg
#   inflating: monet2photo/trainA/00535.jpg
#   inflating: monet2photo/trainA/00206.jpg
#   inflating: monet2photo/trainA/01097.jpg
#   inflating: monet2photo/trainA/00606.jpg
#   inflating: monet2photo/trainA/01096.jpg
#   inflating: monet2photo/trainA/00706.jpg
#   inflating: monet2photo/trainA/01004.jpg
#   inflating: monet2photo/trainA/00835.jpg
#   inflating: monet2photo/trainA/00888.jpg
#   inflating: monet2photo/trainA/00912.jpg
#   inflating: monet2photo/trainA/00759.jpg
#   inflating: monet2photo/trainA/01194.jpg
#   inflating: monet2photo/trainA/00298.jpg
#   inflating: monet2photo/trainA/00151.jpg
#   inflating: monet2photo/trainA/00968.jpg
#   inflating: monet2photo/trainA/00485.jpg
#   inflating: monet2photo/trainA/01295.jpg
#   inflating: monet2photo/trainA/00717.jpg
#   inflating: monet2photo/trainA/00559.jpg
#   inflating: monet2photo/trainA/00387.jpg
#   inflating: monet2photo/trainA/00963.jpg
#   inflating: monet2photo/trainA/00939.jpg
#   inflating: monet2photo/trainA/00916.jpg
#   inflating: monet2photo/trainA/00553.jpg
#   inflating: monet2photo/trainA/01319.jpg
#   inflating: monet2photo/trainA/01168.jpg
#   inflating: monet2photo/trainA/00407.jpg
#   inflating: monet2photo/trainA/00465.jpg
#   inflating: monet2photo/trainA/00612.jpg
#   inflating: monet2photo/trainA/00163.jpg
#   inflating: monet2photo/trainA/00733.jpg
#   inflating: monet2photo/trainA/00802.jpg
#   inflating: monet2photo/trainA/00208.jpg
#   inflating: monet2photo/trainA/00698.jpg
#   inflating: monet2photo/trainA/01264.jpg
#   inflating: monet2photo/trainA/00788.jpg
#   inflating: monet2photo/trainA/00449.jpg
#   inflating: monet2photo/trainA/00096.jpg
#   inflating: monet2photo/trainA/01149.jpg
#   inflating: monet2photo/trainA/00603.jpg
#   inflating: monet2photo/trainA/00417.jpg
#   inflating: monet2photo/trainA/01047.jpg
#   inflating: monet2photo/trainA/00031.jpg
#   inflating: monet2photo/trainA/01039.jpg
#   inflating: monet2photo/trainA/00129.jpg
#   inflating: monet2photo/trainA/00244.jpg
#   inflating: monet2photo/trainA/00284.jpg
#   inflating: monet2photo/trainA/00933.jpg
#   inflating: monet2photo/trainA/00489.jpg
#   inflating: monet2photo/trainA/00993.jpg
#   inflating: monet2photo/trainA/00429.jpg
#   inflating: monet2photo/trainA/00955.jpg
#   inflating: monet2photo/trainA/00352.jpg
#   inflating: monet2photo/trainA/00768.jpg
#   inflating: monet2photo/trainA/01078.jpg
#   inflating: monet2photo/trainA/01076.jpg
#   inflating: monet2photo/trainA/00668.jpg
#   inflating: monet2photo/trainA/00836.jpg
#   inflating: monet2photo/trainA/01163.jpg
#   inflating: monet2photo/trainA/00189.jpg
#   inflating: monet2photo/trainA/00819.jpg
#   inflating: monet2photo/trainA/01311.jpg
#   inflating: monet2photo/trainA/00896.jpg
#   inflating: monet2photo/trainA/01166.jpg
#   inflating: monet2photo/trainA/00047.jpg
#   inflating: monet2photo/trainA/00602.jpg
#   inflating: monet2photo/trainA/00477.jpg
#   inflating: monet2photo/trainA/01034.jpg
#   inflating: monet2photo/trainA/01307.jpg
#   inflating: monet2photo/trainA/00313.jpg
#   inflating: monet2photo/trainA/00904.jpg
#   inflating: monet2photo/trainA/01074.jpg
#   inflating: monet2photo/trainA/00336.jpg
#   inflating: monet2photo/trainA/00021.jpg
#   inflating: monet2photo/trainA/00038.jpg
#   inflating: monet2photo/trainA/01187.jpg
#   inflating: monet2photo/trainA/01214.jpg
#   inflating: monet2photo/trainA/00895.jpg
#   inflating: monet2photo/trainA/00842.jpg
#   inflating: monet2photo/trainA/01236.jpg
#   inflating: monet2photo/trainA/00732.jpg
#   inflating: monet2photo/trainA/01052.jpg
#   inflating: monet2photo/trainA/00479.jpg
#   inflating: monet2photo/trainA/00023.jpg
#   inflating: monet2photo/trainA/00072.jpg
#   inflating: monet2photo/trainA/00884.jpg
#   inflating: monet2photo/trainA/00356.jpg
#   inflating: monet2photo/trainA/00704.jpg
#   inflating: monet2photo/trainA/01313.jpg
#   inflating: monet2photo/trainA/01196.jpg
#   inflating: monet2photo/trainA/00754.jpg
#   inflating: monet2photo/trainA/00621.jpg
#   inflating: monet2photo/trainA/00688.jpg
#   inflating: monet2photo/trainA/00256.jpg
#   inflating: monet2photo/trainA/00442.jpg
#   inflating: monet2photo/trainA/01193.jpg
#   inflating: monet2photo/trainA/00029.jpg
#   inflating: monet2photo/trainA/00681.jpg
#   inflating: monet2photo/trainA/00308.jpg
#   inflating: monet2photo/trainA/00909.jpg
#   inflating: monet2photo/trainA/00934.jpg
#   inflating: monet2photo/trainA/00231.jpg
#   inflating: monet2photo/trainA/00235.jpg
#   inflating: monet2photo/trainA/00073.jpg
#   inflating: monet2photo/trainA/00674.jpg
#   inflating: monet2photo/trainA/01224.jpg
#   inflating: monet2photo/trainA/00232.jpg
#   inflating: monet2photo/trainA/01061.jpg
#   inflating: monet2photo/trainA/01084.jpg
#   inflating: monet2photo/trainA/00528.jpg
#   inflating: monet2photo/trainA/01216.jpg
#   inflating: monet2photo/trainA/00026.jpg
#   inflating: monet2photo/trainA/01226.jpg
#   inflating: monet2photo/trainA/00682.jpg
#   inflating: monet2photo/trainA/00355.jpg
#   inflating: monet2photo/trainA/00619.jpg
#   inflating: monet2photo/trainA/01192.jpg
#   inflating: monet2photo/trainA/00617.jpg
#   inflating: monet2photo/trainA/01258.jpg
#   inflating: monet2photo/trainA/00827.jpg
#   inflating: monet2photo/trainA/00686.jpg
#   inflating: monet2photo/trainA/01008.jpg
#   inflating: monet2photo/trainA/00723.jpg
#   inflating: monet2photo/trainA/00957.jpg
#   inflating: monet2photo/trainA/00878.jpg
#   inflating: monet2photo/trainA/00363.jpg
#   inflating: monet2photo/trainA/00175.jpg
#   inflating: monet2photo/trainA/00861.jpg
#   inflating: monet2photo/trainA/00915.jpg
#   inflating: monet2photo/trainA/00368.jpg
#   inflating: monet2photo/trainA/00036.jpg
#   inflating: monet2photo/trainA/00645.jpg
#   inflating: monet2photo/trainA/00383.jpg
#   inflating: monet2photo/trainA/00168.jpg
#   inflating: monet2photo/trainA/00233.jpg
#   inflating: monet2photo/trainA/00591.jpg
#   inflating: monet2photo/trainA/00552.jpg
#   inflating: monet2photo/trainA/00598.jpg
#   inflating: monet2photo/trainA/01162.jpg
#   inflating: monet2photo/trainA/01325.jpg
#   inflating: monet2photo/trainA/01024.jpg
#   inflating: monet2photo/trainA/00225.jpg
#   inflating: monet2photo/trainA/01022.jpg
#   inflating: monet2photo/trainA/00851.jpg
#   inflating: monet2photo/trainA/00438.jpg
#   inflating: monet2photo/trainA/00541.jpg
#   inflating: monet2photo/trainA/00757.jpg
#   inflating: monet2photo/trainA/00637.jpg
#   inflating: monet2photo/trainA/01301.jpg
#   inflating: monet2photo/trainA/01093.jpg
#   inflating: monet2photo/trainA/00332.jpg
#   inflating: monet2photo/trainA/00937.jpg
#   inflating: monet2photo/trainA/01127.jpg
#   inflating: monet2photo/trainA/00994.jpg
#   inflating: monet2photo/trainA/01082.jpg
#   inflating: monet2photo/trainA/00639.jpg
#   inflating: monet2photo/trainA/00679.jpg
#   inflating: monet2photo/trainA/01041.jpg
#   inflating: monet2photo/trainA/00448.jpg
#   inflating: monet2photo/trainA/00658.jpg
#   inflating: monet2photo/trainA/00217.jpg
#   inflating: monet2photo/trainA/00351.jpg
#   inflating: monet2photo/trainA/01042.jpg
#   inflating: monet2photo/trainA/00498.jpg
#   inflating: monet2photo/trainA/00495.jpg
#   inflating: monet2photo/trainA/00223.jpg
#   inflating: monet2photo/trainA/01058.jpg
#   inflating: monet2photo/trainA/01129.jpg
#   inflating: monet2photo/trainA/01158.jpg
#   inflating: monet2photo/trainA/01063.jpg
#   inflating: monet2photo/trainA/00852.jpg
#   inflating: monet2photo/trainA/00863.jpg
#   inflating: monet2photo/trainA/00152.jpg
#   inflating: monet2photo/trainA/00049.jpg
#   inflating: monet2photo/trainA/01017.jpg
#   inflating: monet2photo/trainA/01019.jpg
#   inflating: monet2photo/trainA/00506.jpg
#   inflating: monet2photo/trainA/00667.jpg
#   inflating: monet2photo/trainA/00111.jpg
#   inflating: monet2photo/trainA/00501.jpg
#   inflating: monet2photo/trainA/00075.jpg
#   inflating: monet2photo/trainA/00848.jpg
#   inflating: monet2photo/trainA/01161.jpg
#   inflating: monet2photo/trainA/01056.jpg
#   inflating: monet2photo/trainA/01276.jpg
#   inflating: monet2photo/trainA/01029.jpg
#   inflating: monet2photo/trainA/00803.jpg
#   inflating: monet2photo/trainA/00243.jpg
#   inflating: monet2photo/trainA/01228.jpg
#   inflating: monet2photo/trainA/00792.jpg
#   inflating: monet2photo/trainA/00599.jpg
#   inflating: monet2photo/trainA/00145.jpg
#   inflating: monet2photo/trainA/00146.jpg
#   inflating: monet2photo/trainA/01172.jpg
#   inflating: monet2photo/trainA/00838.jpg
#   inflating: monet2photo/trainA/00406.jpg
#   inflating: monet2photo/trainA/01289.jpg
#   inflating: monet2photo/trainA/00326.jpg
#   inflating: monet2photo/trainA/00296.jpg
#   inflating: monet2photo/trainA/01049.jpg
#   inflating: monet2photo/trainA/00323.jpg
#   inflating: monet2photo/trainA/00627.jpg
#   inflating: monet2photo/trainA/00255.jpg
#   inflating: monet2photo/trainA/00058.jpg
#   inflating: monet2photo/trainA/00879.jpg
#   inflating: monet2photo/trainA/01285.jpg
#   inflating: monet2photo/trainA/01293.jpg
#   inflating: monet2photo/trainA/00543.jpg
#   inflating: monet2photo/trainA/00753.jpg
#   inflating: monet2photo/trainA/00456.jpg
#   inflating: monet2photo/trainA/00701.jpg
#   inflating: monet2photo/trainA/00482.jpg
#   inflating: monet2photo/trainA/00856.jpg
#   inflating: monet2photo/trainA/00493.jpg
#   inflating: monet2photo/trainA/00212.jpg
#   inflating: monet2photo/trainA/00522.jpg
#   inflating: monet2photo/trainA/01026.jpg
#   inflating: monet2photo/trainA/01118.jpg
#   inflating: monet2photo/trainA/00641.jpg
#   inflating: monet2photo/trainA/00656.jpg
#   inflating: monet2photo/trainA/00492.jpg
#   inflating: monet2photo/trainA/01284.jpg
#   inflating: monet2photo/trainA/00268.jpg
#   inflating: monet2photo/trainA/00043.jpg
#   inflating: monet2photo/trainA/00908.jpg
#   inflating: monet2photo/trainA/00973.jpg
#   inflating: monet2photo/trainA/00059.jpg
#   inflating: monet2photo/trainA/00921.jpg
#   inflating: monet2photo/trainA/01253.jpg
#   inflating: monet2photo/trainA/00905.jpg
#   inflating: monet2photo/trainA/00041.jpg
#   inflating: monet2photo/trainA/01122.jpg
#   inflating: monet2photo/trainA/00179.jpg
#   inflating: monet2photo/trainA/00868.jpg
#   inflating: monet2photo/trainA/00017.jpg
#   inflating: monet2photo/trainA/01104.jpg
#   inflating: monet2photo/trainA/00859.jpg
#   inflating: monet2photo/trainA/01277.jpg
#   inflating: monet2photo/trainA/01057.jpg
#   inflating: monet2photo/trainA/00925.jpg
#   inflating: monet2photo/trainA/00082.jpg
#   inflating: monet2photo/trainA/00348.jpg
#   inflating: monet2photo/trainA/00081.jpg
#   inflating: monet2photo/trainA/01219.jpg
#   inflating: monet2photo/trainA/00089.jpg
#   inflating: monet2photo/trainA/00333.jpg
#   inflating: monet2photo/trainA/01225.jpg
#   inflating: monet2photo/trainA/00011.jpg
#   inflating: monet2photo/trainA/00595.jpg
#   inflating: monet2photo/trainA/00487.jpg
#   inflating: monet2photo/trainA/00694.jpg
#   inflating: monet2photo/trainA/00197.jpg
#   inflating: monet2photo/trainA/00424.jpg
#   inflating: monet2photo/trainA/01065.jpg
#   inflating: monet2photo/trainA/00126.jpg
#   inflating: monet2photo/trainA/00035.jpg
#   inflating: monet2photo/trainA/00476.jpg
#   inflating: monet2photo/trainA/00673.jpg
#   inflating: monet2photo/trainA/00312.jpg
#   inflating: monet2photo/trainA/00881.jpg
#   inflating: monet2photo/trainA/00927.jpg
#   inflating: monet2photo/trainA/00554.jpg
#   inflating: monet2photo/trainA/01032.jpg
#   inflating: monet2photo/trainA/01206.jpg
#   inflating: monet2photo/trainA/00699.jpg
#   inflating: monet2photo/trainA/00137.jpg
#   inflating: monet2photo/trainA/00719.jpg
#   inflating: monet2photo/trainA/00464.jpg
#   inflating: monet2photo/trainA/00118.jpg
#   inflating: monet2photo/trainA/00324.jpg
#   inflating: monet2photo/trainA/01252.jpg
#   inflating: monet2photo/trainA/00497.jpg
#   inflating: monet2photo/trainA/00188.jpg
#   inflating: monet2photo/trainA/01271.jpg
#   inflating: monet2photo/trainA/00395.jpg
#   inflating: monet2photo/trainA/01327.jpg
#   inflating: monet2photo/trainA/00793.jpg
#   inflating: monet2photo/trainA/00749.jpg
#   inflating: monet2photo/trainA/00361.jpg
#   inflating: monet2photo/trainA/01333.jpg
#   inflating: monet2photo/trainA/00947.jpg
#   inflating: monet2photo/trainA/00321.jpg
#   inflating: monet2photo/trainA/00024.jpg
#   inflating: monet2photo/trainA/00091.jpg
#   inflating: monet2photo/trainA/00116.jpg
#   inflating: monet2photo/trainA/00048.jpg
#   inflating: monet2photo/trainA/00194.jpg
#   inflating: monet2photo/trainA/01233.jpg
#   inflating: monet2photo/trainA/01317.jpg
#   inflating: monet2photo/trainA/00315.jpg
#   inflating: monet2photo/trainA/01036.jpg
#   inflating: monet2photo/trainA/00507.jpg
#   inflating: monet2photo/trainA/00756.jpg
#   inflating: monet2photo/trainA/00262.jpg
#   inflating: monet2photo/trainA/00141.jpg
#   inflating: monet2photo/trainA/00171.jpg
#   inflating: monet2photo/trainA/00016.jpg
#   inflating: monet2photo/trainA/01137.jpg
#   inflating: monet2photo/trainA/01186.jpg
#   inflating: monet2photo/trainA/00209.jpg
#   inflating: monet2photo/trainA/01334.jpg
#   inflating: monet2photo/trainA/01112.jpg
#   inflating: monet2photo/trainA/01094.jpg
#   inflating: monet2photo/trainA/00283.jpg
#   inflating: monet2photo/trainA/00195.jpg
#   inflating: monet2photo/trainA/01299.jpg
#   inflating: monet2photo/trainA/00867.jpg
#   inflating: monet2photo/trainA/01156.jpg
#   inflating: monet2photo/trainA/01116.jpg
#   inflating: monet2photo/trainA/00877.jpg
#   inflating: monet2photo/trainA/00981.jpg
#   inflating: monet2photo/trainA/00392.jpg
#   inflating: monet2photo/trainA/00386.jpg
#   inflating: monet2photo/trainA/00815.jpg
#   inflating: monet2photo/trainA/00299.jpg
#   inflating: monet2photo/trainA/00857.jpg
#   inflating: monet2photo/trainA/00527.jpg
#   inflating: monet2photo/trainA/00234.jpg
#   inflating: monet2photo/trainA/00988.jpg
#   inflating: monet2photo/trainA/00632.jpg
#   inflating: monet2photo/trainA/00447.jpg
#   inflating: monet2photo/trainA/01291.jpg
#   inflating: monet2photo/trainA/00155.jpg
#   inflating: monet2photo/trainA/00714.jpg
#   inflating: monet2photo/trainA/00669.jpg
#   inflating: monet2photo/trainA/00786.jpg
#   inflating: monet2photo/trainA/00396.jpg
#   inflating: monet2photo/trainA/00408.jpg
#   inflating: monet2photo/trainA/00593.jpg
#   inflating: monet2photo/trainA/00378.jpg
#   inflating: monet2photo/trainA/00252.jpg
#   inflating: monet2photo/trainA/00796.jpg
#   inflating: monet2photo/trainA/00775.jpg
#   inflating: monet2photo/trainA/00862.jpg
#   inflating: monet2photo/trainA/00525.jpg
#   inflating: monet2photo/trainA/00494.jpg
#   inflating: monet2photo/trainA/01273.jpg
#   inflating: monet2photo/trainA/00894.jpg
#   inflating: monet2photo/trainA/01003.jpg
#   inflating: monet2photo/trainA/00555.jpg
#   inflating: monet2photo/trainA/00064.jpg
#   inflating: monet2photo/trainA/01123.jpg
#   inflating: monet2photo/trainA/00831.jpg
#   inflating: monet2photo/trainA/01331.jpg
#   inflating: monet2photo/trainA/00001.jpg
#   inflating: monet2photo/trainA/00965.jpg
#   inflating: monet2photo/trainA/00009.jpg
#   inflating: monet2photo/trainA/01312.jpg
#   inflating: monet2photo/trainA/00399.jpg
#   inflating: monet2photo/trainA/00642.jpg
#   inflating: monet2photo/trainA/00654.jpg
#   inflating: monet2photo/trainA/00616.jpg
#   inflating: monet2photo/trainA/00876.jpg
#   inflating: monet2photo/trainA/00412.jpg
#   inflating: monet2photo/trainA/01205.jpg
#   inflating: monet2photo/trainA/01071.jpg
#   inflating: monet2photo/trainA/00989.jpg
#   inflating: monet2photo/trainA/00505.jpg
#   inflating: monet2photo/trainA/00776.jpg
#   inflating: monet2photo/trainA/00769.jpg
#   inflating: monet2photo/trainA/00737.jpg
#   inflating: monet2photo/trainA/00787.jpg
#   inflating: monet2photo/trainA/01238.jpg
#   inflating: monet2photo/trainA/01207.jpg
#   inflating: monet2photo/trainA/01223.jpg
#   inflating: monet2photo/trainA/00503.jpg
#   inflating: monet2photo/trainA/00713.jpg
#   inflating: monet2photo/trainA/00067.jpg
#   inflating: monet2photo/trainA/01043.jpg
#   inflating: monet2photo/trainA/01164.jpg
#   inflating: monet2photo/trainA/00153.jpg
#   inflating: monet2photo/trainA/00265.jpg
#   inflating: monet2photo/trainA/00226.jpg
#   inflating: monet2photo/trainA/00875.jpg
#   inflating: monet2photo/trainA/00607.jpg
#   inflating: monet2photo/trainA/00218.jpg
#   inflating: monet2photo/trainA/00724.jpg
#   inflating: monet2photo/trainA/00068.jpg
#   inflating: monet2photo/trainA/00066.jpg
#   inflating: monet2photo/trainA/00549.jpg
#   inflating: monet2photo/trainA/00659.jpg
#   inflating: monet2photo/trainA/01106.jpg
#   inflating: monet2photo/trainA/01305.jpg
#   inflating: monet2photo/trainA/00463.jpg
#   inflating: monet2photo/trainA/00159.jpg
#   inflating: monet2photo/trainA/00917.jpg
#   inflating: monet2photo/trainA/01288.jpg
#   inflating: monet2photo/trainA/01102.jpg
#   inflating: monet2photo/trainA/00362.jpg
#   inflating: monet2photo/trainA/01189.jpg
#   inflating: monet2photo/trainA/00177.jpg
#   inflating: monet2photo/trainA/00018.jpg
#   inflating: monet2photo/trainA/00306.jpg
#   inflating: monet2photo/trainA/00245.jpg
#   inflating: monet2photo/trainA/00462.jpg
#   inflating: monet2photo/trainA/01001.jpg
#   inflating: monet2photo/trainA/00833.jpg
#   inflating: monet2photo/trainA/00708.jpg
#   inflating: monet2photo/trainA/00823.jpg
#   inflating: monet2photo/trainA/01237.jpg
#   inflating: monet2photo/trainA/00727.jpg
#   inflating: monet2photo/trainA/00186.jpg
#   inflating: monet2photo/trainA/00325.jpg
#   inflating: monet2photo/trainA/00903.jpg
#   inflating: monet2photo/trainA/00273.jpg
#   inflating: monet2photo/trainA/00544.jpg
#   inflating: monet2photo/trainA/01079.jpg
#   inflating: monet2photo/trainA/00076.jpg
#   inflating: monet2photo/trainA/00431.jpg
#   inflating: monet2photo/trainA/00958.jpg
#   inflating: monet2photo/trainA/01203.jpg
#   inflating: monet2photo/trainA/01332.jpg
#   inflating: monet2photo/trainA/00215.jpg
#   inflating: monet2photo/trainA/00948.jpg
#   inflating: monet2photo/trainA/00367.jpg
#   inflating: monet2photo/trainA/00825.jpg
#   inflating: monet2photo/trainA/01182.jpg
#   inflating: monet2photo/trainA/00618.jpg
#   inflating: monet2photo/trainA/01256.jpg
#   inflating: monet2photo/trainA/00846.jpg
#   inflating: monet2photo/trainA/00671.jpg
#   inflating: monet2photo/trainA/00529.jpg
#   inflating: monet2photo/trainA/00847.jpg
#   inflating: monet2photo/trainA/00715.jpg
#   inflating: monet2photo/trainA/00282.jpg
#   inflating: monet2photo/trainA/00588.jpg
#   inflating: monet2photo/trainA/01155.jpg
#   inflating: monet2photo/trainA/00999.jpg
#   inflating: monet2photo/trainA/00849.jpg
#   inflating: monet2photo/trainA/00247.jpg
#   inflating: monet2photo/trainA/00533.jpg
#   inflating: monet2photo/trainA/00074.jpg
#   inflating: monet2photo/trainA/00423.jpg
#   inflating: monet2photo/trainA/00305.jpg
#   inflating: monet2photo/trainA/00976.jpg
#   inflating: monet2photo/trainA/00974.jpg
#   inflating: monet2photo/trainA/00918.jpg
#   inflating: monet2photo/trainA/00938.jpg
#   inflating: monet2photo/trainA/00887.jpg
#   inflating: monet2photo/trainA/00285.jpg
#   inflating: monet2photo/trainA/01304.jpg
#   inflating: monet2photo/trainA/00874.jpg
#   inflating: monet2photo/trainA/00556.jpg
#   inflating: monet2photo/trainA/00162.jpg
#   inflating: monet2photo/trainA/01249.jpg
#   inflating: monet2photo/trainA/00784.jpg
#   inflating: monet2photo/trainA/00236.jpg
#   inflating: monet2photo/trainA/00926.jpg
#   inflating: monet2photo/trainA/00214.jpg
#   inflating: monet2photo/trainA/00696.jpg
#   inflating: monet2photo/trainA/01173.jpg
#   inflating: monet2photo/trainA/00458.jpg
#   inflating: monet2photo/trainA/00069.jpg
#   inflating: monet2photo/trainA/00025.jpg
#   inflating: monet2photo/trainA/00112.jpg
#   inflating: monet2photo/trainA/01269.jpg
#   inflating: monet2photo/trainA/01113.jpg
#   inflating: monet2photo/trainA/01015.jpg
#   inflating: monet2photo/trainA/00745.jpg
#   inflating: monet2photo/trainA/00736.jpg
#   inflating: monet2photo/trainA/00942.jpg
#   inflating: monet2photo/trainA/00992.jpg
#   inflating: monet2photo/trainA/00648.jpg
#   inflating: monet2photo/trainA/00257.jpg
#   inflating: monet2photo/trainA/00952.jpg
#   inflating: monet2photo/trainA/00843.jpg
#   inflating: monet2photo/trainA/00763.jpg
#   inflating: monet2photo/trainA/00683.jpg
#   inflating: monet2photo/trainA/00264.jpg
#   inflating: monet2photo/trainA/00052.jpg
#   inflating: monet2photo/trainA/00956.jpg
#   inflating: monet2photo/trainA/01309.jpg
#   inflating: monet2photo/trainA/00791.jpg
#   inflating: monet2photo/trainA/00198.jpg
#   inflating: monet2photo/trainA/01232.jpg
#   inflating: monet2photo/trainA/00647.jpg
#   inflating: monet2photo/trainA/00707.jpg
#   inflating: monet2photo/trainA/00941.jpg
#   inflating: monet2photo/trainA/00702.jpg
#   inflating: monet2photo/trainA/00711.jpg
#   inflating: monet2photo/trainA/01135.jpg
#   inflating: monet2photo/trainA/01255.jpg
#   inflating: monet2photo/trainA/01298.jpg
#   inflating: monet2photo/trainA/00405.jpg
#   inflating: monet2photo/trainA/01326.jpg
#   inflating: monet2photo/trainA/01068.jpg
#   inflating: monet2photo/trainA/01185.jpg
#   inflating: monet2photo/trainA/00949.jpg
#   inflating: monet2photo/trainA/00409.jpg
#   inflating: monet2photo/trainA/00203.jpg
#   inflating: monet2photo/trainA/00393.jpg
#   inflating: monet2photo/trainA/00655.jpg
#   inflating: monet2photo/trainA/00519.jpg
#   inflating: monet2photo/trainA/00327.jpg
#   inflating: monet2photo/trainA/01154.jpg
#   inflating: monet2photo/trainA/01005.jpg
#   inflating: monet2photo/trainA/00821.jpg
#   inflating: monet2photo/trainA/00738.jpg
#   inflating: monet2photo/trainA/00354.jpg
#   inflating: monet2photo/trainA/00297.jpg
#   inflating: monet2photo/trainA/00266.jpg
#   inflating: monet2photo/trainA/00804.jpg
#   inflating: monet2photo/trainA/01171.jpg
#   inflating: monet2photo/trainA/00439.jpg
#   inflating: monet2photo/trainA/00743.jpg
#   inflating: monet2photo/trainA/00953.jpg
#   inflating: monet2photo/trainA/01242.jpg
#   inflating: monet2photo/trainA/00364.jpg
#   inflating: monet2photo/trainA/00626.jpg
#   inflating: monet2photo/trainA/00858.jpg
#   inflating: monet2photo/trainA/00697.jpg
#   inflating: monet2photo/trainA/00263.jpg
#   inflating: monet2photo/trainA/01267.jpg
#   inflating: monet2photo/trainA/00401.jpg
#   inflating: monet2photo/trainA/01262.jpg
#   inflating: monet2photo/trainA/01215.jpg
#   inflating: monet2photo/trainA/01013.jpg
#   inflating: monet2photo/trainA/00277.jpg
#   inflating: monet2photo/trainA/00545.jpg
#   inflating: monet2photo/trainA/00728.jpg
#   inflating: monet2photo/trainA/00622.jpg
#   inflating: monet2photo/trainA/01202.jpg
#   inflating: monet2photo/trainA/01199.jpg
#   inflating: monet2photo/trainA/00381.jpg
#   inflating: monet2photo/trainA/00457.jpg
#   inflating: monet2photo/trainA/00783.jpg
#   inflating: monet2photo/trainA/00705.jpg
#   inflating: monet2photo/trainA/01095.jpg
#   inflating: monet2photo/trainA/00814.jpg
#   inflating: monet2photo/trainA/00771.jpg
#   inflating: monet2photo/trainA/00304.jpg
#   inflating: monet2photo/trainA/01336.jpg
#   inflating: monet2photo/trainA/00428.jpg
#   inflating: monet2photo/trainA/01221.jpg
#   inflating: monet2photo/trainA/00229.jpg
#   inflating: monet2photo/trainA/01201.jpg
#   inflating: monet2photo/trainA/01296.jpg
#   inflating: monet2photo/trainA/00216.jpg
#   inflating: monet2photo/trainA/00246.jpg
#   inflating: monet2photo/trainA/00342.jpg
#   inflating: monet2photo/trainA/00317.jpg
#   inflating: monet2photo/trainA/00295.jpg
#   inflating: monet2photo/trainA/00748.jpg
#   inflating: monet2photo/trainA/01165.jpg
#   inflating: monet2photo/trainA/00065.jpg
#   inflating: monet2photo/trainA/00053.jpg
#   inflating: monet2photo/trainA/01213.jpg
#   inflating: monet2photo/trainA/00353.jpg
#   inflating: monet2photo/trainA/00984.jpg
#   inflating: monet2photo/trainA/00042.jpg
#   inflating: monet2photo/trainA/00346.jpg
#   inflating: monet2photo/trainA/00911.jpg
#   inflating: monet2photo/trainA/00889.jpg
#   inflating: monet2photo/trainA/01287.jpg
#   inflating: monet2photo/trainA/01323.jpg
#   inflating: monet2photo/trainA/00746.jpg
#   inflating: monet2photo/trainA/00979.jpg
#   inflating: monet2photo/trainA/01268.jpg
#   inflating: monet2photo/trainA/00751.jpg
#   inflating: monet2photo/trainA/00054.jpg
#   inflating: monet2photo/trainA/01125.jpg
#   inflating: monet2photo/trainA/00427.jpg
#   inflating: monet2photo/trainA/00335.jpg
#   inflating: monet2photo/trainA/01254.jpg
#   inflating: monet2photo/trainA/00734.jpg
#   inflating: monet2photo/trainA/00413.jpg
#   inflating: monet2photo/trainA/01011.jpg
#   inflating: monet2photo/trainA/00794.jpg
#   inflating: monet2photo/trainA/00643.jpg
#   inflating: monet2photo/trainA/00316.jpg
#   inflating: monet2photo/trainA/00425.jpg
#   inflating: monet2photo/trainA/00773.jpg
#   inflating: monet2photo/trainA/01099.jpg
#   inflating: monet2photo/trainA/00932.jpg
#   inflating: monet2photo/trainA/00314.jpg
#   inflating: monet2photo/trainA/00093.jpg
#   inflating: monet2photo/trainA/00666.jpg
#   inflating: monet2photo/trainA/00365.jpg
#   inflating: monet2photo/trainA/00691.jpg
#   inflating: monet2photo/trainA/00303.jpg
#   inflating: monet2photo/trainA/01075.jpg
#   inflating: monet2photo/trainA/00014.jpg
#   inflating: monet2photo/trainA/00376.jpg
#   inflating: monet2photo/trainA/00057.jpg
#   inflating: monet2photo/trainA/00397.jpg
#   inflating: monet2photo/trainA/00165.jpg
#   inflating: monet2photo/trainA/00271.jpg
#   inflating: monet2photo/trainA/00703.jpg
#   inflating: monet2photo/trainA/01143.jpg
#   inflating: monet2photo/trainA/01101.jpg
#   inflating: monet2photo/trainA/00267.jpg
#   inflating: monet2photo/trainA/01151.jpg
#   inflating: monet2photo/trainA/00902.jpg
#   inflating: monet2photo/trainA/01126.jpg
#   inflating: monet2photo/trainA/00044.jpg
#   inflating: monet2photo/trainA/00496.jpg
#    creating: monet2photo/testB/
#   inflating: monet2photo/testB/2014-12-10 12:08:40.jpg
#   inflating: monet2photo/testB/2014-12-20 00:58:53.jpg
#   inflating: monet2photo/testB/2014-12-21 22:11:41.jpg
#   inflating: monet2photo/testB/2015-04-26 11:40:43.jpg
#   inflating: monet2photo/testB/2014-08-27 17:27:14.jpg
#   inflating: monet2photo/testB/2015-04-15 13:13:59.jpg
#   inflating: monet2photo/testB/2014-08-11 11:35:13.jpg
#   inflating: monet2photo/testB/2014-08-30 19:16:07.jpg
#   inflating: monet2photo/testB/2014-08-12 20:42:52.jpg
#   inflating: monet2photo/testB/2015-04-06 10:32:42.jpg
#   inflating: monet2photo/testB/2014-08-23 16:23:43.jpg
#   inflating: monet2photo/testB/2014-12-23 11:29:45.jpg
# ...
#   inflating: monet2photo/trainB/2016-06-05 03:03:14.jpg
#   inflating: monet2photo/trainB/2015-01-29 19:20:30.jpg
#   inflating: monet2photo/trainB/2015-10-18 05:48:32.jpg
#   inflating: monet2photo/trainB/2016-01-02 10:59:53.jpg
#   inflating: monet2photo/trainB/2015-12-30 16:31:27.jpg
#   inflating: monet2photo/trainB/2015-03-05 19:33:03.jpg
#   inflating: monet2photo/trainB/2016-12-06 07:05:38.jpg
#   inflating: monet2photo/trainB/2014-07-29 04:20:01.jpg
#   inflating: monet2photo/trainB/2014-07-07 01:42:02.jpg
#   inflating: monet2photo/trainB/2015-02-23 14:05:56.jpg
#   inflating: monet2photo/trainB/2016-01-03 14:22:35.jpg
#   inflating: monet2photo/trainB/2016-03-11 16:41:34.jpg
#   inflating: monet2photo/trainB/2014-01-09 22:13:22.jpg
#   inflating: monet2photo/trainB/2016-08-04 06:00:46.jpg
#   inflating: monet2photo/trainB/2014-04-22 21:34:56.jpg
#   inflating: monet2photo/trainB/2015-07-05 20:16:49.jpg
#   inflating: monet2photo/trainB/2016-07-04 21:08:16.jpg
#   inflating: monet2photo/trainB/2016-01-01 04:43:06.jpg
#   inflating: monet2photo/trainB/2014-11-18 05:09:59.jpg
#   inflating: monet2photo/trainB/2014-04-21 09:39:02.jpg
#   inflating: monet2photo/trainB/2016-07-04 21:12:39.jpg
#   inflating: monet2photo/trainB/2015-03-22 17:08:54.jpg
#   inflating: monet2photo/trainB/2015-09-30 08:16:12.jpg
#   inflating: monet2photo/trainB/2015-06-17 15:03:41.jpg
#   inflating: monet2photo/trainB/2016-12-04 09:13:18.jpg
#   inflating: monet2photo/trainB/2016-11-29 19:47:41.jpg
#   inflating: monet2photo/trainB/2016-04-18 19:32:57.jpg
#   inflating: monet2photo/trainB/2016-03-09 05:34:11.jpg
#   inflating: monet2photo/trainB/2015-10-13 08:20:13.jpg
#   inflating: monet2photo/trainB/2016-05-04 05:29:28.jpg
#   inflating: monet2photo/trainB/2014-05-19 12:26:07.jpg
#   inflating: monet2photo/trainB/2014-06-08 12:08:42.jpg
#   inflating: monet2photo/trainB/2015-07-11 15:58:12.jpg
#   inflating: monet2photo/trainB/2014-01-30 15:34:49.jpg
#   inflating: monet2photo/trainB/2017-01-03 00:02:26.jpg
#   inflating: monet2photo/trainB/2015-08-01 19:52:36.jpg
#   inflating: monet2photo/trainB/2015-11-18 07:30:39.jpg
#   inflating: monet2photo/trainB/2015-09-09 19:09:28.jpg
#   inflating: monet2photo/trainB/2015-12-13 07:24:05.jpg
#   inflating: monet2photo/trainB/2016-11-19 07:28:09.jpg
#   inflating: monet2photo/trainB/2016-08-16 12:08:04.jpg
#   inflating: monet2photo/trainB/2016-03-16 14:44:34.jpg
#   inflating: monet2photo/trainB/2016-04-06 11:15:15.jpg
#   inflating: monet2photo/trainB/2015-11-14 16:27:58.jpg
#   inflating: monet2photo/trainB/2015-07-12 01:28:57.jpg
#   inflating: monet2photo/trainB/2014-01-04 08:22:15.jpg
#   inflating: monet2photo/trainB/2016-12-06 11:29:13.jpg
#   inflating: monet2photo/trainB/2016-07-03 08:57:43.jpg
#   inflating: monet2photo/trainB/2016-12-05 04:55:15.jpg
#   inflating: monet2photo/trainB/2016-08-07 02:33:26.jpg
#   inflating: monet2photo/trainB/2016-12-02 16:24:37.jpg
#   inflating: monet2photo/trainB/2015-12-15 12:20:09.jpg
#   inflating: monet2photo/trainB/2015-09-13 21:58:55.jpg
#   inflating: monet2photo/trainB/2016-07-24 09:20:25.jpg
#   inflating: monet2photo/trainB/2016-08-01 04:47:22.jpg
#   inflating: monet2photo/trainB/2015-10-11 15:15:50.jpg
#   inflating: monet2photo/trainB/2015-03-27 00:08:14.jpg
#   inflating: monet2photo/trainB/2015-07-17 21:46:42.jpg
#   inflating: monet2photo/trainB/2015-09-27 03:50:37.jpg
#   inflating: monet2photo/trainB/2015-11-24 18:58:57.jpg
#   inflating: monet2photo/trainB/2014-01-30 08:07:48.jpg
#   inflating: monet2photo/trainB/2016-02-07 22:18:04.jpg
#   inflating: monet2photo/trainB/2016-08-11 21:13:15.jpg
#   inflating: monet2photo/trainB/2015-03-24 11:18:25.jpg
#   inflating: monet2photo/trainB/2016-03-30 20:31:17.jpg
#   inflating: monet2photo/trainB/2016-08-29 07:56:39.jpg
#   inflating: monet2photo/trainB/2016-03-02 23:09:59.jpg
#   inflating: monet2photo/trainB/2016-03-01 09:42:29.jpg
#   inflating: monet2photo/trainB/2015-03-07 12:23:57.jpg
#   inflating: monet2photo/trainB/2015-03-25 19:09:29.jpg
#   inflating: monet2photo/trainB/2014-01-01 02:27:26.jpg
#   inflating: monet2photo/trainB/2014-01-05 23:43:14.jpg
#   inflating: monet2photo/trainB/2015-07-22 21:41:14.jpg
#   inflating: monet2photo/trainB/2015-05-02 03:29:29.jpg
#   inflating: monet2photo/trainB/2016-01-25 13:58:38.jpg
#   inflating: monet2photo/trainB/2015-06-14 08:22:41.jpg
#   inflating: monet2photo/trainB/2016-01-30 07:20:49.jpg
#   inflating: monet2photo/trainB/2015-05-28 22:03:58.jpg
#   inflating: monet2photo/trainB/2013-11-29 03:08:00.jpg
#   inflating: monet2photo/trainB/2015-12-17 07:59:28.jpg
#   inflating: monet2photo/trainB/2016-05-14 01:46:35.jpg
#   inflating: monet2photo/trainB/2015-09-24 14:20:57.jpg
#   inflating: monet2photo/trainB/2016-05-19 17:12:46.jpg
#   inflating: monet2photo/trainB/2014-04-04 22:54:00.jpg
#   inflating: monet2photo/trainB/2014-05-07 14:29:41.jpg
#   inflating: monet2photo/trainB/2013-12-16 20:09:22.jpg
#   inflating: monet2photo/trainB/2016-05-26 08:35:52.jpg
#   inflating: monet2photo/trainB/2015-08-09 14:45:09.jpg
#   inflating: monet2photo/trainB/2014-03-09 00:20:16.jpg
#   inflating: monet2photo/trainB/2014-01-11 05:11:24.jpg
#   inflating: monet2photo/trainB/2015-09-16 04:20:08.jpg
#   inflating: monet2photo/trainB/2015-12-08 14:14:33.jpg
#   inflating: monet2photo/trainB/2015-02-01 05:38:28.jpg
#   inflating: monet2photo/trainB/2015-09-30 12:11:31.jpg
#   inflating: monet2photo/trainB/2015-05-06 17:29:28.jpg
#   inflating: monet2photo/trainB/2015-12-05 10:08:37.jpg
#   inflating: monet2photo/trainB/2014-02-10 08:25:06.jpg
#   inflating: monet2photo/trainB/2015-05-30 23:27:29.jpg
#   inflating: monet2photo/trainB/2016-06-07 17:01:47.jpg
#   inflating: monet2photo/trainB/2015-01-22 10:24:53.jpg
#   inflating: monet2photo/trainB/2015-07-29 03:59:07.jpg
#   inflating: monet2photo/trainB/2016-03-27 06:35:55.jpg
#   inflating: monet2photo/trainB/2015-11-24 12:12:37.jpg
#   inflating: monet2photo/trainB/2016-06-07 05:43:11.jpg
#   inflating: monet2photo/trainB/2016-03-25 11:17:33.jpg
#   inflating: monet2photo/trainB/2015-10-17 08:54:04.jpg
#   inflating: monet2photo/trainB/2014-01-25 03:23:05.jpg
#   inflating: monet2photo/trainB/2016-04-17 22:49:51.jpg
#   inflating: monet2photo/trainB/2015-07-21 13:47:09.jpg
#   inflating: monet2photo/trainB/2015-08-27 11:11:45.jpg
#   inflating: monet2photo/trainB/2014-07-09 15:07:35.jpg
#   inflating: monet2photo/trainB/2015-10-29 06:18:37.jpg
#   inflating: monet2photo/trainB/2015-07-26 14:29:27.jpg
#   inflating: monet2photo/trainB/2015-07-13 15:01:26.jpg
#   inflating: monet2photo/trainB/2016-03-14 08:38:41.jpg
#   inflating: monet2photo/trainB/2016-04-18 01:18:33.jpg
#   inflating: monet2photo/trainB/2014-02-26 17:44:32.jpg
#   inflating: monet2photo/trainB/2016-06-29 03:53:18.jpg
#   inflating: monet2photo/trainB/2016-06-08 07:00:53.jpg
#   inflating: monet2photo/trainB/2015-10-27 17:06:56.jpg
#   inflating: monet2photo/trainB/2014-06-13 23:59:31.jpg
#   inflating: monet2photo/trainB/2015-07-05 10:40:15.jpg
#   inflating: monet2photo/trainB/2016-08-06 05:12:09.jpg
#   inflating: monet2photo/trainB/2016-01-12 00:13:04.jpg
#   inflating: monet2photo/trainB/2016-08-31 13:16:25.jpg
#   inflating: monet2photo/trainB/2015-06-21 13:11:25.jpg
#   inflating: monet2photo/trainB/2016-01-04 20:31:51.jpg
#   inflating: monet2photo/trainB/2015-02-28 20:18:08.jpg
#   inflating: monet2photo/trainB/2013-12-15 06:08:02.jpg
#   inflating: monet2photo/trainB/2016-05-02 01:01:50.jpg
#   inflating: monet2photo/trainB/2015-09-02 09:48:35.jpg
#   inflating: monet2photo/trainB/2015-07-18 22:13:20.jpg
#   inflating: monet2photo/trainB/2014-07-01 00:14:40.jpg
#   inflating: monet2photo/trainB/2014-06-05 15:59:58.jpg
#   inflating: monet2photo/trainB/2016-08-25 14:50:48.jpg
#   inflating: monet2photo/trainB/2015-08-07 06:53:15.jpg
#   inflating: monet2photo/trainB/2014-11-26 03:54:14.jpg
#   inflating: monet2photo/trainB/2014-05-05 04:15:15.jpg
#   inflating: monet2photo/trainB/2013-11-08 16:45:24.jpg
#   inflating: monet2photo/trainB/2016-07-03 06:04:34.jpg
#   inflating: monet2photo/trainB/2014-06-23 17:57:10.jpg
#   inflating: monet2photo/trainB/2016-04-12 10:45:28.jpg
#   inflating: monet2photo/trainB/2015-06-03 09:28:24.jpg
#   inflating: monet2photo/trainB/2016-06-06 15:58:16.jpg
#   inflating: monet2photo/trainB/2014-06-03 12:35:02.jpg
#   inflating: monet2photo/trainB/2016-07-13 12:06:48.jpg
#   inflating: monet2photo/trainB/2015-01-17 16:17:38.jpg
#   inflating: monet2photo/trainB/2016-01-26 08:41:15.jpg
#   inflating: monet2photo/trainB/2016-11-28 09:42:07.jpg
#   inflating: monet2photo/trainB/2016-04-17 12:06:23.jpg
#   inflating: monet2photo/trainB/2016-03-19 01:29:06.jpg
#   inflating: monet2photo/trainB/2016-05-21 06:00:05.jpg
#   inflating: monet2photo/trainB/2015-07-09 13:21:34.jpg
#   inflating: monet2photo/trainB/2015-10-17 05:22:21.jpg
#   inflating: monet2photo/trainB/2016-05-07 21:15:32.jpg
#   inflating: monet2photo/trainB/2016-08-17 18:41:50.jpg
#   inflating: monet2photo/trainB/2016-04-05 05:34:31.jpg
#   inflating: monet2photo/trainB/2016-11-25 00:01:50.jpg
#   inflating: monet2photo/trainB/2015-03-08 11:36:11.jpg
#   inflating: monet2photo/trainB/2015-12-28 09:52:30.jpg
#   inflating: monet2photo/trainB/2015-10-18 16:01:35.jpg
#   inflating: monet2photo/trainB/2015-11-24 14:23:25.jpg
#   inflating: monet2photo/trainB/2016-08-15 09:27:14.jpg
#   inflating: monet2photo/trainB/2015-12-02 00:26:57.jpg
#   inflating: monet2photo/trainB/2015-03-02 19:10:47.jpg
#   inflating: monet2photo/trainB/2014-02-01 23:54:02.jpg
#   inflating: monet2photo/trainB/2016-02-09 01:36:29.jpg
#   inflating: monet2photo/trainB/2016-01-01 11:24:26.jpg
#   inflating: monet2photo/trainB/2016-01-17 04:12:05.jpg
#   inflating: monet2photo/trainB/2015-06-04 21:11:04.jpg
#   inflating: monet2photo/trainB/2016-11-26 01:56:56.jpg
#   inflating: monet2photo/trainB/2015-08-15 04:09:41.jpg
#   inflating: monet2photo/trainB/2016-06-09 05:44:30.jpg
#   inflating: monet2photo/trainB/2014-02-27 22:35:01.jpg
#   inflating: monet2photo/trainB/2015-12-05 00:37:07.jpg
#   inflating: monet2photo/trainB/2015-06-20 17:24:46.jpg
#   inflating: monet2photo/trainB/2015-11-19 01:56:28.jpg
#   inflating: monet2photo/trainB/2016-04-19 15:14:48.jpg
#   inflating: monet2photo/trainB/2016-07-02 10:51:28.jpg
#   inflating: monet2photo/trainB/2015-12-14 11:26:36.jpg
#   inflating: monet2photo/trainB/2015-12-04 18:15:53.jpg
#   inflating: monet2photo/trainB/2015-05-18 13:55:02.jpg
#   inflating: monet2photo/trainB/2014-03-03 09:20:36.jpg
#   inflating: monet2photo/trainB/2014-11-01 03:04:22.jpg
#   inflating: monet2photo/trainB/2015-05-28 02:38:04.jpg
#    creating: monet2photo/testA/
#   inflating: monet2photo/testA/01190.jpg
#   inflating: monet2photo/testA/01120.jpg
#   inflating: monet2photo/testA/00360.jpg
#   inflating: monet2photo/testA/00940.jpg
#   inflating: monet2photo/testA/01230.jpg
#   inflating: monet2photo/testA/01240.jpg
#   inflating: monet2photo/testA/00300.jpg
#   inflating: monet2photo/testA/00700.jpg
#   inflating: monet2photo/testA/00810.jpg
#   inflating: monet2photo/testA/01260.jpg
#   inflating: monet2photo/testA/01020.jpg
#   inflating: monet2photo/testA/00020.jpg
#   inflating: monet2photo/testA/00840.jpg
#   inflating: monet2photo/testA/00980.jpg
#   inflating: monet2photo/testA/00930.jpg
#   inflating: monet2photo/testA/00420.jpg
#   inflating: monet2photo/testA/00620.jpg
#   inflating: monet2photo/testA/00030.jpg
#   inflating: monet2photo/testA/00880.jpg
#   inflating: monet2photo/testA/01030.jpg
#   inflating: monet2photo/testA/00110.jpg
#   inflating: monet2photo/testA/00490.jpg
#   inflating: monet2photo/testA/00120.jpg
#   inflating: monet2photo/testA/00130.jpg
#   inflating: monet2photo/testA/00890.jpg
#   inflating: monet2photo/testA/00900.jpg
#   inflating: monet2photo/testA/00770.jpg
#   inflating: monet2photo/testA/00390.jpg
#   inflating: monet2photo/testA/01000.jpg
#   inflating: monet2photo/testA/00350.jpg
#   inflating: monet2photo/testA/00100.jpg
#   inflating: monet2photo/testA/01050.jpg
#   inflating: monet2photo/testA/00180.jpg
#   inflating: monet2photo/testA/00480.jpg
#   inflating: monet2photo/testA/01040.jpg
#   inflating: monet2photo/testA/00410.jpg
#   inflating: monet2photo/testA/01330.jpg
#   inflating: monet2photo/testA/01110.jpg
#   inflating: monet2photo/testA/01160.jpg
#   inflating: monet2photo/testA/01310.jpg
#   inflating: monet2photo/testA/00780.jpg
#   inflating: monet2photo/testA/00400.jpg
#   inflating: monet2photo/testA/00440.jpg
#   inflating: monet2photo/testA/01070.jpg
#   inflating: monet2photo/testA/00450.jpg
#   inflating: monet2photo/testA/00740.jpg
#   inflating: monet2photo/testA/00170.jpg
#   inflating: monet2photo/testA/01010.jpg
#   inflating: monet2photo/testA/00280.jpg
#   inflating: monet2photo/testA/00690.jpg
#   inflating: monet2photo/testA/00750.jpg
#   inflating: monet2photo/testA/00790.jpg
#   inflating: monet2photo/testA/00250.jpg
#   inflating: monet2photo/testA/00080.jpg
#   inflating: monet2photo/testA/00760.jpg
#   inflating: monet2photo/testA/00470.jpg
#   inflating: monet2photo/testA/00540.jpg
#   inflating: monet2photo/testA/00310.jpg
#   inflating: monet2photo/testA/00800.jpg
#   inflating: monet2photo/testA/00680.jpg
#   inflating: monet2photo/testA/01180.jpg
#   inflating: monet2photo/testA/01090.jpg
#   inflating: monet2photo/testA/00600.jpg
#   inflating: monet2photo/testA/00850.jpg
#   inflating: monet2photo/testA/01060.jpg
#   inflating: monet2photo/testA/00010.jpg
#   inflating: monet2photo/testA/00870.jpg
#   inflating: monet2photo/testA/00160.jpg
#   inflating: monet2photo/testA/00990.jpg
#   inflating: monet2photo/testA/01290.jpg
#   inflating: monet2photo/testA/00380.jpg
#   inflating: monet2photo/testA/01150.jpg
#   inflating: monet2photo/testA/01080.jpg
#   inflating: monet2photo/testA/01210.jpg
#   inflating: monet2photo/testA/01220.jpg
#   inflating: monet2photo/testA/00500.jpg
#   inflating: monet2photo/testA/00920.jpg
#   inflating: monet2photo/testA/00820.jpg
#   inflating: monet2photo/testA/00090.jpg
#   inflating: monet2photo/testA/00710.jpg
#   inflating: monet2photo/testA/00240.jpg
#   inflating: monet2photo/testA/00650.jpg
#   inflating: monet2photo/testA/00330.jpg
#   inflating: monet2photo/testA/01130.jpg
#   inflating: monet2photo/testA/00860.jpg
#   inflating: monet2photo/testA/01200.jpg
#   inflating: monet2photo/testA/00220.jpg
#   inflating: monet2photo/testA/01100.jpg
#   inflating: monet2photo/testA/00260.jpg
#   inflating: monet2photo/testA/00070.jpg
#   inflating: monet2photo/testA/00730.jpg
#   inflating: monet2photo/testA/00640.jpg
#   inflating: monet2photo/testA/00520.jpg
#   inflating: monet2photo/testA/01300.jpg
#   inflating: monet2photo/testA/00950.jpg
#   inflating: monet2photo/testA/00140.jpg
#   inflating: monet2photo/testA/01250.jpg
#   inflating: monet2photo/testA/00855.jpg
#   inflating: monet2photo/testA/01270.jpg
#   inflating: monet2photo/testA/01280.jpg
#   inflating: monet2photo/testA/00590.jpg
#   inflating: monet2photo/testA/00550.jpg
#   inflating: monet2photo/testA/00970.jpg
#   inflating: monet2photo/testA/00290.jpg
#   inflating: monet2photo/testA/00040.jpg
#   inflating: monet2photo/testA/00910.jpg
#   inflating: monet2photo/testA/00610.jpg
#   inflating: monet2photo/testA/00150.jpg
#   inflating: monet2photo/testA/00320.jpg
#   inflating: monet2photo/testA/00270.jpg
#   inflating: monet2photo/testA/01140.jpg
#   inflating: monet2photo/testA/00670.jpg
#   inflating: monet2photo/testA/00830.jpg
#   inflating: monet2photo/testA/00050.jpg
#   inflating: monet2photo/testA/00960.jpg
#   inflating: monet2photo/testA/00430.jpg
#   inflating: monet2photo/testA/00060.jpg
#   inflating: monet2photo/testA/00210.jpg
#   inflating: monet2photo/testA/00190.jpg
#   inflating: monet2photo/testA/00200.jpg
#   inflating: monet2photo/testA/00460.jpg

# %%
import time
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import PIL

from glob import glob
from keras import Input, Model
from keras.callbacks import TensorBoard
from keras.layers import Conv2D, BatchNormalization, Activation
from keras.layers import Add, Conv2DTranspose, ZeroPadding2D, LeakyReLU
from keras.optimizers import Adam
from imageio import imread
from skimage.transform import resize
# Out:
# Using TensorFlow backend.

# %%
# !pip install git+https://www.github.com/keras-team/keras-contrib.git
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-s_z8f_t6
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-s_z8f_t6
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras-contrib==2.0.8) (2.2.4)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.12.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.3.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (2.8.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.16.4)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.1.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (3.13)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-cp36-none-any.whl size=101066 sha256=cfc88de5fa2eac3e2695288ecdf4f8de4699b739e42455ffe03a614c72c4b121
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pzwn1cn5/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# Installing collected packages: keras-contrib
# Successfully installed keras-contrib-2.0.8

# %%
from keras_contrib.layers.normalization.instancenormalization import InstanceNormalization

# %% [markdown]
# ## Residual Block

# %%
def residual_block(x):
  
  """
  Residual block
  """
  
  res = Conv2D(filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
  res = BatchNormalization(axis = 3, momentum = 0.9, epsilon = 1e-5)(res)
  res = Activation('relu')(res)
  res = Conv2D(filters = 128, kernel_size = 3, strides = 1, padding = "same")(res)
  res = BatchNormalization(axis = 3, momentum = 0.9, epsilon = 1e-5)(res)
  
  return Add()([res, x])

# %% [markdown]
# ## Generator Network

# %%
def build_generator():
  
  """
  Creating a generator network with the hyperparameters defined below
  """
  
  input_shape = (128, 128, 3)
  residual_blocks = 6
  input_layer = Input(shape = input_shape)
  
  
  ## 1st Convolutional Block
  x = Conv2D(filters = 32, kernel_size = 7, strides = 1, padding = "same")(input_layer)
  x = InstanceNormalization(axis = 1)(x)
  x = Activation("relu")(x)
  
  ## 2nd Convolutional Block
  x = Conv2D(filters = 64, kernel_size = 3, strides = 2, padding = "same")(x)
  x = InstanceNormalization(axis = 1)(x)
  x = Activation("relu")(x)
  
  ## 3rd Convolutional Block
  x = Conv2D(filters = 128, kernel_size = 3, strides = 2, padding = "same")(x)
  x = InstanceNormalization(axis = 1)(x)
  x = Activation("relu")(x)
  
  
  ## Residual blocks
  for _ in range(residual_blocks):
    x = residual_block(x)
  
  
  ## 1st Upsampling Block
  x = Conv2DTranspose(filters = 64, kernel_size = 3, strides = 2, padding = "same", use_bias = False)(x)
  x = InstanceNormalization(axis = 1)(x)
  x = Activation("relu")(x)
  
  ## 2nd Upsampling Block
  x = Conv2DTranspose(filters = 32, kernel_size = 3, strides = 2, padding = "same", use_bias = False)(x)
  x = InstanceNormalization(axis = 1)(x)
  x = Activation("relu")(x)
  
  ## Last Convolutional Layer
  x = Conv2D(filters = 3, kernel_size = 7, strides = 1, padding = "same")(x)
  output = Activation("tanh")(x)
  
  
  model = Model(inputs = [input_layer], outputs = [output])
  return model

# %% [markdown]
# ## Discriminator Network

# %%
def build_discriminator():
  
  """
  Create a discriminator network using the hyperparameters defined below
  """
  
  input_shape = (128, 128, 3)
  hidden_layers = 3
  
  input_layer = Input(shape = input_shape)
  
  x = ZeroPadding2D(padding = (1, 1))(input_layer)
  
  
  ## 1st Convolutional Block
  x = Conv2D(filters = 64, kernel_size = 4, strides = 2, padding = "valid")(x)
  x = LeakyReLU(alpha = 0.2)(x)
  
  x = ZeroPadding2D(padding = (1, 1))(x)
  
  
  ## 3 Hidden Convolutional Blocks
  for i in range(1, hidden_layers + 1):
    x = Conv2D(filters = 2 ** i * 64, kernel_size = 4, strides = 2, padding = "valid")(x)
    x = InstanceNormalization(axis = 1)(x)
    x = LeakyReLU(alpha = 0.2)(x)
    
    x = ZeroPadding2D(padding = (1, 1))(x)
    
  
  ## Last Convolutional Layer
  output = Conv2D(filters = 1, kernel_size = 4, strides = 1, activation = "sigmoid")(x)
  
  
  model = Model(inputs = [input_layer], outputs = [output])
  return model

# %%
def load_images(data_dir):
  
  imagesA = glob(data_dir + '/testA/*.*')
  imagesB = glob(data_dir + '/testB/*.*')
  
  allImagesA = []
  allImagesB = []
  
  for index, filename in enumerate(imagesA):
    imgA = imread(filename, pilmode = "RGB")
    imgB = imread(imagesB[index], pilmode = "RGB")
    
    imgA = resize(imgA, (128, 128))
    imgB = resize(imgB, (128, 128))
    
    if np.random.random() > 0.5:
      imgA = np.fliplr(imgA)
      imgB = np.fliplr(imgB)
      
    
    allImagesA.append(imgA)
    allImagesB.append(imgB)
    
  
  ## Normalize images
  allImagesA = np.array(allImagesA) / 127.5 - 1.
  allImagesB = np.array(allImagesB) / 127.5 - 1.
  
  return allImagesA, allImagesB

# %%
def load_test_batch(data_dir, batch_size):
  
  imagesA = glob(data_dir + '/testA/*.*')
  imagesB = glob(data_dir + '/testB/*.*')
  
  imagesA = np.random.choice(a = imagesA, size = batch_size)
  imagesB = np.random.choice(a = imagesB, size = batch_size)
  
  allA = []
  allB = []
  
  for i in range(len(imagesA)):
    ## Load and resize images
    imgA = resize(imread(imagesA[i], pilmode = 'RGB').astype(np.float32), (128, 128))
    imgB = resize(imread(imagesB[i], pilmode = 'RGB').astype(np.float32), (128, 128))
    
    allA.append(imgA)
    allB.append(imgB)
    
  return np.array(allA) / 127.5 - 1.0, np.array(allB) / 127.5 - 1.0

# %%
# !mkdir results

def save_images(originalA, generatedB, reconstructedA,
                originalB, generatedA, reconstructedB, path):
  
  """
  Save images
  """
  
  fig = plt.figure()
  
  ax = fig.add_subplot(2, 3, 1)
  ax.imshow(originalA)
  ax.axis("off")
  ax.set_title("Original")
  
  ax = fig.add_subplot(2, 3, 2)
  ax.imshow(generatedB)
  ax.axis("off")
  ax.set_title("Generated")
  
  ax = fig.add_subplot(2, 3, 3)
  ax.imshow(reconstructedA)
  ax.axis("off")
  ax.set_title("Reconstructed")
  
  ax = fig.add_subplot(2, 3, 4)
  ax.imshow(originalB)
  ax.axis("off")
  ax.set_title("Original")
  
  ax = fig.add_subplot(2, 3, 5)
  ax.imshow(generatedA)
  ax.axis("off")
  ax.set_title("Generated")
  
  ax = fig.add_subplot(2, 3, 6)
  ax.imshow(reconstructedB)
  ax.axis("off")
  ax.set_title("Reconstructed")
  
  plt.savefig(path)

# %%
def write_log(callback, name, loss, batch_no):
  
  """
  Write training summary to TensorBoard
  """
  
  summary = tf.Summary()
  summary_value = summary.value.add()
  summary_value.simple_value = loss
  summary_value.tag = name
  callback.writer.add_summary(summary, batch_no)
  callback.writer.flush()

# %%
if __name__ == '__main__':
  
  data_dir = "monet2photo"
  batch_size = 1
  epochs = 500
  mode = 'train'
  
  if mode == 'train':
    
    """
    Load dataset
    """
    
    imagesA, imagesB = load_images(data_dir = data_dir)
    
    ## Define the common optimizer
    common_optimizer = Adam(0.002, 0.5)
    
    
    ## Build and compile discriminator networks
    discriminatorA = build_discriminator()
    discriminatorB = build_discriminator()
    
    discriminatorA.compile(loss = 'mse', 
                           optimizer = common_optimizer,
                           metrics = ['accuracy'])
    discriminatorB.compile(loss = 'mse',
                           optimizer = common_optimizer,
                           metrics = ['accuracy'])
    
    
    ## Build generator networks
    generatorA_to_B = build_generator()
    generatorB_to_A = build_generator()
    
    
    """
    Create an adversarial network
    """
    
    inputA = Input(shape = (128, 128, 3))
    inputB = Input(shape = (128, 128, 3))
    
    
    ## --> Generated images using both of the generator networks
    generatedB = generatorA_to_B(inputA)
    generatedA = generatorB_to_A(inputB)
    
    
    ## --> Reconstruct the images back to the original ones
    reconstructedA = generatorB_to_A(generatedB)
    reconstructedB = generatorA_to_B(generatedA)
    
    generatedA_Id = generatorB_to_A(inputA)
    generatedB_Id = generatorA_to_B(inputB)
    
    
    ## Make both of the discriminator networks non-trainable
    discriminatorA.trainable = False
    discriminatorB.trainable = False
    
    probsA = discriminatorA(generatedA)
    probsB = discriminatorB(generatedB)
    
    
    adversarial_model = Model(inputs = [inputA, inputB],
                              outputs = [probsA, probsB, 
                                         reconstructedA, reconstructedB,
                                         generatedA_Id, generatedB_Id])
    
    adversarial_model.compile(loss = ['mse', 'mse', 'mae', 'mae', 'mae', 'mae'],
                              loss_weights = [1, 1, 10.0, 10.0, 1.0, 1.0],
                              optimizer = common_optimizer)
    
    
    tensorboard = TensorBoard(log_dir = "logs/{}".format(time.time()),
                              write_images = True, write_grads = True,
                              write_graph = True)
    tensorboard.set_model(generatorA_to_B)
    tensorboard.set_model(generatorB_to_A)
    tensorboard.set_model(discriminatorA)
    tensorboard.set_model(discriminatorB)
    
    
    real_labels = np.ones((batch_size, 7, 7, 1))
    fake_labels = np.zeros((batch_size, 7, 7, 1))
    
    for epoch in range(epochs):
      print("Epoch: {}".format(epoch))
      
      D_losses = []
      G_losses = []
      
      num_batches = int(min(imagesA.shape[0], imagesB.shape[0]) / batch_size)
      print("Number of batches: {}".format(num_batches))
      
      
      for index in range(num_batches):
        print("Batch: {}".format(index))
        
        ## Sample images
        batchA = imagesA[index * batch_size: (index + 1) * batch_size]
        batchB = imagesB[index * batch_size: (index + 1) * batch_size]
        
        ## Translate images to opposite domain
        generatedB = generatorA_to_B.predict(batchA)
        generatedA = generatorB_to_A.predict(batchB)
        
        ## Train the discriminator A on real and fake images
        D_A_Loss1 = discriminatorA.train_on_batch(batchA, real_labels)
        D_A_Loss2 = discriminatorA.train_on_batch(generatedA, fake_labels)
        
        ## Train the discriminator B on real and fake images
        D_B_Loss1 = discriminatorB.train_on_batch(batchB, real_labels)
        D_B_Loss2 = discriminatorB.train_on_batch(generatedB, fake_labels)
        
        ## Calculate the total discriminator loss
        D_loss = 0.5 * np.add(0.5 * np.add(D_A_Loss1, D_A_Loss2), 
                              0.5 * np.add(D_B_Loss1, D_B_Loss2))
        
        print("D_Loss: {}".format(D_loss))
        
        
        """
        Train the generator networks
        """
        
        G_loss = adversarial_model.train_on_batch([batchA, batchB],
                                                  [real_labels, real_labels,
                                                   batchA, batchB,
                                                   batchA, batchB])
        
        print("G_Loss: {}".format(G_loss))
        
        D_losses.append(D_loss)
        G_losses.append(G_loss)
        
        
      """
      Save losses to TensorBoard after every epoch
      """
      
      write_log(tensorboard, 'discriminator_loss', np.mean(D_losses), epoch)
      write_log(tensorboard, 'generator_loss', np.mean(G_losses), epoch)
      
      
      ## Sample and save images after every 10 epochs
      if epoch % 10 == 0:
        
        ## Get a batch of test data
        batchA, batchB = load_test_batch(data_dir = data_dir, batch_size = 2)
        
        ## Generate images
        generatedB = generatorA_to_B.predict(batchA)
        generatedA = generatorB_to_A.predict(batchB)
        
        ## Get reconstructed images
        recons_A = generatorB_to_A.predict(generatedB)
        recons_B = generatorA_to_B.predict(generatedA)
        
        ## Save original, generated and reconstructed images
        for i in range(len(generatedA)):
          save_images(originalA = batchA[i], generatedB = generatedB[i], reconstructedA = recons_A[i],
                      originalB = batchB[i], generatedA = generatedA[i], reconstructedB = recons_B[i],
                      path = "results/gen_{}_{}".format(epoch, i))
          
    
    ## Save models
    generatorA_to_B.save_weights("generatorA_to_B.h5")
    generatorB_to_A.save_weights("generatorB_to_A.h5")
    discriminatorA.save_weights("discriminatorA.h5")
    discriminatorB.save_weights("discriminatorB.h5")
    
    
  elif mode == 'predict':
    
    ## Build generator networks
    generatorA_to_B = build_generator()
    generatorB_to_A = build_generator()
    
    generatorA_to_B.load_weights("generatorA_to_B.h5")
    generatorB_to_A.load_weights("generatorB_to_A.h5")
    
    
    ## Get a batch of test data
    batchA, batchB = load_test_batch(data_dir = data_dir, batch_size = 2)
    
    
    ## Save images
    generatedB = generatorA_to_B.predict(batchA)
    generatedA = generatorB_to_A.predict(batchB)
    
    reconsA = generatorB_to_A.predict(generatedB)
    reconsB = generatorA_to_B.predict(generatedA)
    
    for i in range(len(generatedA)):
      save_images(originalA = batchA[i], generatedB = generatedB[i], reconstructedA = recons_A[i],
                  originalB = batchB[i], generatedA = generatedA[i], reconstructedB = recons_B[i],
                  path = "results/test_{}".format(i))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0822 12:57:49.734445 139716881598336 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0822 12:57:49.736517 139716881598336 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0822 12:57:49.752670 139716881598336 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0822 12:57:50.060953 139716881598336 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0822 12:57:50.235987 139716881598336 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0822 12:57:50.237730 139716881598336 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0822 12:57:53.725808 139716881598336 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0822 12:58:08.037763 139716881598336 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:850: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# W0822 12:58:08.039646 139716881598336 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:853: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# Epoch: 0
# Number of batches: 121
# Batch: 0
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# D_Loss: [0.5305587  0.49489796]
# G_Loss: [25.205275, 5.0539395e-09, 6.623143e-08, 1.2187737, 1.0739226, 1.2182144, 1.0600963]
# Batch: 1
# D_Loss: [0.4999975 0.5      ]
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# G_Loss: [3.9817982, 8.908386e-11, 2.0940565e-11, 0.20176497, 0.16031894, 0.19941089, 0.16154826]
# Batch: 2
# D_Loss: [0.4999979 0.5      ]
# G_Loss: [0.14613247, 1.06901446e-10, 3.266916e-11, 0.008199459, 0.0050833183, 0.008200543, 0.0051041497]
# Batch: 3
# D_Loss: [0.49999782 0.5       ]
# G_Loss: [0.07484748, 1.3021768e-10, 4.5673253e-11, 0.0035987599, 0.0032056177, 0.0035989643, 0.0032047378]
# Batch: 4
# D_Loss: [0.49999744 0.5       ]
# G_Loss: [0.055565186, 1.7880945e-10, 7.669714e-11, 0.0039672605, 0.001084133, 0.003967266, 0.0010839804]
# Batch: 5
# D_Loss: [0.4999969 0.5      ]
# G_Loss: [0.08253879, 2.7708774e-10, 1.625803e-10, 0.0032744212, 0.004229109, 0.0032744072, 0.0042290743]
# Batch: 6
# D_Loss: [0.4999958 0.5      ]
# G_Loss: [0.10562783, 5.279189e-10, 5.5828697e-10, 0.0035202028, 0.00608233, 0.0035201842, 0.0060823206]
# Batch: 7
# D_Loss: [0.49999303 0.5       ]
# G_Loss: [0.086792976, 1.5879688e-09, 1.0446463e-08, 0.00399099, 0.0038992828, 0.0039909696, 0.0038992679]
# Batch: 8
# D_Loss: [0.49997103 0.5       ]
# G_Loss: [1.0719333, 3.3966444e-08, 0.9998367, 0.0031124214, 0.003441812, 0.00311242, 0.0034418332]
# Batch: 9
# D_Loss: [0.74946296 0.25      ]
# G_Loss: [2.074207, 0.9999405, 0.9958127, 0.0041293586, 0.0030027935, 0.004129373, 0.003002779]
# Batch: 10
# D_Loss: [0.6524923  0.33163264]
# G_Loss: [2.0854123, 0.9999276, 0.99994147, 0.0026702269, 0.0051064147, 0.0026702278, 0.0051064114]
# Batch: 11
# D_Loss: [0.49996725 0.5       ]
# G_Loss: [2.0732508, 0.9998624, 0.99994475, 0.0046732277, 0.0020034672, 0.0046732393, 0.0020034793]
# Batch: 12
# D_Loss: [0.4999519 0.5      ]
# G_Loss: [2.076531, 0.99949414, 0.9999042, 0.0031265437, 0.0038855155, 0.0031265533, 0.0038854443]
# Batch: 13
# D_Loss: [0.4999232 0.5      ]
# G_Loss: [2.0755465, 0.9983372, 0.999865, 0.005020872, 0.0020104526, 0.005020882, 0.0020104344]
# Batch: 14
# D_Loss: [0.52557886 0.46428573]
# G_Loss: [2.0670457, 1.0, 0.9998054, 0.003332845, 0.0027798975, 0.003332844, 0.0027799131]
# Batch: 15
# D_Loss: [0.49995142 0.5       ]
# G_Loss: [2.0627306, 1.0, 0.99967253, 0.0035078381, 0.0022247022, 0.0035078109, 0.0022247187]
# Batch: 16
# D_Loss: [0.49991855 0.5       ]
# G_Loss: [2.0548084, 1.0, 0.9991885, 0.0022493354, 0.002807031, 0.0022493303, 0.0028070305]
# Batch: 17
# D_Loss: [0.4998095 0.5      ]
# G_Loss: [2.070156, 1.0, 0.99236864, 0.0031272955, 0.0039442857, 0.003127303, 0.0039442796]
# Batch: 18
# D_Loss: [0.74809253 0.25      ]
# G_Loss: [1.0848153, 1.0, 0.0, 0.0033807512, 0.00432973, 0.0033807652, 0.0043297005]
# Batch: 19
# D_Loss: [0.5 0.5]
# G_Loss: [1.0574374, 1.0, 0.0, 0.0034567295, 0.0017648425, 0.0034567132, 0.0017648609]
# Batch: 20
# D_Loss: [0.5 0.5]
# G_Loss: [1.0851662, 1.0, 0.0, 0.0030887434, 0.0046536615, 0.0030885967, 0.004653617]
# Batch: 21
# D_Loss: [0.5 0.5]
# G_Loss: [1.0874918, 1.0, 0.0, 0.0042378055, 0.003715997, 0.004237742, 0.0037159426]
# Batch: 22
# D_Loss: [0.5 0.5]
# G_Loss: [1.0767947, 1.0, 0.0, 0.003374986, 0.0036064032, 0.003374503, 0.0036063932]
# Batch: 23
# D_Loss: [0.5 0.5]
# G_Loss: [1.0570321, 1.0, 0.0, 0.0031483816, 0.0020362842, 0.0031492207, 0.0020362176]
# Batch: 24
# D_Loss: [0.5 0.5]
# G_Loss: [1.051461, 1.0, 0.0, 0.0022763265, 0.0024026777, 0.0022682818, 0.0024027082]
# Batch: 25
# D_Loss: [0.5 0.5]
# G_Loss: [1.0806954, 1.0, 0.0, 0.0036099807, 0.0037259345, 0.0036102007, 0.003725971]
# Batch: 26
# D_Loss: [0.5 0.5]
# G_Loss: [1.0783005, 1.0, 0.0, 0.004731375, 0.0023868494, 0.00473141, 0.0023868706]
# Batch: 27
# D_Loss: [0.5 0.5]
# G_Loss: [1.0667522, 1.0, 0.0, 0.0033675889, 0.002700807, 0.0033674338, 0.0027008553]
# Batch: 28
# D_Loss: [0.5 0.5]
# G_Loss: [1.052085, 1.0, 0.0, 0.0022735798, 0.002461434, 0.0022734143, 0.0024614318]
# Batch: 29
# D_Loss: [0.5 0.5]
# G_Loss: [1.1021444, 1.0, 0.0, 0.0048889676, 0.0043968046, 0.004889828, 0.004396752]
# Batch: 30
# D_Loss: [0.5 0.5]
# G_Loss: [1.0780519, 1.0, 0.0, 0.003395278, 0.0037004033, 0.0033947781, 0.0037003746]
# Batch: 31
# D_Loss: [0.5 0.5]
# G_Loss: [1.0768307, 1.0, 0.0, 0.0032819586, 0.0037026913, 0.0032816841, 0.0037025642]
# Batch: 32
# D_Loss: [0.5 0.5]
# G_Loss: [1.0663079, 1.0, 0.0, 0.0033780397, 0.0026499787, 0.0033778278, 0.0026499734]
# Batch: 33
# D_Loss: [0.5 0.5]
# G_Loss: [1.0675365, 1.0, 0.0, 0.0030047006, 0.0031349768, 0.003004685, 0.0031349908]
# Batch: 34
# D_Loss: [0.5 0.5]
# G_Loss: [1.0556906, 1.0, 0.0, 0.0034778118, 0.0015851352, 0.0034762435, 0.0015849032]
# Batch: 35
# D_Loss: [0.5 0.5]
# G_Loss: [1.0632472, 1.0, 0.0, 0.003059525, 0.0026906393, 0.0030549334, 0.0026905788]
# Batch: 36
# D_Loss: [0.5 0.5]
# G_Loss: [1.0780853, 1.0, 0.0, 0.0059963553, 0.0011018349, 0.0060012974, 0.0011019123]
# Batch: 37
# D_Loss: [0.5 0.5]
# G_Loss: [1.0686725, 1.0, 0.0, 0.004952337, 0.001290628, 0.0049523315, 0.0012905572]
# Batch: 38
# D_Loss: [0.5 0.5]
# G_Loss: [1.059172, 1.0, 0.0, 0.004489617, 0.00088965584, 0.0044896095, 0.0008896413]
# Batch: 39
# D_Loss: [0.5 0.5]
# G_Loss: [1.0479424, 1.0, 0.0, 0.0031680036, 0.0011903526, 0.0031684681, 0.0011903867]
# Batch: 40
# D_Loss: [0.5 0.5]
# G_Loss: [1.0867711, 1.0, 0.0, 0.0036952486, 0.004193059, 0.0036950114, 0.004193094]
# Batch: 41
# D_Loss: [0.5 0.5]
# G_Loss: [1.090488, 1.0, 0.0, 0.0052892114, 0.002936988, 0.005289113, 0.002936964]
# Batch: 42
# D_Loss: [0.5 0.5]
# G_Loss: [1.0798702, 1.0, 0.0, 0.0031518026, 0.0041091316, 0.0031518235, 0.0041091973]
# Batch: 43
# D_Loss: [0.5 0.5]
# G_Loss: [1.084857, 1.0, 0.0, 0.003741756, 0.003972517, 0.0037417463, 0.0039725807]
# Batch: 44
# D_Loss: [0.5 0.5]
# G_Loss: [1.0679239, 1.0, 0.0, 0.0036366396, 0.0025382612, 0.0036366002, 0.0025382675]
# Batch: 45
# D_Loss: [0.5 0.5]
# G_Loss: [1.0486474, 1.0, 0.0, 0.0030035162, 0.001419005, 0.0030033097, 0.001418854]
# Batch: 46
# D_Loss: [0.5 0.5]
# G_Loss: [1.0841243, 1.0, 0.0, 0.004741164, 0.0029064927, 0.0047411527, 0.002906536]
# Batch: 47
# D_Loss: [0.5 0.5]
# G_Loss: [1.0815023, 1.0, 0.0, 0.0037443202, 0.0036649501, 0.0037445861, 0.0036651045]
# Batch: 48
# D_Loss: [0.5 0.5]
# G_Loss: [1.0864365, 1.0, 0.0, 0.0035981806, 0.0042596306, 0.0035984716, 0.0042598965]
# Batch: 49
# D_Loss: [0.5 0.5]
# G_Loss: [1.0906178, 1.0, 0.0, 0.004105132, 0.004132814, 0.0041052364, 0.0041330634]
# Batch: 50
# D_Loss: [0.5 0.5]
# G_Loss: [1.0778519, 1.0, 0.0, 0.0035791048, 0.0034983526, 0.0035793327, 0.0034979074]
# Batch: 51
# D_Loss: [0.5 0.5]
# G_Loss: [1.0800817, 1.0, 0.0, 0.0042693685, 0.0030108076, 0.004269264, 0.003010592]
# Batch: 52
# D_Loss: [0.5 0.5]
# G_Loss: [1.0871855, 1.0, 0.0, 0.0038375768, 0.0040883394, 0.0038375626, 0.0040887096]
# Batch: 53
# D_Loss: [0.5 0.5]
# G_Loss: [1.0628582, 1.0, 0.0, 0.0029133393, 0.002801029, 0.0029132674, 0.0028012986]
# Batch: 54
# D_Loss: [0.5 0.5]
# G_Loss: [1.077869, 1.0, 0.0, 0.0043209996, 0.0027580336, 0.0043206667, 0.0027580424]
# Batch: 55
# D_Loss: [0.5 0.5]
# G_Loss: [1.0779094, 1.0, 0.0, 0.003730467, 0.0033522083, 0.003730199, 0.0033524567]
# Batch: 56
# D_Loss: [0.5 0.5]
# G_Loss: [1.0749876, 1.0, 0.0, 0.004295883, 0.00252108, 0.004296179, 0.0025218101]
# Batch: 57
# D_Loss: [0.5 0.5]
# G_Loss: [1.0770252, 1.0, 0.0, 0.004742824, 0.0022594454, 0.004742638, 0.0022598822]
# Batch: 58
# D_Loss: [0.5 0.5]
# G_Loss: [1.0795077, 1.0, 0.0, 0.0046040365, 0.0026238794, 0.004604093, 0.0026244419]
# Batch: 59
# D_Loss: [0.5 0.5]
# G_Loss: [1.064366, 1.0, 0.0, 0.0032435777, 0.0026074562, 0.0032441802, 0.0026115323]
# Batch: 60
# D_Loss: [0.5 0.5]
# G_Loss: [1.1274866, 1.0, 0.0, 0.0040348433, 0.0075588943, 0.00403386, 0.0075154817]
# Batch: 61
# D_Loss: [0.5 0.5]
# G_Loss: [1.0737286, 1.0, 0.0, 0.0034005335, 0.0033020773, 0.0034006143, 0.0033019525]
# Batch: 62
# D_Loss: [0.5 0.5]
# G_Loss: [1.0905625, 1.0, 0.0, 0.004027214, 0.004205725, 0.0040273867, 0.0042056846]
# Batch: 63
# D_Loss: [0.5 0.5]
# G_Loss: [1.0964904, 1.0, 0.0, 0.0042829257, 0.0044889115, 0.0042831446, 0.0044887755]
# Batch: 64
# D_Loss: [0.5 0.5]
# G_Loss: [1.0696694, 1.0, 0.0, 0.0035361843, 0.0027973326, 0.0035371496, 0.0027970588]
# Batch: 65
# D_Loss: [0.5 0.5]
# G_Loss: [1.0733979, 1.0, 0.0, 0.0027131853, 0.0039593363, 0.0027134323, 0.0039593377]
# Batch: 66
# D_Loss: [0.5 0.5]
# G_Loss: [1.0742708, 1.0, 0.0, 0.0034474717, 0.0033044256, 0.0034474852, 0.0033043916]
# Batch: 67
# D_Loss: [0.5 0.5]
# G_Loss: [1.0489588, 1.0, 0.0, 0.0025036074, 0.0019471708, 0.0025037182, 0.0019471394]
# Batch: 68
# D_Loss: [0.5 0.5]
# G_Loss: [1.09276, 1.0, 0.0, 0.0052122213, 0.0032205018, 0.005212277, 0.0032204827]
# Batch: 69
# D_Loss: [0.5 0.5]
# G_Loss: [1.0650876, 1.0, 0.0, 0.0028143679, 0.0031026572, 0.0028146973, 0.003102632]
# Batch: 70
# D_Loss: [0.5 0.5]
# G_Loss: [1.076307, 1.0, 0.0, 0.005073653, 0.0018633741, 0.0050733928, 0.0018633879]
# Batch: 71
# D_Loss: [0.5 0.5]
# G_Loss: [1.0785102, 1.0, 0.0, 0.0031344837, 0.0040026596, 0.0031359803, 0.0040026912]
# Batch: 72
# D_Loss: [0.5 0.5]
# G_Loss: [1.0717121, 1.0, 0.0, 0.003545532, 0.0029737581, 0.003545533, 0.002973699]
# Batch: 73
# D_Loss: [0.5 0.5]
# G_Loss: [1.0820658, 1.0, 0.0, 0.0033342442, 0.004126278, 0.0033342445, 0.0041262778]
# Batch: 74
# D_Loss: [0.5 0.5]
# G_Loss: [1.0856704, 1.0, 0.0, 0.0035295077, 0.004258689, 0.0035295356, 0.0042587053]
# Batch: 75
# D_Loss: [0.5 0.5]
# G_Loss: [1.0973699, 1.0, 0.0, 0.004074935, 0.004776881, 0.0040749134, 0.004776835]
# Batch: 76
# D_Loss: [0.5 0.5]
# G_Loss: [1.0872959, 1.0, 0.0, 0.0050162543, 0.0029197321, 0.0050163274, 0.0029197254]
# Batch: 77
# D_Loss: [0.5 0.5]
# G_Loss: [1.0685794, 1.0, 0.0, 0.003675417, 0.0025590837, 0.0036753644, 0.0025591091]
# Batch: 78
# D_Loss: [0.5 0.5]
# G_Loss: [1.0550449, 1.0, 0.0, 0.0041380986, 0.0008659789, 0.004138087, 0.0008659939]
# Batch: 79
# D_Loss: [0.5 0.5]
# G_Loss: [1.0651807, 1.0, 0.0, 0.0034196381, 0.0025058696, 0.0034195997, 0.0025058584]
# Batch: 80
# D_Loss: [0.5 0.5]
# G_Loss: [1.0762947, 1.0, 0.0, 0.0045200223, 0.0024158582, 0.0045200656, 0.0024157786]
# Batch: 81
# D_Loss: [0.5 0.5]
# G_Loss: [1.061006, 1.0, 0.0, 0.0021862653, 0.0033597136, 0.002186448, 0.0033597415]
# Batch: 82
# D_Loss: [0.5 0.5]
# G_Loss: [1.0631664, 1.0, 0.0, 0.0030834829, 0.0026589192, 0.003083443, 0.002658933]
# Batch: 83
# D_Loss: [0.5 0.5]
# G_Loss: [1.071692, 1.0, 0.0, 0.0037598638, 0.00275759, 0.0037598151, 0.002757649]
# Batch: 84
# D_Loss: [0.5 0.5]
# G_Loss: [1.0868279, 1.0, 0.0, 0.0035172347, 0.0043762056, 0.003517234, 0.00437618]
# Batch: 85
# D_Loss: [0.5 0.5]
# G_Loss: [1.0737256, 1.0, 0.0, 0.0039054756, 0.002796845, 0.003905605, 0.0027968176]
# Batch: 86
# D_Loss: [0.5 0.5]
# G_Loss: [1.0768528, 1.0, 0.0, 0.0038795, 0.003107092, 0.0038796565, 0.0031071838]
# Batch: 87
# D_Loss: [0.5 0.5]
# G_Loss: [1.058604, 1.0, 0.0, 0.0031390134, 0.0021886071, 0.003139085, 0.0021885857]
# Batch: 88
# D_Loss: [0.5 0.5]
# G_Loss: [1.0670298, 1.0, 0.0, 0.0031270678, 0.002966572, 0.00312701, 0.0029665818]
# Batch: 89
# D_Loss: [0.5 0.5]
# G_Loss: [1.0691516, 1.0, 0.0, 0.003329737, 0.0029567499, 0.0033298177, 0.0029568754]
# Batch: 90
# D_Loss: [0.5 0.5]
# G_Loss: [1.0603658, 1.0, 0.0, 0.0028722296, 0.0026155564, 0.002872322, 0.002615537]
# Batch: 91
# D_Loss: [0.5 0.5]
# G_Loss: [1.0871449, 1.0, 0.0, 0.004564752, 0.0033575501, 0.0045642396, 0.0033574726]
# Batch: 92
# D_Loss: [0.5 0.5]
# G_Loss: [1.0613427, 1.0, 0.0, 0.0039046337, 0.0016719277, 0.0039053552, 0.0016719126]
# Batch: 93
# D_Loss: [0.5 0.5]
# G_Loss: [1.0717534, 1.0, 0.0, 0.004279409, 0.002243618, 0.004279781, 0.0022434099]
# Batch: 94
# D_Loss: [0.5 0.5]
# G_Loss: [1.0699325, 1.0, 0.0, 0.004034694, 0.0023227795, 0.004034913, 0.0023227953]
# Batch: 95
# D_Loss: [0.5 0.5]
# G_Loss: [1.078219, 1.0, 0.0, 0.0036165146, 0.0034943172, 0.0036162194, 0.0034944594]
# Batch: 96
# D_Loss: [0.5 0.5]
# G_Loss: [1.0747249, 1.0, 0.0, 0.0038836333, 0.0029095171, 0.003883834, 0.002909556]
# Batch: 97
# D_Loss: [0.5 0.5]
# G_Loss: [1.0739962, 1.0, 0.0, 0.0036926835, 0.0030341838, 0.0036932414, 0.0030341984]
# Batch: 98
# D_Loss: [0.5 0.5]
# G_Loss: [1.0573971, 1.0, 0.0, 0.003084928, 0.0021330016, 0.0030848081, 0.00213297]
# Batch: 99
# D_Loss: [0.5 0.5]
# G_Loss: [1.0624814, 1.0, 0.0, 0.0032848888, 0.0023952425, 0.0032848283, 0.0023952671]
# Batch: 100
# D_Loss: [0.5 0.5]
# G_Loss: [1.0733134, 1.0, 0.0, 0.0041300706, 0.002534788, 0.0041300394, 0.0025348193]
# Batch: 101
# D_Loss: [0.5 0.5]
# G_Loss: [1.0451329, 1.0, 0.0, 0.0030677933, 0.0010351529, 0.0030683372, 0.0010350395]
# Batch: 102
# D_Loss: [0.5 0.5]
# G_Loss: [1.0779171, 1.0, 0.0, 0.0043695667, 0.0027137883, 0.0043696933, 0.0027138027]
# Batch: 103
# D_Loss: [0.5 0.5]
# G_Loss: [1.0759537, 1.0, 0.0, 0.0033069362, 0.003597927, 0.003307046, 0.0035979534]
# Batch: 104
# D_Loss: [0.5 0.5]
# G_Loss: [1.0812958, 1.0, 0.0, 0.0032483656, 0.0041421754, 0.0032482634, 0.004142168]
# Batch: 105
# D_Loss: [0.5 0.5]
# G_Loss: [1.0655774, 1.0, 0.0, 0.0026388727, 0.0033226293, 0.0026396988, 0.0033226837]
# Batch: 106
# D_Loss: [0.5 0.5]
# G_Loss: [1.0708199, 1.0, 0.0, 0.003556444, 0.0028817393, 0.0035563638, 0.0028817055]
# Batch: 107
# D_Loss: [0.5 0.5]
# G_Loss: [1.0803638, 1.0, 0.0, 0.004227072, 0.0030787254, 0.0042271223, 0.0030787117]
# Batch: 108
# D_Loss: [0.5 0.5]
# G_Loss: [1.0846242, 1.0, 0.0, 0.0028743737, 0.0048187403, 0.0028743937, 0.0048187356]
# Batch: 109
# D_Loss: [0.5 0.5]
# G_Loss: [1.0863596, 1.0, 0.0, 0.004478797, 0.0033721244, 0.004478313, 0.0033721193]
# Batch: 110
# D_Loss: [0.5 0.5]
# G_Loss: [1.0712557, 1.0, 0.0, 0.0030880217, 0.003389774, 0.0030878845, 0.0033897818]
# Batch: 111
# D_Loss: [0.5 0.5]
# G_Loss: [1.0743222, 1.0, 0.0, 0.004573022, 0.0021835642, 0.0045728656, 0.0021833978]
# Batch: 112
# D_Loss: [0.5 0.5]
# G_Loss: [1.0732552, 1.0, 0.0, 0.0040654046, 0.0025941664, 0.004065361, 0.0025941008]
# Batch: 113
# D_Loss: [0.5 0.5]
# G_Loss: [1.0623237, 1.0, 0.0, 0.003333007, 0.0023328, 0.003332877, 0.0023327845]
# Batch: 114
# D_Loss: [0.5 0.5]
# G_Loss: [1.0415868, 1.0, 0.0, 0.002432391, 0.0013482854, 0.002431692, 0.0013482757]
# Batch: 115
# D_Loss: [0.5 0.5]
# G_Loss: [1.0499488, 1.0, 0.0, 0.0025880132, 0.0019527874, 0.0025879866, 0.001952795]
# Batch: 116
# D_Loss: [0.5 0.5]
# G_Loss: [1.0585754, 1.0, 0.0, 0.0030760448, 0.0022489824, 0.0030762176, 0.0022489754]
# Batch: 117
# D_Loss: [0.5 0.5]
# G_Loss: [1.0502319, 1.0, 0.0, 0.0038499665, 0.0007165597, 0.0038500559, 0.00071656296]
# Batch: 118
# D_Loss: [0.5 0.5]
# G_Loss: [1.0947158, 1.0, 0.0, 0.004319322, 0.0042911433, 0.0043199672, 0.0042911833]
# Batch: 119
# D_Loss: [0.5 0.5]
# G_Loss: [1.0638133, 1.0, 0.0, 0.002425766, 0.0033754623, 0.0024256422, 0.0033754224]
# Batch: 120
# D_Loss: [0.5 0.5]
# G_Loss: [1.0824113, 1.0, 0.0, 0.0044944594, 0.0029974456, 0.0044946223, 0.0029974855]
# W0822 12:59:28.696646 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 12:59:28.715202 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 12:59:28.736211 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 12:59:28.753946 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 12:59:28.772412 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 12:59:28.792045 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 12:59:28.878107 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 12:59:28.897553 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 12:59:28.917304 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 12:59:28.937082 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 12:59:28.957372 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 12:59:28.978284 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch: 1
# Number of batches: 121
# Batch: 0
# D_Loss: [0.5 0.5]
# G_Loss: [1.0690359, 1.0, 0.0, 0.002908807, 0.003367193, 0.0029086964, 0.0033672038]
# Batch: 1
# D_Loss: [0.5 0.5]
# G_Loss: [1.0828736, 1.0, 0.0, 0.004325145, 0.0032088323, 0.0043251896, 0.0032088072]
# Batch: 2
# D_Loss: [0.5 0.5]
# G_Loss: [1.0789301, 1.0, 0.0, 0.0048052473, 0.0023702187, 0.0048053046, 0.002370237]
# Batch: 3
# D_Loss: [0.5 0.5]
# G_Loss: [1.0674511, 1.0, 0.0, 0.0030081037, 0.0031238394, 0.0030078182, 0.0031238368]
# Batch: 4
# D_Loss: [0.5 0.5]
# G_Loss: [1.0506923, 1.0, 0.0, 0.0035094658, 0.0010988972, 0.0035097501, 0.0010989867]
# Batch: 5
# D_Loss: [0.5 0.5]
# G_Loss: [1.0756971, 1.0, 0.0, 0.0027716947, 0.0041098623, 0.0027717045, 0.0041097756]
# Batch: 6
# D_Loss: [0.5 0.5]
# G_Loss: [1.0988199, 1.0, 0.0, 0.0030399049, 0.005943728, 0.0030398485, 0.0059436564]
# Batch: 7
# D_Loss: [0.5 0.5]
# G_Loss: [1.0760825, 1.0, 0.0, 0.0031523965, 0.0037642352, 0.0031520324, 0.0037641423]
# Batch: 8
# D_Loss: [0.5 0.5]
# G_Loss: [1.0683393, 1.0, 0.0, 0.0029137386, 0.003299105, 0.0029120487, 0.003298933]
# Batch: 9
# D_Loss: [0.5 0.5]
# G_Loss: [1.069293, 1.0, 0.0, 0.0033497447, 0.0029496374, 0.0033495626, 0.0029495822]
# Batch: 10
# D_Loss: [0.5 0.5]
# G_Loss: [1.0790051, 1.0, 0.0, 0.0022527794, 0.0049294764, 0.0022530123, 0.004929535]
# Batch: 11
# D_Loss: [0.5 0.5]
# G_Loss: [1.0660744, 1.0, 0.0, 0.0039958097, 0.0020109871, 0.0039953827, 0.0020109636]
# Batch: 12
# D_Loss: [0.5 0.5]
# G_Loss: [1.0673909, 1.0, 0.0, 0.0023699692, 0.0037565092, 0.0023696898, 0.0037564773]
# Batch: 13
# D_Loss: [0.5 0.5]
# G_Loss: [1.0651402, 1.0, 0.0, 0.0039214743, 0.002000365, 0.003921532, 0.0020003505]
# Batch: 14
# D_Loss: [0.5 0.5]
# G_Loss: [1.0650758, 1.0, 0.0, 0.0032533435, 0.002662763, 0.0032518697, 0.002662723]
# Batch: 15
# D_Loss: [0.5 0.5]
# G_Loss: [1.058662, 1.0, 0.0, 0.0031617132, 0.0021711942, 0.003161782, 0.0021711853]
# Batch: 16
# D_Loss: [0.5 0.5]
# G_Loss: [1.0514642, 1.0, 0.0, 0.0019652606, 0.0027133147, 0.0019651125, 0.0027132959]
# Batch: 17
# D_Loss: [0.5 0.5]
# G_Loss: [1.0737677, 1.0, 0.0, 0.00286523, 0.0038409191, 0.0028652376, 0.0038408777]
# Batch: 18
# D_Loss: [0.5 0.5]
# G_Loss: [1.0794905, 1.0, 0.0, 0.0030385405, 0.004187871, 0.003038527, 0.0041879574]
# Batch: 19
# D_Loss: [0.5 0.5]
# G_Loss: [1.0535123, 1.0, 0.0, 0.0030541336, 0.0018106545, 0.0030537304, 0.0018106659]
# Batch: 20
# D_Loss: [0.5 0.5]
# G_Loss: [1.077323, 1.0, 0.0, 0.00253687, 0.0044925357, 0.0025364468, 0.004492525]
# Batch: 21
# D_Loss: [0.5 0.5]
# G_Loss: [1.0763917, 1.0, 0.0, 0.0033263233, 0.0036183875, 0.003326186, 0.0036184522]
# Batch: 22
# D_Loss: [0.5 0.5]
# G_Loss: [1.0754428, 1.0, 0.0, 0.0033466062, 0.0035119387, 0.003345548, 0.0035118305]
# Batch: 23
# D_Loss: [0.5 0.5]
# G_Loss: [1.0612429, 1.0, 0.0, 0.0034765787, 0.002090917, 0.0034770353, 0.0020909025]
# Batch: 24
# D_Loss: [0.5 0.5]
# G_Loss: [1.0503787, 1.0, 0.0, 0.002196201, 0.0023836978, 0.0021959045, 0.0023837374]
# Batch: 25
# D_Loss: [0.5 0.5]
# G_Loss: [1.075517, 1.0, 0.0, 0.003242367, 0.0036228593, 0.0032421346, 0.003622795]
# Batch: 26
# D_Loss: [0.5 0.5]
# G_Loss: [1.0704234, 1.0, 0.0, 0.0040702857, 0.0023318431, 0.004070302, 0.0023318212]
# Batch: 27
# D_Loss: [0.5 0.5]
# G_Loss: [1.0575237, 1.0, 0.0, 0.0025779274, 0.0026514744, 0.002578204, 0.0026514705]
# Batch: 28
# D_Loss: [0.5 0.5]
# G_Loss: [1.052472, 1.0, 0.0, 0.002380249, 0.0023899446, 0.0023801723, 0.0023899553]
# Batch: 29
# D_Loss: [0.5 0.5]
# G_Loss: [1.0976458, 1.0, 0.0, 0.004596005, 0.004280909, 0.0045956727, 0.004280923]
# Batch: 30
# D_Loss: [0.5 0.5]
# G_Loss: [1.0752236, 1.0, 0.0, 0.0032524911, 0.003586011, 0.0032526483, 0.0035859928]
# Batch: 31
# D_Loss: [0.5 0.5]
# G_Loss: [1.0738326, 1.0, 0.0, 0.0031165336, 0.003595496, 0.0031167995, 0.0035954663]
# Batch: 32
# D_Loss: [0.5 0.5]
# G_Loss: [1.0606256, 1.0, 0.0, 0.0029350608, 0.002576422, 0.0029342338, 0.0025764583]
# Batch: 33
# D_Loss: [0.5 0.5]
# G_Loss: [1.0642027, 1.0, 0.0, 0.0028187367, 0.0030178954, 0.0028185486, 0.0030177254]
# Batch: 34
# D_Loss: [0.5 0.5]
# G_Loss: [1.055972, 1.0, 0.0, 0.0034350348, 0.0016532931, 0.0034353798, 0.0016533652]
# Batch: 35
# D_Loss: [0.5 0.5]
# G_Loss: [1.0696948, 1.0, 0.0, 0.003709991, 0.0026259064, 0.003709926, 0.0026258607]
# Batch: 36
# D_Loss: [0.5 0.5]
# G_Loss: [1.0499235, 1.0, 0.0, 0.003411762, 0.0011267848, 0.0034111529, 0.0011269166]
# Batch: 37
# D_Loss: [0.5 0.5]
# G_Loss: [1.059263, 1.0, 0.0, 0.004023206, 0.0013645109, 0.0040213643, 0.0013644792]
# Batch: 38
# D_Loss: [0.5 0.5]
# G_Loss: [1.0471228, 1.0, 0.0, 0.0033818176, 0.0009020152, 0.0033824537, 0.0009020141]
# Batch: 39
# D_Loss: [0.5 0.5]
# G_Loss: [1.0424316, 1.0, 0.0, 0.0026934939, 0.0011638699, 0.0026941667, 0.0011638134]
# Batch: 40
# D_Loss: [0.5 0.5]
# G_Loss: [1.0818876, 1.0, 0.0, 0.003300084, 0.004144351, 0.0032989727, 0.004144259]
# Batch: 41
# D_Loss: [0.5 0.5]
# G_Loss: [1.0875378, 1.0, 0.0, 0.0050630597, 0.0028948048, 0.0050642765, 0.0028948546]
# Batch: 42
# D_Loss: [0.5 0.5]
# G_Loss: [1.0723424, 1.0, 0.0, 0.0025149612, 0.004061666, 0.00251455, 0.004061615]
# Batch: 43
# D_Loss: [0.5 0.5]
# G_Loss: [1.0744872, 1.0, 0.0, 0.002846898, 0.0039246846, 0.002846796, 0.0039245617]
# Batch: 44
# D_Loss: [0.5 0.5]
# G_Loss: [1.0575687, 1.0, 0.0, 0.002779054, 0.0024544718, 0.00277879, 0.002454618]
# Batch: 45
# D_Loss: [0.5 0.5]
# G_Loss: [1.0415702, 1.0, 0.0, 0.0023469822, 0.0014322456, 0.0023456414, 0.001432311]
# Batch: 46
# D_Loss: [0.5 0.5]
# G_Loss: [1.0754511, 1.0, 0.0, 0.0040341495, 0.0028250732, 0.0040339613, 0.0028250706]
# Batch: 47
# D_Loss: [0.5 0.5]
# G_Loss: [1.0702459, 1.0, 0.0, 0.0028041434, 0.0035818587, 0.002804057, 0.0035817802]
# Batch: 48
# D_Loss: [0.5 0.5]
# G_Loss: [1.0778897, 1.0, 0.0, 0.0029199668, 0.004161032, 0.0029186336, 0.0041609406]
# Batch: 49
# D_Loss: [0.5 0.5]
# G_Loss: [1.0782099, 1.0, 0.0, 0.003100296, 0.0040096906, 0.0031004376, 0.0040096305]
# Batch: 50
# D_Loss: [0.5 0.5]
# G_Loss: [1.0696911, 1.0, 0.0, 0.0029329679, 0.0034026187, 0.0029326736, 0.0034025484]
# Batch: 51
# D_Loss: [0.5 0.5]
# G_Loss: [1.0722039, 1.0, 0.0, 0.003576219, 0.0029878162, 0.0035756277, 0.0029878698]
# Batch: 52
# D_Loss: [0.5 0.5]
# G_Loss: [1.0788169, 1.0, 0.0, 0.0031494433, 0.0040157316, 0.003149445, 0.0040157894]
# Batch: 53
# D_Loss: [0.5 0.5]
# G_Loss: [1.0547557, 1.0, 0.0, 0.0022319546, 0.0027458156, 0.0022322708, 0.0027455962]
# Batch: 54
# D_Loss: [0.5 0.5]
# G_Loss: [1.0672694, 1.0, 0.0, 0.0033480022, 0.0027674837, 0.003347007, 0.0027675093]
# Batch: 55
# D_Loss: [0.5 0.5]
# G_Loss: [1.0647525, 1.0, 0.0, 0.0025712266, 0.0033155691, 0.0025689583, 0.0033155228]
# Batch: 56
# D_Loss: [0.5 0.5]
# G_Loss: [1.0649921, 1.0, 0.0, 0.0033634999, 0.0025451235, 0.003360709, 0.0025451174]
# Batch: 57
# D_Loss: [0.5 0.5]
# G_Loss: [1.0700454, 1.0, 0.0, 0.004102381, 0.0022649579, 0.004107074, 0.0022649076]
# Batch: 58
# D_Loss: [0.5 0.5]
# G_Loss: [1.0717363, 1.0, 0.0, 0.0038430905, 0.0026784507, 0.0038425163, 0.0026783664]
# Batch: 59
# D_Loss: [0.5 0.5]
# G_Loss: [1.0575136, 1.0, 0.0, 0.0022858365, 0.002942732, 0.0022853059, 0.0029425807]
# Batch: 60
# D_Loss: [0.5 0.5]
# G_Loss: [1.051129, 1.0, 0.0, 0.0029304698, 0.0017177439, 0.0029290586, 0.0017176372]
# Batch: 61
# D_Loss: [0.5 0.5]
# G_Loss: [1.0633619, 1.0, 0.0, 0.0026121608, 0.0031480354, 0.0026119584, 0.0031479988]
# Batch: 62
# D_Loss: [0.5 0.5]
# G_Loss: [1.0811806, 1.0, 0.0, 0.0033721686, 0.0040073157, 0.0033784842, 0.004007233]
# Batch: 63
# D_Loss: [0.5 0.5]
# G_Loss: [1.0837145, 1.0, 0.0, 0.0033826162, 0.004227848, 0.003382165, 0.0042276876]
# Batch: 64
# D_Loss: [0.5 0.5]
# G_Loss: [1.0616775, 1.0, 0.0, 0.0030957947, 0.0025113367, 0.0030949702, 0.0025112615]
# Batch: 65
# D_Loss: [0.5 0.5]
# G_Loss: [1.0660031, 1.0, 0.0, 0.0023560212, 0.0036443167, 0.002355568, 0.003644269]
# Batch: 66
# D_Loss: [0.5 0.5]
# G_Loss: [1.0669566, 1.0, 0.0, 0.0029435083, 0.003143541, 0.0029428368, 0.0031434712]
# Batch: 67
# D_Loss: [0.5 0.5]
# G_Loss: [1.0467743, 1.0, 0.0, 0.0024026977, 0.0018496225, 0.0024014488, 0.0018495583]
# Batch: 68
# D_Loss: [0.5 0.5]
# G_Loss: [1.0828505, 1.0, 0.0, 0.0044814064, 0.0030505161, 0.0044807936, 0.0030503203]
# Batch: 69
# D_Loss: [0.5 0.5]
# G_Loss: [1.0597439, 1.0, 0.0, 0.0023904028, 0.00304088, 0.0023900098, 0.0030408874]
# Batch: 70
# D_Loss: [0.5 0.5]
# G_Loss: [1.0652426, 1.0, 0.0, 0.004161967, 0.0017692402, 0.0041613444, 0.001769146]
# Batch: 71
# D_Loss: [0.5 0.5]
# G_Loss: [1.0781186, 1.0, 0.0, 0.0032573468, 0.003844549, 0.0032552246, 0.0038443434]
# Batch: 72
# D_Loss: [0.5 0.5]
# G_Loss: [1.0607215, 1.0, 0.0, 0.0027751883, 0.002745027, 0.0027743669, 0.0027448612]
# Batch: 73
# D_Loss: [0.5 0.5]
# G_Loss: [1.0699923, 1.0, 0.0, 0.0025502543, 0.003812763, 0.0025493565, 0.0038126225]
# Batch: 74
# D_Loss: [0.5 0.5]
# G_Loss: [1.0699056, 1.0, 0.0, 0.0025083034, 0.0038471567, 0.0025039297, 0.0038471108]
# Batch: 75
# D_Loss: [0.5 0.5]
# G_Loss: [1.0772461, 1.0, 0.0, 0.0027869977, 0.004235564, 0.0027852524, 0.0042352653]
# Batch: 76
# D_Loss: [0.5 0.5]
# G_Loss: [1.0692925, 1.0, 0.0, 0.0032747467, 0.0030248929, 0.003270689, 0.003025419]
# Batch: 77
# D_Loss: [0.5 0.5]
# G_Loss: [1.0579554, 1.0, 0.0, 0.0028439309, 0.0024247929, 0.0028435267, 0.0024247244]
# Batch: 78
# D_Loss: [0.5 0.5]
# G_Loss: [1.0437514, 1.0, 0.0, 0.0031132712, 0.0008641704, 0.0031128041, 0.0008641989]
# Batch: 79
# D_Loss: [0.5 0.5]
# G_Loss: [1.0517775, 1.0, 0.0, 0.0022416362, 0.0024654143, 0.0022417475, 0.0024652854]
# Batch: 80
# D_Loss: [0.5 0.5]
# G_Loss: [1.0586634, 1.0, 0.0, 0.0029461482, 0.0023870608, 0.0029443253, 0.0023869488]
# Batch: 81
# D_Loss: [0.5 0.5]
# G_Loss: [1.0749251, 1.0, 0.0, 0.0035061294, 0.0033053532, 0.003505185, 0.0033051241]
# Batch: 82
# D_Loss: [0.5 0.5]
# G_Loss: [1.0564024, 1.0, 0.0, 0.0025257547, 0.0026019975, 0.0025229806, 0.0026019413]
# Batch: 83
# D_Loss: [0.5 0.5]
# G_Loss: [1.0673636, 1.0, 0.0, 0.0034374665, 0.0026864354, 0.0034379463, 0.0026864987]
# Batch: 84
# D_Loss: [0.5 0.5]
# G_Loss: [1.0816848, 1.0, 0.0, 0.003139732, 0.004286159, 0.003139875, 0.004286024]
# Batch: 85
# D_Loss: [0.5 0.5]
# G_Loss: [1.0662302, 1.0, 0.0, 0.0033241857, 0.002696741, 0.0033242744, 0.0026966264]
# Batch: 86
# D_Loss: [0.5 0.5]
# G_Loss: [1.0635854, 1.0, 0.0, 0.002820759, 0.0029598828, 0.002819197, 0.002959826]
# Batch: 87
# D_Loss: [0.5 0.5]
# G_Loss: [1.0525088, 1.0, 0.0, 0.0026739584, 0.0021000733, 0.0026685582, 0.0021000463]
# Batch: 88
# D_Loss: [0.5 0.5]
# G_Loss: [1.0603169, 1.0, 0.0, 0.002738479, 0.0027444796, 0.0027428984, 0.002744441]
# Batch: 89
# D_Loss: [0.5 0.5]
# G_Loss: [1.0578811, 1.0, 0.0, 0.0025970214, 0.0026648347, 0.0025976426, 0.002664812]
# Batch: 90
# D_Loss: [0.5 0.5]
# G_Loss: [1.0529727, 1.0, 0.0, 0.002345852, 0.0024698945, 0.0023451631, 0.002469975]
# Batch: 91
# D_Loss: [0.5 0.5]
# G_Loss: [1.0741739, 1.0, 0.0, 0.0036837007, 0.003059436, 0.0036833805, 0.0030592834]
# Batch: 92
# D_Loss: [0.5 0.5]
# G_Loss: [1.0489503, 1.0, 0.0, 0.0027278408, 0.0017222384, 0.0027272003, 0.0017223866]
# Batch: 93
# D_Loss: [0.5 0.5]
# G_Loss: [1.0584309, 1.0, 0.0, 0.0030426648, 0.0022693058, 0.0030419582, 0.0022693032]
# Batch: 94
# D_Loss: [0.5 0.5]
# G_Loss: [1.05576, 1.0, 0.0, 0.002895498, 0.0021735672, 0.0028959112, 0.0021734422]
# Batch: 95
# D_Loss: [0.5 0.5]
# G_Loss: [1.0704371, 1.0, 0.0, 0.0030447748, 0.0033586551, 0.0030438825, 0.0033589015]
# Batch: 96
# D_Loss: [0.5 0.5]
# G_Loss: [1.0585555, 1.0, 0.0, 0.0026243734, 0.0026989118, 0.0026239108, 0.00269882]
# Batch: 97
# D_Loss: [0.5 0.5]
# G_Loss: [1.0595974, 1.0, 0.0, 0.0025129043, 0.002905117, 0.002511977, 0.0029050908]
# Batch: 98
# D_Loss: [0.5 0.5]
# G_Loss: [1.0482585, 1.0, 0.0, 0.002263237, 0.0021240371, 0.0022617173, 0.0021240667]
# Batch: 99
# D_Loss: [0.5 0.5]
# G_Loss: [1.0519004, 1.0, 0.0, 0.0025234034, 0.0021946216, 0.0025255508, 0.0021946784]
# Batch: 100
# D_Loss: [0.5 0.5]
# G_Loss: [1.0615052, 1.0, 0.0, 0.0032799293, 0.0023113347, 0.003281176, 0.0023113214]
# Batch: 101
# D_Loss: [0.5 0.5]
# G_Loss: [1.0413585, 1.0, 0.0, 0.0025414922, 0.0012183666, 0.0025413905, 0.0012184889]
# Batch: 102
# D_Loss: [0.5 0.5]
# G_Loss: [1.0636867, 1.0, 0.0, 0.0032056642, 0.0025839475, 0.0032067788, 0.002583893]
# Batch: 103
# D_Loss: [0.5 0.5]
# G_Loss: [1.0638754, 1.0, 0.0, 0.0023310354, 0.003475741, 0.0023321854, 0.0034755766]
# Batch: 104
# D_Loss: [0.5 0.5]
# G_Loss: [1.0690624, 1.0, 0.0, 0.0022851112, 0.0039933478, 0.0022846754, 0.003993195]
# Batch: 105
# D_Loss: [0.5 0.5]
# G_Loss: [1.0590044, 1.0, 0.0, 0.0022372527, 0.0031268988, 0.0022361416, 0.003126856]
# Batch: 106
# D_Loss: [0.5 0.5]
# G_Loss: [1.0603896, 1.0, 0.0, 0.0026443498, 0.0028455583, 0.002644991, 0.0028455728]
# Batch: 107
# D_Loss: [0.5 0.5]
# G_Loss: [1.0666258, 1.0, 0.0, 0.0031364998, 0.0029203868, 0.0031366302, 0.002920326]
# Batch: 108
# D_Loss: [0.5 0.5]
# G_Loss: [1.071319, 1.0, 0.0, 0.0019209204, 0.0045627104, 0.0019202413, 0.0045624417]
# Batch: 109
# D_Loss: [0.5 0.5]
# G_Loss: [1.0704637, 1.0, 0.0, 0.0031581768, 0.0032477318, 0.0031568694, 0.0032476843]
# Batch: 110
# D_Loss: [0.5 0.5]
# G_Loss: [1.0571347, 1.0, 0.0, 0.0020918113, 0.0031023163, 0.00209124, 0.003102203]
# Batch: 111
# D_Loss: [0.5 0.5]
# G_Loss: [1.0594218, 1.0, 0.0, 0.0033497117, 0.0020519346, 0.0033533927, 0.0020518934]
# Batch: 112
# D_Loss: [0.5 0.5]
# G_Loss: [1.0574048, 1.0, 0.0, 0.0026998739, 0.0025189386, 0.0026978017, 0.0025187684]
# Batch: 113
# D_Loss: [0.5 0.5]
# G_Loss: [1.0474591, 1.0, 0.0, 0.0020996686, 0.0022148513, 0.0020992109, 0.002214741]
# Batch: 114
# D_Loss: [0.5 0.5]
# G_Loss: [1.0353155, 1.0, 0.0, 0.0018949468, 0.0013156135, 0.001893992, 0.0013157844]
# Batch: 115
# D_Loss: [0.5 0.5]
# G_Loss: [1.0435133, 1.0, 0.0, 0.002103814, 0.0018518267, 0.0021051364, 0.0018518277]
# Batch: 116
# D_Loss: [0.5 0.5]
# G_Loss: [1.0500723, 1.0, 0.0, 0.002416893, 0.0021349012, 0.0024195246, 0.0021348763]
# Batch: 117
# D_Loss: [0.5 0.5]
# G_Loss: [1.042225, 1.0, 0.0, 0.0030416262, 0.00079694495, 0.0030422262, 0.0007970494]
# Batch: 118
# D_Loss: [0.5 0.5]
# G_Loss: [1.0771601, 1.0, 0.0, 0.0028419718, 0.004172641, 0.0028415876, 0.004172408]
# Batch: 119
# D_Loss: [0.5 0.5]
# G_Loss: [1.0657964, 1.0, 0.0, 0.0027472656, 0.0032341143, 0.002748827, 0.0032337713]
# Batch: 120
# D_Loss: [0.5 0.5]
# G_Loss: [1.0783491, 1.0, 0.0, 0.0042481273, 0.0028731367, 0.0042632525, 0.0028732328]
# Epoch: 2
# Number of batches: 121
# Batch: 0
# D_Loss: [0.5 0.5]
# G_Loss: [1.061259, 1.0, 0.0, 0.0024423595, 0.0031266783, 0.0024418945, 0.0031266848]
# Batch: 1
# D_Loss: [0.5 0.5]
# G_Loss: [1.0762488, 1.0, 0.0, 0.0036676268, 0.0032638868, 0.0036692405, 0.0032643655]
# Batch: 2
# D_Loss: [0.5 0.5]
# G_Loss: [1.0600425, 1.0, 0.0, 0.0032377578, 0.0022205813, 0.0032385404, 0.0022204658]
# Batch: 3
# D_Loss: [0.5 0.5]
# G_Loss: [1.0767678, 1.0, 0.0, 0.004056763, 0.002922262, 0.004055498, 0.0029220288]
# Batch: 4
# D_Loss: [0.5 0.5]
# G_Loss: [1.0424306, 1.0, 0.0, 0.0025824332, 0.0012747147, 0.0025843093, 0.0012748487]
# Batch: 5
# D_Loss: [0.5 0.5]
# G_Loss: [1.0670744, 1.0, 0.0, 0.002128982, 0.003968633, 0.0021297112, 0.003968571]
# Batch: 6
# D_Loss: [0.5 0.5]
# G_Loss: [1.0887794, 1.0, 0.0, 0.0022860523, 0.0057847043, 0.002287315, 0.0057846173]
# Batch: 7
# D_Loss: [0.5 0.5]
# G_Loss: [1.063317, 1.0, 0.0, 0.00218467, 0.0035714412, 0.0021846485, 0.0035712798]
# Batch: 8
# D_Loss: [0.5 0.5]
# G_Loss: [1.0615164, 1.0, 0.0, 0.002598328, 0.0029943946, 0.0025949068, 0.0029941797]
# Batch: 9
# D_Loss: [0.5 0.5]
# G_Loss: [1.0576092, 1.0, 0.0, 0.0023047668, 0.0029323497, 0.0023055123, 0.0029326025]
# Batch: 10
# D_Loss: [0.5 0.5]
# G_Loss: [1.0730894, 1.0, 0.0, 0.00200796, 0.0046368353, 0.002005082, 0.0046363384]
# Batch: 11
# D_Loss: [0.5 0.5]
# G_Loss: [1.0563979, 1.0, 0.0, 0.003114642, 0.002012339, 0.0031156263, 0.0020124847]
# Batch: 12
# D_Loss: [0.5 0.5]
# G_Loss: [1.057968, 1.0, 0.0, 0.0016790037, 0.0035908425, 0.0016788708, 0.0035907128]
# Batch: 13
# D_Loss: [0.5 0.5]
# G_Loss: [1.0530388, 1.0, 0.0, 0.0029528085, 0.001868739, 0.002954541, 0.0018688994]
# Batch: 14
# D_Loss: [0.5 0.5]
# G_Loss: [1.0539542, 1.0, 0.0, 0.0024093266, 0.0024959384, 0.0024059373, 0.002495679]
# Batch: 15
# D_Loss: [0.5 0.5]
# G_Loss: [1.0480483, 1.0, 0.0, 0.002361334, 0.0020067028, 0.0023612578, 0.0020066197]
# Batch: 16
# D_Loss: [0.5 0.5]
# G_Loss: [1.042879, 1.0, 0.0, 0.0013706357, 0.0025274602, 0.0013706465, 0.002527379]
# Batch: 17
# D_Loss: [0.5 0.5]
# G_Loss: [1.0621293, 1.0, 0.0, 0.0020485106, 0.003599551, 0.0020491988, 0.0035994272]
# Batch: 18
# D_Loss: [0.5 0.5]
# G_Loss: [1.0631925, 1.0, 0.0, 0.0020884506, 0.0036562078, 0.0020895954, 0.0036562188]
# Batch: 19
# D_Loss: [0.5 0.5]
# G_Loss: [1.0552627, 1.0, 0.0, 0.0021312716, 0.0028921773, 0.0021358037, 0.002892536]
# Batch: 20
# D_Loss: [0.5 0.5]
# G_Loss: [1.0694221, 1.0, 0.0, 0.0019700672, 0.0043408787, 0.0019721591, 0.0043405876]
# Batch: 21
# D_Loss: [0.5 0.5]
# G_Loss: [1.0656296, 1.0, 0.0, 0.0024027938, 0.0035635978, 0.002402244, 0.0035635524]
# Batch: 22
# D_Loss: [0.5 0.5]
# G_Loss: [1.0619597, 1.0, 0.0, 0.0022251266, 0.0034076776, 0.0022240696, 0.0034076218]
# Batch: 23
# D_Loss: [0.5 0.5]
# G_Loss: [1.0443435, 1.0, 0.0, 0.002135187, 0.0018959282, 0.0021366007, 0.0018958377]
# Batch: 24
# D_Loss: [0.5 0.5]
# G_Loss: [1.0499337, 1.0, 0.0, 0.0022313213, 0.0023083333, 0.0022288444, 0.0023082634]
# Batch: 25
# D_Loss: [0.5 0.5]
# G_Loss: [1.0640622, 1.0, 0.0, 0.0023771378, 0.003446613, 0.0023783888, 0.003446363]
# Batch: 26
# D_Loss: [0.5 0.5]
# G_Loss: [1.0580457, 1.0, 0.0, 0.0031465678, 0.0021301175, 0.0031490405, 0.0021299575]
# Batch: 27
# D_Loss: [0.5 0.5]
# G_Loss: [1.0486431, 1.0, 0.0, 0.0019776686, 0.0024445048, 0.0019770972, 0.002444311]
# Batch: 28
# D_Loss: [0.5 0.5]
# G_Loss: [1.04566, 1.0, 0.0, 0.0019027262, 0.002248522, 0.0018989019, 0.0022486188]
# Batch: 29
# D_Loss: [0.5 0.5]
# G_Loss: [1.0834832, 1.0, 0.0, 0.003605139, 0.0039843502, 0.003603933, 0.003984281]
# Batch: 30
# D_Loss: [0.5 0.5]
# G_Loss: [1.0596406, 1.0, 0.0, 0.0021709942, 0.0032508438, 0.0021715278, 0.0032507668]
# Batch: 31
# D_Loss: [0.5 0.5]
# G_Loss: [1.0583608, 1.0, 0.0, 0.0020126696, 0.0032925834, 0.002015729, 0.0032926148]
# Batch: 32
# D_Loss: [0.5 0.5]
# G_Loss: [1.0465386, 1.0, 0.0, 0.0018356898, 0.0023951703, 0.0018348638, 0.0023951225]
# Batch: 33
# D_Loss: [0.5 0.5]
# G_Loss: [1.05011, 1.0, 0.0, 0.0018752685, 0.0026802174, 0.0018750782, 0.002680068]
# Batch: 34
# D_Loss: [0.5 0.5]
# G_Loss: [1.0447266, 1.0, 0.0, 0.0023408895, 0.0017249156, 0.0023432611, 0.0017252682]
# Batch: 35
# D_Loss: [0.5 0.5]
# G_Loss: [1.055094, 1.0, 0.0, 0.0025154874, 0.002492826, 0.0025183521, 0.002492636]
# Batch: 36
# D_Loss: [0.5 0.5]
# G_Loss: [1.0372342, 1.0, 0.0, 0.0022806767, 0.0011045688, 0.0022770518, 0.0011046659]
# Batch: 37
# D_Loss: [0.5 0.5]
# G_Loss: [1.0450032, 1.0, 0.0, 0.0027802878, 0.0013109366, 0.0027800004, 0.0013110216]
# Batch: 38
# D_Loss: [0.5 0.5]
# G_Loss: [1.0335577, 1.0, 0.0, 0.0022059518, 0.0008446739, 0.0022065616, 0.0008448336]
# Batch: 39
# D_Loss: [0.5 0.5]
# G_Loss: [1.0380403, 1.0, 0.0, 0.0023271893, 0.0011309357, 0.002328386, 0.0011306133]
# Batch: 40
# D_Loss: [0.5 0.5]
# G_Loss: [1.0725842, 1.0, 0.0, 0.002555321, 0.004043279, 0.0025551007, 0.0040429803]
# Batch: 41
# D_Loss: [0.5 0.5]
# G_Loss: [1.0722293, 1.0, 0.0, 0.003784782, 0.0027814046, 0.0037859515, 0.0027814207]
# Batch: 42
# D_Loss: [0.5 0.5]
# G_Loss: [1.0604196, 1.0, 0.0, 0.0016394679, 0.0038532522, 0.0016391543, 0.0038532254]
# Batch: 43
# D_Loss: [0.5 0.5]
# G_Loss: [1.059217, 1.0, 0.0, 0.0017665966, 0.0036166157, 0.0017682037, 0.0036165244]
# Batch: 44
# D_Loss: [0.5 0.5]
# G_Loss: [1.0452725, 1.0, 0.0, 0.0016868194, 0.0024290504, 0.001684617, 0.002429049]
# Batch: 45
# D_Loss: [0.5 0.5]
# G_Loss: [1.0355186, 1.0, 0.0, 0.0016571472, 0.0015718825, 0.0016563495, 0.0015719752]
# Batch: 46
# D_Loss: [0.5 0.5]
# G_Loss: [1.0603846, 1.0, 0.0, 0.0028282804, 0.0026610773, 0.0028300057, 0.0026610973]
# Batch: 47
# D_Loss: [0.5 0.5]
# G_Loss: [1.0557445, 1.0, 0.0, 0.0016256084, 0.0034420872, 0.0016256236, 0.003441954]
# Batch: 48
# D_Loss: [0.5 0.5]
# G_Loss: [1.0669335, 1.0, 0.0, 0.002121899, 0.0039631696, 0.002119782, 0.003962987]
# Batch: 49
# D_Loss: [0.5 0.5]
# G_Loss: [1.0593663, 1.0, 0.0, 0.0017041132, 0.003692768, 0.0017047763, 0.0036927382]
# Batch: 50
# D_Loss: [0.5 0.5]
# G_Loss: [1.05051, 1.0, 0.0, 0.0015142155, 0.0030780744, 0.0015088164, 0.003078164]
# Batch: 51
# D_Loss: [0.5 0.5]
# G_Loss: [1.0550034, 1.0, 0.0, 0.002115359, 0.0028847477, 0.0021173372, 0.002884934]
# Batch: 52
# D_Loss: [0.5 0.5]
# G_Loss: [1.0635129, 1.0, 0.0, 0.0018894451, 0.0038843653, 0.00189041, 0.0038844706]
# Batch: 53
# D_Loss: [0.5 0.5]
# G_Loss: [1.047862, 1.0, 0.0, 0.00171995, 0.0026312955, 0.0017184562, 0.002631185]
# Batch: 54
# D_Loss: [0.5 0.5]
# G_Loss: [1.05466, 1.0, 0.0, 0.0023490847, 0.0026196023, 0.0023535872, 0.0026195466]
# Batch: 55
# D_Loss: [0.5 0.5]
# G_Loss: [1.0561117, 1.0, 0.0, 0.0019735054, 0.0031274513, 0.001974703, 0.0031273537]
# Batch: 56
# D_Loss: [0.5 0.5]
# G_Loss: [1.0480297, 1.0, 0.0, 0.0018382845, 0.0025281142, 0.0018374963, 0.0025281622]
# Batch: 57
# D_Loss: [0.5 0.5]
# G_Loss: [1.0464865, 1.0, 0.0, 0.00216116, 0.0020648616, 0.0021614614, 0.0020647668]
# Batch: 58
# D_Loss: [0.5 0.5]
# G_Loss: [1.0480962, 1.0, 0.0, 0.0019813338, 0.0023911158, 0.0019807606, 0.0023909642]
# Batch: 59
# D_Loss: [0.5 0.5]
# G_Loss: [1.0492793, 1.0, 0.0, 0.0018538698, 0.002626535, 0.0018488222, 0.002626478]
# Batch: 60
# D_Loss: [0.5 0.5]
# G_Loss: [1.0362929, 1.0, 0.0, 0.0019228206, 0.0013762095, 0.0019258481, 0.0013767632]
# Batch: 61
# D_Loss: [0.5 0.5]
# G_Loss: [1.047023, 1.0, 0.0, 0.0014762672, 0.0027984467, 0.0014775873, 0.0027982595]
# Batch: 62
# D_Loss: [0.5 0.5]
# G_Loss: [1.0573773, 1.0, 0.0, 0.0016067433, 0.0036092275, 0.0016083473, 0.003609267]
# Batch: 63
# D_Loss: [0.5 0.5]
# G_Loss: [1.0644308, 1.0, 0.0, 0.0021126862, 0.0037450194, 0.0021088577, 0.0037449421]
# Batch: 64
# D_Loss: [0.5 0.5]
# G_Loss: [1.0463731, 1.0, 0.0, 0.0021069155, 0.0021088654, 0.0021061725, 0.0021091893]
# Batch: 65
# D_Loss: [0.5 0.5]
# G_Loss: [1.0556995, 1.0, 0.0, 0.0018634859, 0.0032004148, 0.0018596449, 0.0032007976]
# Batch: 66
# D_Loss: [0.5 0.5]
# G_Loss: [1.0523547, 1.0, 0.0, 0.0018449273, 0.0029143007, 0.0018478204, 0.0029145917]
# Batch: 67
# D_Loss: [0.5 0.5]
# G_Loss: [1.0341142, 1.0, 0.0, 0.0014344461, 0.0016668406, 0.0014343087, 0.0016670444]
# Batch: 68
# D_Loss: [0.5 0.5]
# G_Loss: [1.0686315, 1.0, 0.0, 0.0033318568, 0.0029072764, 0.003332968, 0.0029072736]
# Batch: 69
# D_Loss: [0.5 0.5]
# G_Loss: [1.0476406, 1.0, 0.0, 0.0014259843, 0.0029050913, 0.0014247888, 0.0029050652]
# Batch: 70
# D_Loss: [0.5 0.5]
# G_Loss: [1.0446297, 1.0, 0.0, 0.0023683147, 0.0016887967, 0.0023696073, 0.0016888438]
# Batch: 71
# D_Loss: [0.5 0.5]
# G_Loss: [1.0752852, 1.0, 0.0, 0.0031588557, 0.0036857799, 0.0031529812, 0.003685802]
# Batch: 72
# D_Loss: [0.5 0.5]
# G_Loss: [1.0431309, 1.0, 0.0, 0.0014783232, 0.0024426784, 0.0014782897, 0.0024425355]
# Batch: 73
# D_Loss: [0.5 0.5]
# G_Loss: [1.0525625, 1.0, 0.0, 0.0013579663, 0.003420405, 0.0013585312, 0.003420348]
# Batch: 74
# D_Loss: [0.5 0.5]
# G_Loss: [1.0551721, 1.0, 0.0, 0.0016604142, 0.0033552034, 0.0016607353, 0.0033552023]
# Batch: 75
# D_Loss: [0.5 0.5]
# G_Loss: [1.0628487, 1.0, 0.0, 0.0018207688, 0.003892755, 0.0018205697, 0.0038929477]
# Batch: 76
# D_Loss: [0.5 0.5]
# G_Loss: [1.0522014, 1.0, 0.0, 0.0019648117, 0.0027808629, 0.0019637104, 0.0027809558]
# Batch: 77
# D_Loss: [0.5 0.5]
# G_Loss: [1.0481422, 1.0, 0.0, 0.00206586, 0.0023108707, 0.002063952, 0.0023108162]
# Batch: 78
# D_Loss: [0.5 0.5]
# G_Loss: [1.0264069, 1.0, 0.0, 0.00148029, 0.00092031475, 0.0014804709, 0.00092034356]
# Batch: 79
# D_Loss: [0.5 0.5]
# G_Loss: [1.0370853, 1.0, 0.0, 0.00095449446, 0.002416918, 0.0009541576, 0.0024169153]
# Batch: 80
# D_Loss: [0.5 0.5]
# G_Loss: [1.0468363, 1.0, 0.0, 0.0019274622, 0.0023303214, 0.001928134, 0.002330317]
# Batch: 81
# D_Loss: [0.5 0.5]
# G_Loss: [1.0620333, 1.0, 0.0, 0.0024296562, 0.0032098175, 0.0024287133, 0.0032097748]
# Batch: 82
# D_Loss: [0.5 0.5]
# G_Loss: [1.0417036, 1.0, 0.0, 0.0012979513, 0.0024933536, 0.0012970854, 0.0024933456]
# Batch: 83
# D_Loss: [0.5 0.5]
# G_Loss: [1.0493389, 1.0, 0.0, 0.0019274976, 0.0025577503, 0.0019285575, 0.0025578276]
# Batch: 84
# D_Loss: [0.5 0.5]
# G_Loss: [1.0582824, 1.0, 0.0, 0.0012374436, 0.0040609213, 0.0012378432, 0.004060886]
# Batch: 85
# D_Loss: [0.5 0.5]
# G_Loss: [1.0447869, 1.0, 0.0, 0.0014940441, 0.0025775745, 0.0014930558, 0.0025775316]
# Batch: 86
# D_Loss: [0.5 0.5]
# G_Loss: [1.0474793, 1.0, 0.0, 0.0016763309, 0.002640178, 0.0016739096, 0.002640233]
# Batch: 87
# D_Loss: [0.5 0.5]
# G_Loss: [1.0405004, 1.0, 0.0, 0.0015026813, 0.00217932, 0.0015010163, 0.002179355]
# Batch: 88
# D_Loss: [0.5 0.5]
# G_Loss: [1.040252, 1.0, 0.0, 0.0010502003, 0.0026090117, 0.0010507766, 0.0026089835]
# Batch: 89
# D_Loss: [0.5 0.5]
# G_Loss: [1.0459871, 1.0, 0.0, 0.0016498787, 0.0025307355, 0.0016503447, 0.00253074]
# Batch: 90
# D_Loss: [0.5 0.5]
# G_Loss: [1.0429528, 1.0, 0.0, 0.0015410698, 0.0023639132, 0.001539162, 0.0023638806]
# Batch: 91
# D_Loss: [0.5 0.5]
# G_Loss: [1.0553709, 1.0, 0.0, 0.0021943008, 0.0028393369, 0.0021952435, 0.0028392829]
# Batch: 92
# D_Loss: [0.5 0.5]
# G_Loss: [1.0398393, 1.0, 0.0, 0.001770867, 0.0018507807, 0.0017718923, 0.0018508034]
# Batch: 93
# D_Loss: [0.5 0.5]
# G_Loss: [1.0420873, 1.0, 0.0, 0.0015307306, 0.0022954515, 0.0015301667, 0.0022954238]
# Batch: 94
# D_Loss: [0.5 0.5]
# G_Loss: [1.0383918, 1.0, 0.0, 0.0014439363, 0.0020463332, 0.001442817, 0.002046308]
# Batch: 95
# D_Loss: [0.5 0.5]
# G_Loss: [1.0621653, 1.0, 0.0, 0.0024200382, 0.0032314458, 0.0024188394, 0.0032315524]
# Batch: 96
# D_Loss: [0.5 0.5]
# G_Loss: [1.0459155, 1.0, 0.0, 0.0016276736, 0.002546456, 0.0016277721, 0.00254644]
# Batch: 97
# D_Loss: [0.5 0.5]
# G_Loss: [1.0459532, 1.0, 0.0, 0.0014020189, 0.002775622, 0.001401169, 0.0027755997]
# Batch: 98
# D_Loss: [0.5 0.5]
# G_Loss: [1.0419289, 1.0, 0.0, 0.0016989178, 0.002113074, 0.0016956226, 0.0021131714]
# Batch: 99
# D_Loss: [0.5 0.5]
# G_Loss: [1.0354477, 1.0, 0.0, 0.0012092374, 0.0020133057, 0.0012090843, 0.0020132298]
# Batch: 100
# D_Loss: [0.5 0.5]
# G_Loss: [1.0446681, 1.0, 0.0, 0.0019317153, 0.002128841, 0.0019338353, 0.0021287624]
# Batch: 101
# D_Loss: [0.5 0.5]
# G_Loss: [1.0386283, 1.0, 0.0, 0.0022101018, 0.0013016385, 0.0022092075, 0.001301758]
# Batch: 102
# D_Loss: [0.5 0.5]
# G_Loss: [1.0493385, 1.0, 0.0, 0.0020478745, 0.0024372793, 0.0020496733, 0.002437241]
# Batch: 103
# D_Loss: [0.5 0.5]
# G_Loss: [1.0551047, 1.0, 0.0, 0.0016676272, 0.0033417717, 0.0016689023, 0.0033418112]
# Batch: 104
# D_Loss: [0.5 0.5]
# G_Loss: [1.0559654, 1.0, 0.0, 0.0012619337, 0.0038258685, 0.0012614162, 0.003825849]
# Batch: 105
# D_Loss: [0.5 0.5]
# G_Loss: [1.0533264, 1.0, 0.0, 0.001911834, 0.0029362226, 0.0019096434, 0.0029362473]
# Batch: 106
# D_Loss: [0.5 0.5]
# G_Loss: [1.0467163, 1.0, 0.0, 0.0014709327, 0.0027759043, 0.0014721402, 0.0027758442]
# Batch: 107
# D_Loss: [0.5 0.5]
# G_Loss: [1.0528431, 1.0, 0.0, 0.0020548003, 0.0027490682, 0.0020553889, 0.0027490254]
# Batch: 108
# D_Loss: [0.5 0.5]
# G_Loss: [1.0623486, 1.0, 0.0, 0.0013942681, 0.0042738398, 0.0013938048, 0.0042736717]
# Batch: 109
# D_Loss: [0.5 0.5]
# G_Loss: [1.0571885, 1.0, 0.0, 0.002141499, 0.0030574682, 0.0021415167, 0.003057334]
# Batch: 110
# D_Loss: [0.5 0.5]
# G_Loss: [1.0443932, 1.0, 0.0, 0.0012539402, 0.0027820002, 0.0012519797, 0.0027818577]
# Batch: 111
# D_Loss: [0.5 0.5]
# G_Loss: [1.0434794, 1.0, 0.0, 0.0020980705, 0.001854219, 0.0021023015, 0.0018542846]
# Batch: 112
# D_Loss: [0.5 0.5]
# G_Loss: [1.0416527, 1.0, 0.0, 0.0014644209, 0.002322259, 0.0014636046, 0.0023222526]
# Batch: 113
# D_Loss: [0.5 0.5]
# G_Loss: [1.0386976, 1.0, 0.0, 0.0014516012, 0.0020667296, 0.0014477673, 0.0020664888]
# Batch: 114
# D_Loss: [0.5 0.5]
# G_Loss: [1.0289363, 1.0, 0.0, 0.0012929605, 0.0013377871, 0.0012912059, 0.0013376256]
# Batch: 115
# D_Loss: [0.5 0.5]
# G_Loss: [1.0362641, 1.0, 0.0, 0.0015417014, 0.0017549911, 0.0015421574, 0.0017550038]
# Batch: 116
# D_Loss: [0.5 0.5]
# G_Loss: [1.040037, 1.0, 0.0, 0.0016481484, 0.0019914294, 0.0016500272, 0.0019913064]
# Batch: 117
# D_Loss: [0.5 0.5]
# G_Loss: [1.0354906, 1.0, 0.0, 0.0023681677, 0.0008581633, 0.002368992, 0.0008582865]
# Batch: 118
# D_Loss: [0.5 0.5]
# G_Loss: [1.0638645, 1.0, 0.0, 0.001774144, 0.004031552, 0.0017760888, 0.0040314132]
# Batch: 119
# D_Loss: [0.5 0.5]
# G_Loss: [1.0663065, 1.0, 0.0, 0.002969727, 0.003058016, 0.0029712291, 0.003057837]
# Batch: 120
# D_Loss: [0.5 0.5]
# G_Loss: [1.0525385, 1.0, 0.0, 0.002075063, 0.00270091, 0.0020777057, 0.0027010192]
# Epoch: 3
# Number of batches: 121
# Batch: 0
# D_Loss: [0.5 0.5]
# G_Loss: [1.0448604, 1.0, 0.0, 0.0012180633, 0.0028602816, 0.001216554, 0.002860312]
# Batch: 1
# D_Loss: [0.5 0.5]
# G_Loss: [1.0561738, 1.0, 0.0, 0.0019169755, 0.0031893505, 0.0019211348, 0.0031893002]
# Batch: 2
# D_Loss: [0.5 0.5]
# G_Loss: [1.0408058, 1.0, 0.0, 0.0016860184, 0.0020235386, 0.0016866224, 0.0020236687]
# Batch: 3
# D_Loss: [0.5 0.5]
# G_Loss: [1.0619934, 1.0, 0.0, 0.0029238907, 0.0027121748, 0.002920683, 0.0027120668]
# Batch: 4
# D_Loss: [0.5 0.5]
# G_Loss: [1.0304688, 1.0, 0.0, 0.0014125878, 0.0013572723, 0.0014131258, 0.0013571728]
# Batch: 5
# D_Loss: [0.5 0.5]
# G_Loss: [1.0529622, 1.0, 0.0, 0.001044853, 0.0037698264, 0.001045636, 0.0037697887]
# Batch: 6
# D_Loss: [0.5 0.5]
# G_Loss: [1.0745748, 1.0, 0.0, 0.0012361947, 0.005543242, 0.001237172, 0.0055432133]
# Batch: 7
# D_Loss: [0.5 0.5]
# G_Loss: [1.0488625, 1.0, 0.0, 0.0011559338, 0.003286126, 0.0011558679, 0.0032860376]
# Batch: 8
# D_Loss: [0.5 0.5]
# G_Loss: [1.0492578, 1.0, 0.0, 0.0018717357, 0.0026066029, 0.0018678609, 0.0026063947]
# Batch: 9
# D_Loss: [0.5 0.5]
# ...
# Batch: 4
# D_Loss: [0.5 0.5]
# G_Loss: [1.0260189, 1.0, 0.0, 0.0012021405, 0.0011632015, 0.0012024658, 0.001163062]
# Batch: 5
# D_Loss: [0.5 0.5]
# G_Loss: [1.0420821, 1.0, 0.0, 0.0010185931, 0.0028070416, 0.0010184897, 0.0028071366]
# Batch: 6
# D_Loss: [0.5 0.5]
# G_Loss: [1.0621687, 1.0, 0.0, 0.0012110521, 0.004440671, 0.001210931, 0.004440679]
# Batch: 7
# D_Loss: [0.5 0.5]
# G_Loss: [1.0335295, 1.0, 0.0, 0.0010604453, 0.0019877553, 0.001059826, 0.001987652]
# Batch: 8
# D_Loss: [0.5 0.5]
# G_Loss: [1.0370389, 1.0, 0.0, 0.001973149, 0.0013941401, 0.0019720206, 0.0013939454]
# Batch: 9
# D_Loss: [0.5 0.5]
# G_Loss: [1.0321226, 1.0, 0.0, 0.0011819066, 0.0017384002, 0.0011815382, 0.0017379057]
# Batch: 10
# D_Loss: [0.5 0.5]
# G_Loss: [1.0462992, 1.0, 0.0, 0.0016359723, 0.0025732215, 0.0016340713, 0.0025731921]
# Batch: 11
# D_Loss: [0.5 0.5]
# G_Loss: [1.0405555, 1.0, 0.0, 0.0019933921, 0.0016935196, 0.0019928087, 0.0016934823]
# Batch: 12
# D_Loss: [0.5 0.5]
# G_Loss: [1.0402775, 1.0, 0.0, 0.0012229466, 0.0024386588, 0.0012229021, 0.0024385427]
# Batch: 13
# D_Loss: [0.5 0.5]
# G_Loss: [1.0300137, 1.0, 0.0, 0.0019340577, 0.00079445646, 0.0019342041, 0.0007943441]
# Batch: 14
# D_Loss: [0.5 0.5]
# G_Loss: [1.0293646, 1.0, 0.0, 0.0014370914, 0.0012324471, 0.0014368416, 0.001232326]
# Batch: 15
# D_Loss: [0.5 0.5]
# G_Loss: [1.0258054, 1.0, 0.0, 0.0013564338, 0.0009895694, 0.0013557759, 0.0009895267]
# Batch: 16
# D_Loss: [0.5 0.5]
# G_Loss: [1.02848, 1.0, 0.0, 0.0013558274, 0.0012332343, 0.0013561301, 0.0012333589]
# Batch: 17
# D_Loss: [0.5 0.5]
# G_Loss: [1.0392098, 1.0, 0.0, 0.0012894671, 0.002275081, 0.0012892147, 0.0022751226]
# Batch: 18
# D_Loss: [0.5 0.5]
# G_Loss: [1.0352863, 1.0, 0.0, 0.0014165564, 0.0017913694, 0.0014160194, 0.0017910709]
# Batch: 19
# D_Loss: [0.5 0.5]
# G_Loss: [1.055467, 1.0, 0.0, 0.0016287086, 0.003413749, 0.0016287975, 0.0034137082]
# Batch: 20
# D_Loss: [0.5 0.5]
# G_Loss: [1.041546, 1.0, 0.0, 0.0015972555, 0.0021796497, 0.0015971186, 0.002179734]
# Batch: 21
# D_Loss: [0.5 0.5]
# G_Loss: [1.03433, 1.0, 0.0, 0.001559102, 0.0015619257, 0.0015580619, 0.0015616847]
# Batch: 22
# D_Loss: [0.5 0.5]
# G_Loss: [1.030588, 1.0, 0.0, 0.0014417511, 0.0013390755, 0.0014406508, 0.0013390263]
# Batch: 23
# D_Loss: [0.5 0.5]
# G_Loss: [1.0315473, 1.0, 0.0, 0.0010021295, 0.0018657951, 0.0010023986, 0.0018656636]
# Batch: 24
# D_Loss: [0.5 0.5]
# G_Loss: [1.0399143, 1.0, 0.0, 0.0019097237, 0.0017189134, 0.0019090471, 0.0017188545]
# Batch: 25
# D_Loss: [0.5 0.5]
# G_Loss: [1.0411891, 1.0, 0.0, 0.0014259114, 0.002318562, 0.0014257275, 0.0023185844]
# Batch: 26
# D_Loss: [0.5 0.5]
# G_Loss: [1.0330373, 1.0, 0.0, 0.0020442149, 0.00095922855, 0.0020438428, 0.0009590448]
# Batch: 27
# D_Loss: [0.5 0.5]
# G_Loss: [1.0365442, 1.0, 0.0, 0.0016541538, 0.0016680865, 0.001653871, 0.001667995]
# Batch: 28
# D_Loss: [0.5 0.5]
# G_Loss: [1.0314324, 1.0, 0.0, 0.0017692724, 0.0010881893, 0.0017696342, 0.0010881711]
# Batch: 29
# D_Loss: [0.5 0.5]
# G_Loss: [1.057723, 1.0, 0.0, 0.0027728586, 0.0024747842, 0.0027719026, 0.0024748177]
# Batch: 30
# D_Loss: [0.5 0.5]
# G_Loss: [1.0339209, 1.0, 0.0, 0.001482028, 0.00160173, 0.0014815673, 0.0016017521]
# Batch: 31
# D_Loss: [0.5 0.5]
# G_Loss: [1.0320717, 1.0, 0.0, 0.0013316341, 0.0015839749, 0.0013317859, 0.0015838271]
# Batch: 32
# D_Loss: [0.5 0.5]
# G_Loss: [1.0360016, 1.0, 0.0, 0.0010485788, 0.0022243224, 0.0010482881, 0.002224153]
# Batch: 33
# D_Loss: [0.5 0.5]
# G_Loss: [1.027247, 1.0, 0.0, 0.001185141, 0.0012919588, 0.0011843897, 0.0012915932]
# Batch: 34
# D_Loss: [0.5 0.5]
# G_Loss: [1.0306399, 1.0, 0.0, 0.0013650595, 0.0014204273, 0.0013648896, 0.0014201938]
# Batch: 35
# D_Loss: [0.5 0.5]
# G_Loss: [1.0374326, 1.0, 0.0, 0.0016240941, 0.001778899, 0.0016240051, 0.0017786245]
# Batch: 36
# D_Loss: [0.5 0.5]
# G_Loss: [1.0262914, 1.0, 0.0, 0.0012122078, 0.0011780352, 0.0012109522, 0.0011780094]
# Batch: 37
# D_Loss: [0.5 0.5]
# G_Loss: [1.0287861, 1.0, 0.0, 0.0016337103, 0.0009832574, 0.0016332341, 0.0009829766]
# Batch: 38
# D_Loss: [0.5 0.5]
# G_Loss: [1.0239105, 1.0, 0.0, 0.0015337104, 0.00063997856, 0.0015337075, 0.00063996523]
# Batch: 39
# D_Loss: [0.5 0.5]
# G_Loss: [1.0295863, 1.0, 0.0, 0.0021298989, 0.00055973814, 0.0021301247, 0.00055976014]
# Batch: 40
# D_Loss: [0.5 0.5]
# G_Loss: [1.0569739, 1.0, 0.0, 0.0017407136, 0.0034388648, 0.0017391775, 0.0034389556]
# Batch: 41
# D_Loss: [0.5 0.5]
# G_Loss: [1.060181, 1.0, 0.0, 0.0029747665, 0.0024962542, 0.0029745803, 0.0024961575]
# Batch: 42
# D_Loss: [0.5 0.5]
# G_Loss: [1.0515972, 1.0, 0.0, 0.0015301753, 0.0031605058, 0.0015298761, 0.0031606539]
# Batch: 43
# D_Loss: [0.5 0.5]
# G_Loss: [1.0412954, 1.0, 0.0, 0.0009700396, 0.0027840342, 0.0009705226, 0.0027840827]
# Batch: 44
# D_Loss: [0.5 0.5]
# G_Loss: [1.0258994, 1.0, 0.0, 0.0011617623, 0.0011927957, 0.0011616095, 0.0011921976]
# Batch: 45
# D_Loss: [0.5 0.5]
# G_Loss: [1.0310634, 1.0, 0.0, 0.0012231991, 0.0016007638, 0.0012231154, 0.0016006841]
# Batch: 46
# D_Loss: [0.5 0.5]
# G_Loss: [1.0422815, 1.0, 0.0, 0.0023827879, 0.0014609806, 0.0023827425, 0.0014610023]
# Batch: 47
# D_Loss: [0.5 0.5]
# G_Loss: [1.0322785, 1.0, 0.0, 0.0010188838, 0.0019155806, 0.0010183232, 0.0019156062]
# Batch: 48
# D_Loss: [0.5 0.5]
# G_Loss: [1.041182, 1.0, 0.0, 0.0016750928, 0.002068827, 0.0016743432, 0.002068471]
# Batch: 49
# D_Loss: [0.5 0.5]
# G_Loss: [1.0260246, 1.0, 0.0, 0.00081514916, 0.0015507606, 0.00081478816, 0.0015506956]
# Batch: 50
# D_Loss: [0.5 0.5]
# G_Loss: [1.0234177, 1.0, 0.0, 0.000687354, 0.001441552, 0.0006873333, 0.0014413211]
# Batch: 51
# D_Loss: [0.5 0.5]
# G_Loss: [1.0383681, 1.0, 0.0, 0.0017385986, 0.0017494524, 0.0017382716, 0.001749322]
# Batch: 52
# D_Loss: [0.5 0.5]
# G_Loss: [1.042916, 1.0, 0.0, 0.0013809557, 0.0025205088, 0.0013810284, 0.0025203442]
# Batch: 53
# D_Loss: [0.5 0.5]
# G_Loss: [1.0409602, 1.0, 0.0, 0.0018903227, 0.0018333147, 0.0018909121, 0.0018328668]
# Batch: 54
# D_Loss: [0.5 0.5]
# G_Loss: [1.0328778, 1.0, 0.0, 0.0019032598, 0.0010855824, 0.0019039657, 0.001085365]
# Batch: 55
# D_Loss: [0.5 0.5]
# G_Loss: [1.0400084, 1.0, 0.0, 0.0016553912, 0.0019817872, 0.001655021, 0.0019816873]
# Batch: 56
# D_Loss: [0.5 0.5]
# G_Loss: [1.0349036, 1.0, 0.0, 0.0013705832, 0.0018024824, 0.0013707189, 0.0018023615]
# Batch: 57
# D_Loss: [0.5 0.5]
# G_Loss: [1.0380063, 1.0, 0.0, 0.0017284066, 0.001726777, 0.0017277147, 0.0017267361]
# Batch: 58
# D_Loss: [0.5 0.5]
# G_Loss: [1.0318496, 1.0, 0.0, 0.0016862033, 0.0012092271, 0.0016861574, 0.0012091603]
# Batch: 59
# D_Loss: [0.5 0.5]
# G_Loss: [1.0346175, 1.0, 0.0, 0.0016729087, 0.0014742131, 0.0016722241, 0.0014740685]
# Batch: 60
# D_Loss: [0.5 0.5]
# G_Loss: [1.0345839, 1.0, 0.0, 0.0018567576, 0.0012872231, 0.0018570155, 0.0012871261]
# Batch: 61
# D_Loss: [0.5 0.5]
# G_Loss: [1.0323975, 1.0, 0.0, 0.00142484, 0.0015203131, 0.0014256935, 0.0015203113]
# Batch: 62
# D_Loss: [0.5 0.5]
# G_Loss: [1.0439736, 1.0, 0.0, 0.001642341, 0.0023553243, 0.0016420998, 0.0023547397]
# Batch: 63
# D_Loss: [0.5 0.5]
# G_Loss: [1.0433083, 1.0, 0.0, 0.0017498626, 0.0021873156, 0.0017492762, 0.0021872222]
# Batch: 64
# D_Loss: [0.5 0.5]
# G_Loss: [1.0418314, 1.0, 0.0, 0.0019244165, 0.0018785759, 0.001923477, 0.0018780254]
# Batch: 65
# D_Loss: [0.5 0.5]
# G_Loss: [1.0469831, 1.0, 0.0, 0.0018237126, 0.0024476247, 0.0018221162, 0.0024476335]
# Batch: 66
# D_Loss: [0.5 0.5]
# G_Loss: [1.0321903, 1.0, 0.0, 0.0014991667, 0.0014273042, 0.0014993725, 0.0014262553]
# Batch: 67
# D_Loss: [0.5 0.5]
# G_Loss: [1.031825, 1.0, 0.0, 0.0010129234, 0.0018803156, 0.0010124478, 0.001880195]
# Batch: 68
# D_Loss: [0.5 0.5]
# G_Loss: [1.0492519, 1.0, 0.0, 0.0030741869, 0.0014032396, 0.003074552, 0.001403184]
# Batch: 69
# D_Loss: [0.5 0.5]
# G_Loss: [1.0428371, 1.0, 0.0, 0.0014490404, 0.002445368, 0.0014479943, 0.002445083]
# Batch: 70
# D_Loss: [0.5 0.5]
# G_Loss: [1.0391766, 1.0, 0.0, 0.0020331335, 0.0015283603, 0.0020334956, 0.001528116]
# Batch: 71
# D_Loss: [0.5 0.5]
# G_Loss: [1.0694069, 1.0, 0.0, 0.0034906776, 0.002819276, 0.003488138, 0.002819233]
# Batch: 72
# D_Loss: [0.5 0.5]
# G_Loss: [1.0272957, 1.0, 0.0, 0.0011886966, 0.0012927458, 0.0011886067, 0.0012927193]
# Batch: 73
# D_Loss: [0.5 0.5]
# G_Loss: [1.0336707, 1.0, 0.0, 0.0010970236, 0.001964009, 0.0010963837, 0.001963919]
# Batch: 74
# D_Loss: [0.5 0.5]
# G_Loss: [1.0328513, 1.0, 0.0, 0.0014914175, 0.0014952143, 0.0014897209, 0.0014952146]
# Batch: 75
# D_Loss: [0.5 0.5]
# G_Loss: [1.0388095, 1.0, 0.0, 0.0018143298, 0.0017140484, 0.0018136665, 0.0017120275]
# Batch: 76
# D_Loss: [0.5 0.5]
# G_Loss: [1.0510029, 1.0, 0.0, 0.0018853032, 0.0027513872, 0.001883969, 0.002751897]
# Batch: 77
# D_Loss: [0.5 0.5]
# G_Loss: [1.0321256, 1.0, 0.0, 0.0018128918, 0.0011076981, 0.0018122431, 0.0011075722]
# Batch: 78
# D_Loss: [0.5 0.5]
# G_Loss: [1.0289961, 1.0, 0.0, 0.0012927951, 0.0013432822, 0.0012921154, 0.0013431844]
# Batch: 79
# D_Loss: [0.5 0.5]
# G_Loss: [1.0281091, 1.0, 0.0, 0.0008837995, 0.0016715818, 0.0008837378, 0.0016716465]
# Batch: 80
# D_Loss: [0.5 0.5]
# G_Loss: [1.0366894, 1.0, 0.0, 0.0017149956, 0.0016204057, 0.0017150375, 0.0016204314]
# Batch: 81
# D_Loss: [0.5 0.5]
# G_Loss: [1.0535716, 1.0, 0.0, 0.0024596488, 0.0024105788, 0.0024590655, 0.0024102516]
# Batch: 82
# D_Loss: [0.5 0.5]
# G_Loss: [1.0290697, 1.0, 0.0, 0.0011983076, 0.0014444795, 0.0011973022, 0.0014444215]
# Batch: 83
# D_Loss: [0.5 0.5]
# G_Loss: [1.0356461, 1.0, 0.0, 0.0017217182, 0.0015188815, 0.0017216485, 0.0015185147]
# Batch: 84
# D_Loss: [0.5 0.5]
# G_Loss: [1.0362724, 1.0, 0.0, 0.0010005485, 0.0022969642, 0.0010005354, 0.0022968408]
# Batch: 85
# D_Loss: [0.5 0.5]
# G_Loss: [1.0371575, 1.0, 0.0, 0.0013809197, 0.0019972194, 0.0013791265, 0.0019970436]
# Batch: 86
# D_Loss: [0.5 0.5]
# G_Loss: [1.0334011, 1.0, 0.0, 0.0013879118, 0.0016487059, 0.0013864973, 0.0016485394]
# Batch: 87
# D_Loss: [0.5 0.5]
# G_Loss: [1.0340297, 1.0, 0.0, 0.0015679987, 0.0015257497, 0.0015665668, 0.001525721]
# Batch: 88
# D_Loss: [0.5 0.5]
# G_Loss: [1.025744, 1.0, 0.0, 0.0008372845, 0.0015030759, 0.0008372585, 0.0015030508]
# Batch: 89
# D_Loss: [0.5 0.5]
# G_Loss: [1.0304021, 1.0, 0.0, 0.0015397856, 0.0012240161, 0.001540123, 0.0012238675]
# Batch: 90
# D_Loss: [0.5 0.5]
# G_Loss: [1.0379899, 1.0, 0.0, 0.0017816279, 0.0016721019, 0.0017808506, 0.0016716582]
# Batch: 91
# D_Loss: [0.5 0.5]
# G_Loss: [1.0418786, 1.0, 0.0, 0.0023264585, 0.0014806848, 0.002326909, 0.0014802254]
# Batch: 92
# D_Loss: [0.5 0.5]
# G_Loss: [1.0375973, 1.0, 0.0, 0.0014620431, 0.001956052, 0.0014601757, 0.0019560591]
# Batch: 93
# D_Loss: [0.5 0.5]
# G_Loss: [1.0421395, 1.0, 0.0, 0.001038446, 0.0027924725, 0.0010377064, 0.0027926276]
# Batch: 94
# D_Loss: [0.5 0.5]
# G_Loss: [1.0250717, 1.0, 0.0, 0.0012722824, 0.0010070696, 0.001271293, 0.0010069769]
# Batch: 95
# D_Loss: [0.5 0.5]
# G_Loss: [1.0527713, 1.0, 0.0, 0.0023167618, 0.0024807635, 0.0023160186, 0.0024799774]
# Batch: 96
# D_Loss: [0.5 0.5]
# G_Loss: [1.0322775, 1.0, 0.0, 0.0015260859, 0.0014082303, 0.0015261426, 0.001408247]
# Batch: 97
# D_Loss: [0.5 0.5]
# G_Loss: [1.0344924, 1.0, 0.0, 0.0012941902, 0.0018415228, 0.0012938122, 0.0018414212]
# Batch: 98
# D_Loss: [0.5 0.5]
# G_Loss: [1.0425364, 1.0, 0.0, 0.001568997, 0.0022980485, 0.0015676646, 0.0022982932]
# Batch: 99
# D_Loss: [0.5 0.5]
# G_Loss: [1.0283717, 1.0, 0.0, 0.001053901, 0.0015254244, 0.0010533975, 0.0015249705]
# Batch: 100
# D_Loss: [0.5 0.5]
# G_Loss: [1.0320138, 1.0, 0.0, 0.0018789268, 0.0010314492, 0.0018786575, 0.0010313431]
# Batch: 101
# D_Loss: [0.5 0.5]
# G_Loss: [1.0366875, 1.0, 0.0, 0.0018783172, 0.0014569024, 0.0018783044, 0.0014569508]
# Batch: 102
# D_Loss: [0.5 0.5]
# G_Loss: [1.0340805, 1.0, 0.0, 0.0016309532, 0.0014672492, 0.0016313721, 0.0014671113]
# Batch: 103
# D_Loss: [0.5 0.5]
# G_Loss: [1.0427271, 1.0, 0.0, 0.0016282676, 0.002255972, 0.0016288089, 0.0022559126]
# Batch: 104
# D_Loss: [0.5 0.5]
# G_Loss: [1.0409677, 1.0, 0.0, 0.001166272, 0.0025581075, 0.00116597, 0.0025578653]
# Batch: 105
# D_Loss: [0.5 0.5]
# G_Loss: [1.0321752, 1.0, 0.0, 0.0017714417, 0.0011536679, 0.0017705989, 0.0011534595]
# Batch: 106
# D_Loss: [0.5 0.5]
# G_Loss: [1.0404569, 1.0, 0.0, 0.0014787556, 0.0021992102, 0.0014780327, 0.0021991208]
# Batch: 107
# D_Loss: [0.5 0.5]
# G_Loss: [1.0372792, 1.0, 0.0, 0.0020286213, 0.0013605019, 0.002027859, 0.001360208]
# Batch: 108
# D_Loss: [0.5 0.5]
# G_Loss: [1.0402292, 1.0, 0.0, 0.0012369014, 0.0024203353, 0.0012366995, 0.002420194]
# Batch: 109
# D_Loss: [0.5 0.5]
# G_Loss: [1.0350393, 1.0, 0.0, 0.001748792, 0.0014366355, 0.0017485797, 0.0014364452]
# Batch: 110
# D_Loss: [0.5 0.5]
# G_Loss: [1.0303367, 1.0, 0.0, 0.0011912576, 0.0015666328, 0.0011914144, 0.0015664395]
# Batch: 111
# D_Loss: [0.5 0.5]
# G_Loss: [1.0408204, 1.0, 0.0, 0.0019766313, 0.0017343466, 0.0019767717, 0.0017338158]
# Batch: 112
# D_Loss: [0.5 0.5]
# G_Loss: [1.028091, 1.0, 0.0, 0.0011102355, 0.0014435581, 0.0011096642, 0.001443421]
# Batch: 113
# D_Loss: [0.5 0.5]
# G_Loss: [1.0270739, 1.0, 0.0, 0.0013245367, 0.0011369099, 0.0013229653, 0.0011364755]
# Batch: 114
# D_Loss: [0.5 0.5]
# G_Loss: [1.0259445, 1.0, 0.0, 0.0011068482, 0.0012517942, 0.0011063777, 0.0012516417]
# Batch: 115
# D_Loss: [0.5 0.5]
# G_Loss: [1.0276794, 1.0, 0.0, 0.0015456218, 0.0009706937, 0.0015456406, 0.000970599]
# Batch: 116
# D_Loss: [0.5 0.5]
# G_Loss: [1.0347098, 1.0, 0.0, 0.0018385837, 0.0013168086, 0.0018391602, 0.0013167257]
# Batch: 117
# D_Loss: [0.5 0.5]
# G_Loss: [1.0393384, 1.0, 0.0, 0.0024280108, 0.0011482252, 0.0024279084, 0.001148141]
# Batch: 118
# D_Loss: [0.5 0.5]
# G_Loss: [1.0548131, 1.0, 0.0, 0.0017590927, 0.0032238779, 0.0017595916, 0.003223897]
# Batch: 119
# D_Loss: [0.5 0.5]
# G_Loss: [1.0641576, 1.0, 0.0, 0.0036672824, 0.002165115, 0.0036686016, 0.002165122]
# Batch: 120
# D_Loss: [0.5 0.5]
# W0822 13:12:00.810707 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 13:12:00.835649 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 13:12:00.855693 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# G_Loss: [1.039357, 1.0, 0.0, 0.0017186594, 0.0018592626, 0.0017186969, 0.0018590989]
# W0822 13:12:00.874701 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 13:12:00.895823 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 13:12:00.913496 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 13:12:00.991259 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 13:12:01.010306 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 13:12:01.029375 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 13:12:01.048117 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 13:12:01.066426 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0822 13:12:01.084241 139716881598336 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch: 21
# Number of batches: 121
# Batch: 0
# D_Loss: [0.5 0.5]
# G_Loss: [1.0317351, 1.0, 0.0, 0.0010825285, 0.0018024929, 0.0010828323, 0.0018020737]
# Batch: 1
# D_Loss: [0.5 0.5]
# G_Loss: [1.0511647, 1.0, 0.0, 0.0018909018, 0.0027604117, 0.0018909741, 0.002760621]
# Batch: 2
# D_Loss: [0.5 0.5]
# G_Loss: [1.0320256, 1.0, 0.0, 0.0017160284, 0.0011955148, 0.0017146135, 0.0011955099]
# Batch: 3
# D_Loss: [0.5 0.5]
# G_Loss: [1.0510559, 1.0, 0.0, 0.0028536946, 0.0017877315, 0.0028541593, 0.0017875144]
# Batch: 4
# D_Loss: [0.5 0.5]
# G_Loss: [1.0260245, 1.0, 0.0, 0.0012029654, 0.0011628708, 0.0012032909, 0.0011627255]
# Batch: 5
# D_Loss: [0.5 0.5]
# G_Loss: [1.0420709, 1.0, 0.0, 0.0010179211, 0.002806708, 0.0010178435, 0.0028068065]
# Batch: 6
# D_Loss: [0.5 0.5]
