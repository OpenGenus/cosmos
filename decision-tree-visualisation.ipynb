# %% [markdown]
# # Visualising a Decision Tree
# ### This will help you picture what a decision tree algorithm internal structure looks like.
# #### Done By: Meyank Mohapatra

# %%
# importing the libraries
import pandas as pd
from sklearn import datasets
from sklearn import tree
from matplotlib import pyplot as plt

# %%
# importing the data
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
# creating the model
model_task4 = tree.DecisionTreeClassifier()
model_task4.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
# visualising the model
fig = plt.figure(figsize=(40, 30))
_ = tree.plot_tree(model_task4, 
                   feature_names=iris.feature_names,  
                   class_names=iris.target_names,
                   filled=True)
# Out:
# &lt;Figure size 2880x2160 with 1 Axes&gt;
